# %% [markdown]
# # Automated Spidroin Annotation
#
# This project The goal of this project is to develop an automated pipeline for spidroin annotation for spider genome.

# %%
import os
import subprocess

from spider_silkome_module import (
    RAW_DATA_DIR,
    INTERIM_DATA_DIR,
    PROCESSED_DATA_DIR,
    EXTERNAL_DATA_DIR,
    REFERENCES_DIR,
    SCRIPTS_DIR,
)
from spider_silkome_module import (
    run_shell_command_with_check,
)
# Out:
# 2025-12-05 10:52:39.020 | INFO     | spider_silkome_module.config:<module>:11 - PROJ_ROOT path is: /home/gyk/project/spider_silkome

# %% [markdown]
# ## Configure the environment

# %%
project_name = "automated_spidroin_annotation"

# Define multiple species to analyze
spiders = [
    "001.Allagelena_difficilis",
    "002.Anyphaena_bomiensis",
    "003.Atypus_heterothecus",
    "004.Borboropactus_sp",
    "005.Bowie_medogensis",
    "006.Cicurina_yinheensis",
    "007.Ctenus_medogensis",
    "008.Cybaeus_sp",
    "009.Cyclocosmia_sp",
    "010.Damarchus_sp",
    "011.Dolomedes_nigrimaculatus",
    "012.Ectatosticta_nyingchiensis",
    "013.Evarcha_sp",
    "014.Guicybaeus_sp",
    "015.Heliconilla_oblonga",
    "016.Hersilia_striata",
    "017.Hippasa_lycosina",
    "018.Jacaena_bannaensis",
    "019.Karstia_sp",
    "020.Lathys_subalberta",
    "021.Leclercera_selasihensis",
    "022.Loxosceles_rufescens",
    "023.Macrothele_washanensis",
    "024.Meta_wanglangensis",
    "025.Micaria_jinlin",
    "026.Mimetus_sp",
    "027.Neobisiidae_sp",
    "028.Neriene_sp",
    "029.nizha",
    "030.Oecobius_navus",
    "031.Pandercetes_sp",
    "032.Perania_robusta",
    "033.Peucetia_latikae",
    "034.Pholcus_sp",
    "035.Phrurolithus_hamatus",
    "036.Pimoa_nyingchi",
    "037.Pireneitega_xinping",
    "038.Plator_bowo",
    "039.Prochora_praticola",
    "040.Psechrus_senoculatus",
    "041.Pseudogagrella_splendens",
    "042.Psilodercidae_sp",
    "043.Raveniola_sp",
    "044.Schizomida_sp",
    "045.Scorpiops_zhui",
    "046.Scytodidae_sp",
    "047.Selenops_bursarius",
    "048.Solifugae_sp",
    "049.Songthela_sp",
    "050.Spinirta_sp",
    "051.Stedocys_bafengensis",
    "052.Taira_zhui",
    "053.Tibellus_sp.2",
    "054.Titanoeca_chayuensis",
    "055.Tricalamus_sp",
    "056.Uloborus_guangxiensis",
    "057.Uropygi_sp",
    "058.Weygoldtia_hainanensis",
    "059.Zoropsis_tangi",
    "060.Acanthoscurria_geniculata",
    "061.Amaurobius_ferox",
    "062.Anelosimus_studiosus",
    "063.Araneus_marmoreus",
    "064.Araneus_ventricosus",
    "065.Argiope_argentata",
    "066.Argiope_aurantia",
    "067.Argiope_bruennichi",
    "068.Argiope_trifasciata",
    "069.Atypus_karschi",
    "070.Caerostris_darwini",
    "071.Caerostris_extrusa",
    "072.Chaetopelma_lymberakisi",
    "073.Cheiracanthium_punctorium",
    "074.Dolomedes_plantarius",
    "075.Dysdera_silvatica",
    "076.Ectatosticta_davidi",
    "077.Eratigena_atrica",
    "078.Gibbaranea_gibbosa",
    "079.Heteropoda_venatoria",
    "080.Hylyphantes_graminicola",
    "081.Larinioides_cornutus",
    "082.Larinioides_sclopetarius",
    "083.Latrodectus_elegans",
    "084.Latrodectus_geometricus",
    "085.Latrodectus_hesperus",
    "086.Leviellus_thorelli",
    "087.Linyphia_triangularis",
    "088.Loxosceles_reclusa",
    "089.Luthela_beijing",
    "090.Lycosa_singoriensis",
    "091.Macrothele_cretica",
    "092.Macrothele_yani",
    "093.Maratus_albus",
    "094.Maratus_michaelseni",
    "095.Maratus_speciosus",
    "096.Maratus_speculifer",
    "097.Meta_bourneti",
    "098.Metellina_segmentata",
    "099.Nephila_pilipes",
    "100.Octonoba_sinensis",
    "101.Oedothorax_gibbosus",
    "102.Parasteatoda_lunata",
    "103.Parasteatoda_tepidariorum",
    "104.Pardosa_agraria",
    "105.Pardosa_laura",
    "106.Pardosa_pseudoannulata",
    "107.Ryuthela_nishihirai",
    "108.Salticus_scenicus",
    "109.Stegodyphus_bicolor",
    "110.Stegodyphus_dumicola",
    "111.Stegodyphus_lineatus",
    "112.Stegodyphus_mimosarum",
    "113.Stegodyphus_sarasinorum",
    "114.Stegodyphus_tentoriicola",
    "115.Tetragnatha_kauaiensis",
    "116.Tetragnatha_montana",
    "117.Tetragnatha_versicolor",
    "118.Trichonephila_antipodiana",
    "119.Trichonephila_clavata",
    "120.Trichonephila_clavipes",
    "121.Trichonephila_inaurata_madagascariensis",
    "122.Troglohyphantes_excavatus",
    "123.Uloborus_diversus",
    "124.Uloborus_plumipes",
    "125.Aptostichus_stephencolberti",
    "126.Araneus_angulatus",
    "127.Dysdera_catalonica",
    "128.Dysdera_tilosensis",
    "129.Philodromus_cespitum",
    "130.Pimoa_clavata",
    "131.Segestria_senoculata",
    "132.Tibellus_oblongus",
    "133.Xysticus_acerbus",
    "134.Zoropsis_spinimana"
]

# Common directories
hmmer_model_dir = REFERENCES_DIR / "2025_Schoneberg_data" / "hmmer_nucl_profile_trimmed"
nhmmer_search_base = INTERIM_DATA_DIR / project_name / "nhmmer_search"
spider_genome_dir = RAW_DATA_DIR / "01.ref_gff"
spidroin_analysis_output = PROCESSED_DATA_DIR / project_name / "spidroin_analysis"

# Create output directories for each species
for spider in spiders:
    spider_nhmmer_dir = nhmmer_search_base / spider
    os.makedirs(spider_nhmmer_dir, exist_ok=True)
os.makedirs(spidroin_analysis_output, exist_ok=True)

# Step 2: Spidroin prediction with Augustus (per species config)
augustus_config_file = EXTERNAL_DATA_DIR / "extrinsic.cfg"

print(f"Configured {len(spiders)} species: {spiders}")
# Out:
# Configured 10 species: ['Trichonephila_clavata', 'Araneus_ventricosus', 'Evarcha_sp', 'Heteropoda_venatoria', 'Hippasa_lycosina', 'Pandercetes_sp', 'Pardosa_pseudoannulata', 'Pholcus_sp', 'Scorpiops_zhui', 'Songthela_sp']

# %% [markdown]
# ## Step 1: Identifying and Sorting Spidroins
#
# In this step, we will use the nhmmer to map the spider genome to the spidroin N/C terminal protein sequences. The hmmer model was downloaded from this [paper](https://doi.org/10.1111/1755-0998.14038) and the [Zenodo link](https://doi.org/10.5281/zenodo.13711380).

# %%
# Step 1.1: Press HMM models (only once)
for model in hmmer_model_dir.glob("*TD.hmm"):
    model_name = model.stem.split('.')[0]
    hmmer_press_cmd = f"pixi run hmmpress {model}"
    run_shell_command_with_check(hmmer_press_cmd, f"{model_name}.h3m")

# %%
# Step 1.2: Run nhmmer search for all species
for spider in spiders:
    print(f"\n{'='*60}")
    print(f"Processing: {spider}")
    print(f"{'='*60}")

    spider_subdir = spider_genome_dir / spider
    spider_genome_file = next(
        (f for f in spider_subdir.iterdir() if f.suffix in ('.fa', '.fna')), None
    )
    nhmmer_output_dir = nhmmer_search_base / spider

    if spider_genome_file is None:
        print(f"Warning: No .fa or .fna genome file found in: {spider_subdir}")
        continue

    for model in hmmer_model_dir.glob("*TD.hmm"):
        model_name = model.stem.split('.')[0]
        nhmmer_cmd = f"pixi run nhmmer --cpu 200 --tblout {nhmmer_output_dir}/{model_name}.tbl {model} {spider_genome_file} > {nhmmer_output_dir}/{model_name}.out"
        run_shell_command_with_check(nhmmer_cmd, f"{nhmmer_output_dir}/{model_name}.out")

    print(f"Completed: {spider}")

# %%
# Step 1.3: Analyze all species with spidroin analysis script
# The script will automatically detect all species subdirectories in nhmmer_search_base
spidroin_analysis_cmd = f"pixi run python {SCRIPTS_DIR}/analyse_spidroins.py \
    -i {nhmmer_search_base} \
    -p {hmmer_model_dir} \
    --assembly-dir {spider_genome_dir} \
    -o {spidroin_analysis_output}"
print(spidroin_analysis_cmd)
run_shell_command_with_check(spidroin_analysis_cmd, spidroin_analysis_output / "spidroins_total.tsv", force=True)
# Out:
# pixi run python /home/gyk/project/spider_silkome/scripts/analyse_spidroins.py     -i /home/gyk/project/spider_silkome/data/interim/automated_spidroin_annotation/nhmmer_search     -p /home/gyk/project/spider_silkome/references/2025_Schoneberg_data/hmmer_nucl_profile_trimmed     --assembly-dir /home/gyk/project/spider_silkome/data/raw/spider_genome     -o /home/gyk/project/spider_silkome/data/processed/automated_spidroin_annotation/spidroin_analysis
# 2025-12-05 13:11:26.779 | INFO     | spider_silkome_module.features:run_shell_command_with_check:50 - Execute command: pixi run python /home/gyk/project/spider_silkome/scripts/analyse_spidroins.py     -i /home/gyk/project/spider_silkome/data/interim/automated_spidroin_annotation/nhmmer_search     -p /home/gyk/project/spider_silkome/references/2025_Schoneberg_data/hmmer_nucl_profile_trimmed     --assembly-dir /home/gyk/project/spider_silkome/data/raw/spider_genome     -o /home/gyk/project/spider_silkome/data/processed/automated_spidroin_annotation/spidroin_analysis
# Generating summary table from HMMER results...
# Reading HMMER-Tables for Scorpiops_zhui
# /home/gyk/project/spider_silkome/scripts/analyse_spidroins.py:944: FutureWarning: The behavior of DataFrame concatenation with empty or all-NA entries is deprecated. In a future version, this will no longer exclude empty or all-NA columns when determining the result dtypes. To retain the old behavior, exclude the relevant entries before the concat operation.
#   summary_table = pd.concat([
# Warning: Pandas parser Error, No HMMER hits in output file /home/gyk/project/spider_silkome/data/interim/automated_spidroin_annotation/nhmmer_search/Scorpiops_zhui/MaSp_CTD.tbl?
# /home/gyk/project/spider_silkome/scripts/analyse_spidroins.py:944: FutureWarning: The behavior of DataFrame concatenation with empty or all-NA entries is deprecated. In a future version, this will no longer exclude empty or all-NA columns when determining the result dtypes. To retain the old behavior, exclude the relevant entries before the concat operation.
#   summary_table = pd.concat([
# Warning: Pandas parser Error, No HMMER hits in output file /home/gyk/project/spider_silkome/data/interim/automated_spidroin_annotation/nhmmer_search/Scorpiops_zhui/CySp_CTD.tbl?
# Reading HMMER-Tables for Evarcha_sp
# /home/gyk/project/spider_silkome/scripts/analyse_spidroins.py:944: FutureWarning: The behavior of DataFrame concatenation with empty or all-NA entries is deprecated. In a future version, this will no longer exclude empty or all-NA columns when determining the result dtypes. To retain the old behavior, exclude the relevant entries before the concat operation.
#   summary_table = pd.concat([
# Warning: Pandas parser Error, No HMMER hits in output file /home/gyk/project/spider_silkome/data/interim/automated_spidroin_annotation/nhmmer_search/Evarcha_sp/Flag_CTD.tbl?
# Warning: Pandas parser Error, No HMMER hits in output file /home/gyk/project/spider_silkome/data/interim/automated_spidroin_annotation/nhmmer_search/Evarcha_sp/hypo_CTD.tbl?
# /home/gyk/project/spider_silkome/scripts/analyse_spidroins.py:944: FutureWarning: The behavior of DataFrame concatenation with empty or all-NA entries is deprecated. In a future version, this will no longer exclude empty or all-NA columns when determining the result dtypes. To retain the old behavior, exclude the relevant entries before the concat operation.
#   summary_table = pd.concat([
# /home/gyk/project/spider_silkome/scripts/analyse_spidroins.py:944: FutureWarning: The behavior of DataFrame concatenation with empty or all-NA entries is deprecated. In a future version, this will no longer exclude empty or all-NA columns when determining the result dtypes. To retain the old behavior, exclude the relevant entries before the concat operation.
#   summary_table = pd.concat([
# Reading HMMER-Tables for Pandercetes_sp
# Reading HMMER-Tables for Trichonephila_clavata
# Warning: Pandas parser Error, No HMMER hits in output file /home/gyk/project/spider_silkome/data/interim/automated_spidroin_annotation/nhmmer_search/Trichonephila_clavata/hypo_CTD.tbl?
# /home/gyk/project/spider_silkome/scripts/analyse_spidroins.py:944: FutureWarning: The behavior of DataFrame concatenation with empty or all-NA entries is deprecated. In a future version, this will no longer exclude empty or all-NA columns when determining the result dtypes. To retain the old behavior, exclude the relevant entries before the concat operation.
#   summary_table = pd.concat([
# Warning: Pandas parser Error, No HMMER hits in output file /home/gyk/project/spider_silkome/data/interim/automated_spidroin_annotation/nhmmer_search/Trichonephila_clavata/Pflag_CTD.tbl?
# /home/gyk/project/spider_silkome/scripts/analyse_spidroins.py:944: FutureWarning: The behavior of DataFrame concatenation with empty or all-NA entries is deprecated. In a future version, this will no longer exclude empty or all-NA columns when determining the result dtypes. To retain the old behavior, exclude the relevant entries before the concat operation.
#   summary_table = pd.concat([
# Reading HMMER-Tables for Pardosa_pseudoannulata
# Warning: Pandas parser Error, No HMMER hits in output file /home/gyk/project/spider_silkome/data/interim/automated_spidroin_annotation/nhmmer_search/Pardosa_pseudoannulata/hypo_CTD.tbl?
# /home/gyk/project/spider_silkome/scripts/analyse_spidroins.py:944: FutureWarning: The behavior of DataFrame concatenation with empty or all-NA entries is deprecated. In a future version, this will no longer exclude empty or all-NA columns when determining the result dtypes. To retain the old behavior, exclude the relevant entries before the concat operation.
#   summary_table = pd.concat([
# Warning: Pandas parser Error, No HMMER hits in output file /home/gyk/project/spider_silkome/data/interim/automated_spidroin_annotation/nhmmer_search/Pardosa_pseudoannulata/Pflag_CTD.tbl?
# /home/gyk/project/spider_silkome/scripts/analyse_spidroins.py:944: FutureWarning: The behavior of DataFrame concatenation with empty or all-NA entries is deprecated. In a future version, this will no longer exclude empty or all-NA columns when determining the result dtypes. To retain the old behavior, exclude the relevant entries before the concat operation.
#   summary_table = pd.concat([
# Warning: Pandas parser Error, No HMMER hits in output file /home/gyk/project/spider_silkome/data/interim/automated_spidroin_annotation/nhmmer_search/Pardosa_pseudoannulata/AgSp2_CTD.tbl?
# Reading HMMER-Tables for Pholcus_sp
# /home/gyk/project/spider_silkome/scripts/analyse_spidroins.py:944: FutureWarning: The behavior of DataFrame concatenation with empty or all-NA entries is deprecated. In a future version, this will no longer exclude empty or all-NA columns when determining the result dtypes. To retain the old behavior, exclude the relevant entries before the concat operation.
#   summary_table = pd.concat([
# Warning: Pandas parser Error, No HMMER hits in output file /home/gyk/project/spider_silkome/data/interim/automated_spidroin_annotation/nhmmer_search/Pholcus_sp/MaSp3_CTD.tbl?
# Reading HMMER-Tables for Hippasa_lycosina
# /home/gyk/project/spider_silkome/scripts/analyse_spidroins.py:944: FutureWarning: The behavior of DataFrame concatenation with empty or all-NA entries is deprecated. In a future version, this will no longer exclude empty or all-NA columns when determining the result dtypes. To retain the old behavior, exclude the relevant entries before the concat operation.
#   summary_table = pd.concat([
# Reading HMMER-Tables for Heteropoda_venatoria
# Warning: Pandas parser Error, No HMMER hits in output file /home/gyk/project/spider_silkome/data/interim/automated_spidroin_annotation/nhmmer_search/Heteropoda_venatoria/hypo_CTD.tbl?
# /home/gyk/project/spider_silkome/scripts/analyse_spidroins.py:944: FutureWarning: The behavior of DataFrame concatenation with empty or all-NA entries is deprecated. In a future version, this will no longer exclude empty or all-NA columns when determining the result dtypes. To retain the old behavior, exclude the relevant entries before the concat operation.
#   summary_table = pd.concat([
# Reading HMMER-Tables for Araneus_ventricosus
# Reading HMMER-Tables for Songthela_sp
# Finished reading HMMER-Tables
# Writing summary table
# Getting HMM profile lengths
# Applying filters...
# /home/gyk/project/spider_silkome/scripts/analyse_spidroins.py:210: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   duplicates.sort_values("E-value", inplace=True)
# /home/gyk/project/spider_silkome/scripts/analyse_spidroins.py:210: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   duplicates.sort_values("E-value", inplace=True)
# /home/gyk/project/spider_silkome/scripts/analyse_spidroins.py:210: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   duplicates.sort_values("E-value", inplace=True)
# /home/gyk/project/spider_silkome/scripts/analyse_spidroins.py:210: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   duplicates.sort_values("E-value", inplace=True)
# /home/gyk/project/spider_silkome/scripts/analyse_spidroins.py:210: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   duplicates.sort_values("E-value", inplace=True)
# /home/gyk/project/spider_silkome/scripts/analyse_spidroins.py:210: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   duplicates.sort_values("E-value", inplace=True)
# /home/gyk/project/spider_silkome/scripts/analyse_spidroins.py:210: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   duplicates.sort_values("E-value", inplace=True)
# /home/gyk/project/spider_silkome/scripts/analyse_spidroins.py:210: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   duplicates.sort_values("E-value", inplace=True)
# /home/gyk/project/spider_silkome/scripts/analyse_spidroins.py:210: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   duplicates.sort_values("E-value", inplace=True)
# /home/gyk/project/spider_silkome/scripts/analyse_spidroins.py:210: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   duplicates.sort_values("E-value", inplace=True)
# /home/gyk/project/spider_silkome/scripts/analyse_spidroins.py:210: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   duplicates.sort_values("E-value", inplace=True)
# /home/gyk/project/spider_silkome/scripts/analyse_spidroins.py:210: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   duplicates.sort_values("E-value", inplace=True)
# /home/gyk/project/spider_silkome/scripts/analyse_spidroins.py:210: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   duplicates.sort_values("E-value", inplace=True)
# /home/gyk/project/spider_silkome/scripts/analyse_spidroins.py:210: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   duplicates.sort_values("E-value", inplace=True)
# /home/gyk/project/spider_silkome/scripts/analyse_spidroins.py:210: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   duplicates.sort_values("E-value", inplace=True)
# /home/gyk/project/spider_silkome/scripts/analyse_spidroins.py:210: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   duplicates.sort_values("E-value", inplace=True)
# /home/gyk/project/spider_silkome/scripts/analyse_spidroins.py:210: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   duplicates.sort_values("E-value", inplace=True)
# /home/gyk/project/spider_silkome/scripts/analyse_spidroins.py:210: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   duplicates.sort_values("E-value", inplace=True)
# /home/gyk/project/spider_silkome/scripts/analyse_spidroins.py:210: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   duplicates.sort_values("E-value", inplace=True)
# /home/gyk/project/spider_silkome/scripts/analyse_spidroins.py:210: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   duplicates.sort_values("E-value", inplace=True)
# /home/gyk/project/spider_silkome/scripts/analyse_spidroins.py:210: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   duplicates.sort_values("E-value", inplace=True)
# /home/gyk/project/spider_silkome/scripts/analyse_spidroins.py:210: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   duplicates.sort_values("E-value", inplace=True)
# /home/gyk/project/spider_silkome/scripts/analyse_spidroins.py:210: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   duplicates.sort_values("E-value", inplace=True)
# /home/gyk/project/spider_silkome/scripts/analyse_spidroins.py:210: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   duplicates.sort_values("E-value", inplace=True)
# /home/gyk/project/spider_silkome/scripts/analyse_spidroins.py:210: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   duplicates.sort_values("E-value", inplace=True)
# /home/gyk/project/spider_silkome/scripts/analyse_spidroins.py:210: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   duplicates.sort_values("E-value", inplace=True)
# /home/gyk/project/spider_silkome/scripts/analyse_spidroins.py:210: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   duplicates.sort_values("E-value", inplace=True)
# /home/gyk/project/spider_silkome/scripts/analyse_spidroins.py:210: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   duplicates.sort_values("E-value", inplace=True)
# /home/gyk/project/spider_silkome/scripts/analyse_spidroins.py:210: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   duplicates.sort_values("E-value", inplace=True)
# /home/gyk/project/spider_silkome/scripts/analyse_spidroins.py:210: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   duplicates.sort_values("E-value", inplace=True)
# /home/gyk/project/spider_silkome/scripts/analyse_spidroins.py:210: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   duplicates.sort_values("E-value", inplace=True)
# /home/gyk/project/spider_silkome/scripts/analyse_spidroins.py:210: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   duplicates.sort_values("E-value", inplace=True)
# /home/gyk/project/spider_silkome/scripts/analyse_spidroins.py:210: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   duplicates.sort_values("E-value", inplace=True)
# /home/gyk/project/spider_silkome/scripts/analyse_spidroins.py:210: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   duplicates.sort_values("E-value", inplace=True)
# /home/gyk/project/spider_silkome/scripts/analyse_spidroins.py:210: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   duplicates.sort_values("E-value", inplace=True)
# /home/gyk/project/spider_silkome/scripts/analyse_spidroins.py:210: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   duplicates.sort_values("E-value", inplace=True)
# /home/gyk/project/spider_silkome/scripts/analyse_spidroins.py:210: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   duplicates.sort_values("E-value", inplace=True)
# /home/gyk/project/spider_silkome/scripts/analyse_spidroins.py:210: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   duplicates.sort_values("E-value", inplace=True)
# /home/gyk/project/spider_silkome/scripts/analyse_spidroins.py:210: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   duplicates.sort_values("E-value", inplace=True)
# /home/gyk/project/spider_silkome/scripts/analyse_spidroins.py:210: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   duplicates.sort_values("E-value", inplace=True)
# /home/gyk/project/spider_silkome/scripts/analyse_spidroins.py:210: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   duplicates.sort_values("E-value", inplace=True)
# /home/gyk/project/spider_silkome/scripts/analyse_spidroins.py:210: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   duplicates.sort_values("E-value", inplace=True)
# /home/gyk/project/spider_silkome/scripts/analyse_spidroins.py:210: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   duplicates.sort_values("E-value", inplace=True)
# /home/gyk/project/spider_silkome/scripts/analyse_spidroins.py:210: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   duplicates.sort_values("E-value", inplace=True)
# /home/gyk/project/spider_silkome/scripts/analyse_spidroins.py:210: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   duplicates.sort_values("E-value", inplace=True)
# /home/gyk/project/spider_silkome/scripts/analyse_spidroins.py:210: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   duplicates.sort_values("E-value", inplace=True)
# /home/gyk/project/spider_silkome/scripts/analyse_spidroins.py:210: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   duplicates.sort_values("E-value", inplace=True)
# /home/gyk/project/spider_silkome/scripts/analyse_spidroins.py:210: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   duplicates.sort_values("E-value", inplace=True)
# /home/gyk/project/spider_silkome/scripts/analyse_spidroins.py:210: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   duplicates.sort_values("E-value", inplace=True)
# /home/gyk/project/spider_silkome/scripts/analyse_spidroins.py:210: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   duplicates.sort_values("E-value", inplace=True)
# /home/gyk/project/spider_silkome/scripts/analyse_spidroins.py:210: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   duplicates.sort_values("E-value", inplace=True)
# /home/gyk/project/spider_silkome/scripts/analyse_spidroins.py:210: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   duplicates.sort_values("E-value", inplace=True)
# /home/gyk/project/spider_silkome/scripts/analyse_spidroins.py:210: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   duplicates.sort_values("E-value", inplace=True)
# /home/gyk/project/spider_silkome/scripts/analyse_spidroins.py:210: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   duplicates.sort_values("E-value", inplace=True)
# /home/gyk/project/spider_silkome/scripts/analyse_spidroins.py:210: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   duplicates.sort_values("E-value", inplace=True)
# /home/gyk/project/spider_silkome/scripts/analyse_spidroins.py:210: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   duplicates.sort_values("E-value", inplace=True)
# /home/gyk/project/spider_silkome/scripts/analyse_spidroins.py:210: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   duplicates.sort_values("E-value", inplace=True)
# /home/gyk/project/spider_silkome/scripts/analyse_spidroins.py:210: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   duplicates.sort_values("E-value", inplace=True)
# /home/gyk/project/spider_silkome/scripts/analyse_spidroins.py:210: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   duplicates.sort_values("E-value", inplace=True)
# /home/gyk/project/spider_silkome/scripts/analyse_spidroins.py:210: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   duplicates.sort_values("E-value", inplace=True)
# /home/gyk/project/spider_silkome/scripts/analyse_spidroins.py:210: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   duplicates.sort_values("E-value", inplace=True)
# /home/gyk/project/spider_silkome/scripts/analyse_spidroins.py:210: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   duplicates.sort_values("E-value", inplace=True)
# /home/gyk/project/spider_silkome/scripts/analyse_spidroins.py:210: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   duplicates.sort_values("E-value", inplace=True)
# /home/gyk/project/spider_silkome/scripts/analyse_spidroins.py:210: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   duplicates.sort_values("E-value", inplace=True)
# /home/gyk/project/spider_silkome/scripts/analyse_spidroins.py:210: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   duplicates.sort_values("E-value", inplace=True)
# /home/gyk/project/spider_silkome/scripts/analyse_spidroins.py:210: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   duplicates.sort_values("E-value", inplace=True)
# /home/gyk/project/spider_silkome/scripts/analyse_spidroins.py:210: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   duplicates.sort_values("E-value", inplace=True)
# /home/gyk/project/spider_silkome/scripts/analyse_spidroins.py:210: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   duplicates.sort_values("E-value", inplace=True)
# /home/gyk/project/spider_silkome/scripts/analyse_spidroins.py:210: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   duplicates.sort_values("E-value", inplace=True)
# /home/gyk/project/spider_silkome/scripts/analyse_spidroins.py:210: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   duplicates.sort_values("E-value", inplace=True)
# /home/gyk/project/spider_silkome/scripts/analyse_spidroins.py:210: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   duplicates.sort_values("E-value", inplace=True)
# /home/gyk/project/spider_silkome/scripts/analyse_spidroins.py:210: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   duplicates.sort_values("E-value", inplace=True)
# /home/gyk/project/spider_silkome/scripts/analyse_spidroins.py:210: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   duplicates.sort_values("E-value", inplace=True)
# /home/gyk/project/spider_silkome/scripts/analyse_spidroins.py:210: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   duplicates.sort_values("E-value", inplace=True)
# /home/gyk/project/spider_silkome/scripts/analyse_spidroins.py:210: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   duplicates.sort_values("E-value", inplace=True)
# /home/gyk/project/spider_silkome/scripts/analyse_spidroins.py:210: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   duplicates.sort_values("E-value", inplace=True)
# /home/gyk/project/spider_silkome/scripts/analyse_spidroins.py:210: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   duplicates.sort_values("E-value", inplace=True)
# /home/gyk/project/spider_silkome/scripts/analyse_spidroins.py:210: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   duplicates.sort_values("E-value", inplace=True)
# /home/gyk/project/spider_silkome/scripts/analyse_spidroins.py:210: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   duplicates.sort_values("E-value", inplace=True)
# /home/gyk/project/spider_silkome/scripts/analyse_spidroins.py:210: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   duplicates.sort_values("E-value", inplace=True)
# /home/gyk/project/spider_silkome/scripts/analyse_spidroins.py:210: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   duplicates.sort_values("E-value", inplace=True)
# /home/gyk/project/spider_silkome/scripts/analyse_spidroins.py:210: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   duplicates.sort_values("E-value", inplace=True)
# /home/gyk/project/spider_silkome/scripts/analyse_spidroins.py:210: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   duplicates.sort_values("E-value", inplace=True)
# /home/gyk/project/spider_silkome/scripts/analyse_spidroins.py:210: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   duplicates.sort_values("E-value", inplace=True)
# /home/gyk/project/spider_silkome/scripts/analyse_spidroins.py:210: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   duplicates.sort_values("E-value", inplace=True)
# /home/gyk/project/spider_silkome/scripts/analyse_spidroins.py:210: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   duplicates.sort_values("E-value", inplace=True)
# /home/gyk/project/spider_silkome/scripts/analyse_spidroins.py:210: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   duplicates.sort_values("E-value", inplace=True)
# /home/gyk/project/spider_silkome/scripts/analyse_spidroins.py:210: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   duplicates.sort_values("E-value", inplace=True)
# /home/gyk/project/spider_silkome/scripts/analyse_spidroins.py:210: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   duplicates.sort_values("E-value", inplace=True)
# /home/gyk/project/spider_silkome/scripts/analyse_spidroins.py:210: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   duplicates.sort_values("E-value", inplace=True)
# /home/gyk/project/spider_silkome/scripts/analyse_spidroins.py:210: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   duplicates.sort_values("E-value", inplace=True)
# /home/gyk/project/spider_silkome/scripts/analyse_spidroins.py:210: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   duplicates.sort_values("E-value", inplace=True)
# /home/gyk/project/spider_silkome/scripts/analyse_spidroins.py:210: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   duplicates.sort_values("E-value", inplace=True)
# /home/gyk/project/spider_silkome/scripts/analyse_spidroins.py:210: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   duplicates.sort_values("E-value", inplace=True)
# /home/gyk/project/spider_silkome/scripts/analyse_spidroins.py:210: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   duplicates.sort_values("E-value", inplace=True)
# /home/gyk/project/spider_silkome/scripts/analyse_spidroins.py:210: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   duplicates.sort_values("E-value", inplace=True)
# /home/gyk/project/spider_silkome/scripts/analyse_spidroins.py:210: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   duplicates.sort_values("E-value", inplace=True)
# /home/gyk/project/spider_silkome/scripts/analyse_spidroins.py:210: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   duplicates.sort_values("E-value", inplace=True)
# /home/gyk/project/spider_silkome/scripts/analyse_spidroins.py:210: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   duplicates.sort_values("E-value", inplace=True)
# /home/gyk/project/spider_silkome/scripts/analyse_spidroins.py:210: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   duplicates.sort_values("E-value", inplace=True)
# /home/gyk/project/spider_silkome/scripts/analyse_spidroins.py:210: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   duplicates.sort_values("E-value", inplace=True)
# /home/gyk/project/spider_silkome/scripts/analyse_spidroins.py:210: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   duplicates.sort_values("E-value", inplace=True)
# /home/gyk/project/spider_silkome/scripts/analyse_spidroins.py:210: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   duplicates.sort_values("E-value", inplace=True)
# /home/gyk/project/spider_silkome/scripts/analyse_spidroins.py:210: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   duplicates.sort_values("E-value", inplace=True)
# /home/gyk/project/spider_silkome/scripts/analyse_spidroins.py:210: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   duplicates.sort_values("E-value", inplace=True)
# /home/gyk/project/spider_silkome/scripts/analyse_spidroins.py:210: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   duplicates.sort_values("E-value", inplace=True)
# /home/gyk/project/spider_silkome/scripts/analyse_spidroins.py:210: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   duplicates.sort_values("E-value", inplace=True)
# /home/gyk/project/spider_silkome/scripts/analyse_spidroins.py:210: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   duplicates.sort_values("E-value", inplace=True)
# /home/gyk/project/spider_silkome/scripts/analyse_spidroins.py:210: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   duplicates.sort_values("E-value", inplace=True)
# /home/gyk/project/spider_silkome/scripts/analyse_spidroins.py:210: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   duplicates.sort_values("E-value", inplace=True)
# /home/gyk/project/spider_silkome/scripts/analyse_spidroins.py:210: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   duplicates.sort_values("E-value", inplace=True)
# /home/gyk/project/spider_silkome/scripts/analyse_spidroins.py:210: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   duplicates.sort_values("E-value", inplace=True)
# /home/gyk/project/spider_silkome/scripts/analyse_spidroins.py:210: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   duplicates.sort_values("E-value", inplace=True)
# /home/gyk/project/spider_silkome/scripts/analyse_spidroins.py:210: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   duplicates.sort_values("E-value", inplace=True)
# ...
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   ctds["distance"] = abs(ctds["ali_from"] - ntd["ali_from"])
# /home/gyk/project/spider_silkome/scripts/analyse_spidroins.py:393: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   ctds["distance"] = abs(ctds["ali_from"] - ntd["ali_from"])
# /home/gyk/project/spider_silkome/scripts/analyse_spidroins.py:393: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   ctds["distance"] = abs(ctds["ali_from"] - ntd["ali_from"])
# /home/gyk/project/spider_silkome/scripts/analyse_spidroins.py:393: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   ctds["distance"] = abs(ctds["ali_from"] - ntd["ali_from"])
# /home/gyk/project/spider_silkome/scripts/analyse_spidroins.py:393: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   ctds["distance"] = abs(ctds["ali_from"] - ntd["ali_from"])
# /home/gyk/project/spider_silkome/scripts/analyse_spidroins.py:393: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   ctds["distance"] = abs(ctds["ali_from"] - ntd["ali_from"])
# /home/gyk/project/spider_silkome/scripts/analyse_spidroins.py:393: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   ctds["distance"] = abs(ctds["ali_from"] - ntd["ali_from"])
# /home/gyk/project/spider_silkome/scripts/analyse_spidroins.py:393: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   ctds["distance"] = abs(ctds["ali_from"] - ntd["ali_from"])
# /home/gyk/project/spider_silkome/scripts/analyse_spidroins.py:393: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   ctds["distance"] = abs(ctds["ali_from"] - ntd["ali_from"])
# /home/gyk/project/spider_silkome/scripts/analyse_spidroins.py:393: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   ctds["distance"] = abs(ctds["ali_from"] - ntd["ali_from"])
# /home/gyk/project/spider_silkome/scripts/analyse_spidroins.py:393: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   ctds["distance"] = abs(ctds["ali_from"] - ntd["ali_from"])
# /home/gyk/project/spider_silkome/scripts/analyse_spidroins.py:393: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   ctds["distance"] = abs(ctds["ali_from"] - ntd["ali_from"])
# /home/gyk/project/spider_silkome/scripts/analyse_spidroins.py:393: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   ctds["distance"] = abs(ctds["ali_from"] - ntd["ali_from"])
# /home/gyk/project/spider_silkome/scripts/analyse_spidroins.py:393: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   ctds["distance"] = abs(ctds["ali_from"] - ntd["ali_from"])
# /home/gyk/project/spider_silkome/scripts/analyse_spidroins.py:393: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   ctds["distance"] = abs(ctds["ali_from"] - ntd["ali_from"])
# /home/gyk/project/spider_silkome/scripts/analyse_spidroins.py:393: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   ctds["distance"] = abs(ctds["ali_from"] - ntd["ali_from"])
# /home/gyk/project/spider_silkome/scripts/analyse_spidroins.py:393: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   ctds["distance"] = abs(ctds["ali_from"] - ntd["ali_from"])
# /home/gyk/project/spider_silkome/scripts/analyse_spidroins.py:393: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   ctds["distance"] = abs(ctds["ali_from"] - ntd["ali_from"])
# /home/gyk/project/spider_silkome/scripts/analyse_spidroins.py:393: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   ctds["distance"] = abs(ctds["ali_from"] - ntd["ali_from"])
# /home/gyk/project/spider_silkome/scripts/analyse_spidroins.py:393: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   ctds["distance"] = abs(ctds["ali_from"] - ntd["ali_from"])
# /home/gyk/project/spider_silkome/scripts/analyse_spidroins.py:393: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   ctds["distance"] = abs(ctds["ali_from"] - ntd["ali_from"])
# /home/gyk/project/spider_silkome/scripts/analyse_spidroins.py:393: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   ctds["distance"] = abs(ctds["ali_from"] - ntd["ali_from"])
# /home/gyk/project/spider_silkome/scripts/analyse_spidroins.py:393: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   ctds["distance"] = abs(ctds["ali_from"] - ntd["ali_from"])
# /home/gyk/project/spider_silkome/scripts/analyse_spidroins.py:393: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   ctds["distance"] = abs(ctds["ali_from"] - ntd["ali_from"])
# /home/gyk/project/spider_silkome/scripts/analyse_spidroins.py:393: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   ctds["distance"] = abs(ctds["ali_from"] - ntd["ali_from"])
# /home/gyk/project/spider_silkome/scripts/analyse_spidroins.py:393: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   ctds["distance"] = abs(ctds["ali_from"] - ntd["ali_from"])
# Found 130 joined spidroin genes, 58 singletons
# Generating GFF files...
# Wrote GFF file: /home/gyk/project/spider_silkome/data/processed/automated_spidroin_annotation/spidroin_analysis/GFF/Hippasa_lycosina.gff
# Wrote GFF file: /home/gyk/project/spider_silkome/data/processed/automated_spidroin_annotation/spidroin_analysis/GFF/Pandercetes_sp.gff
# Wrote GFF file: /home/gyk/project/spider_silkome/data/processed/automated_spidroin_annotation/spidroin_analysis/GFF/Trichonephila_clavata.gff
# Wrote GFF file: /home/gyk/project/spider_silkome/data/processed/automated_spidroin_annotation/spidroin_analysis/GFF/Heteropoda_venatoria.gff
# Wrote GFF file: /home/gyk/project/spider_silkome/data/processed/automated_spidroin_annotation/spidroin_analysis/GFF/Pardosa_pseudoannulata.gff
# Wrote GFF file: /home/gyk/project/spider_silkome/data/processed/automated_spidroin_annotation/spidroin_analysis/GFF/Evarcha_sp.gff
# Wrote GFF file: /home/gyk/project/spider_silkome/data/processed/automated_spidroin_annotation/spidroin_analysis/GFF/Araneus_ventricosus.gff
# Wrote GFF file: /home/gyk/project/spider_silkome/data/processed/automated_spidroin_annotation/spidroin_analysis/GFF/Songthela_sp.gff
# Extracting spidroin sequences...
# Extracting spidroin sequences for Hippasa_lycosina
# Assembly: /home/gyk/project/spider_silkome/data/raw/spider_genome/Hippasa_lycosina/Hippasa_lycosina.fa
# Chr03: 182883559 bp
# Chr03: 182883559 bp
# Chr03: 182883559 bp
# Chr04: 180112200 bp
# Chr04: 180112200 bp
# Chr04: 180112200 bp
# Chr04: 180112200 bp
# Chr04: 180112200 bp
# Chr06: 172433735 bp
# Chr06: 172433735 bp
# Chr06: 172433735 bp
# Chr06: 172433735 bp
# Extracting spidroin sequences for Pandercetes_sp
# Assembly: /home/gyk/project/spider_silkome/data/raw/spider_genome/Pandercetes_sp/Pandercetes_sp.fa
# Chr08: 227776469 bp
# Chr13: 208702017 bp
# Chr13: 208702017 bp
# Chr13: 208702017 bp
# Chr13: 208702017 bp
# Chr15: 195731055 bp
# Chr15: 195731055 bp
# Chr15: 195731055 bp
# Chr15: 195731055 bp
# Chr15: 195731055 bp
# Chr15: 195731055 bp
# Chr15: 195731055 bp
# Chr15: 195731055 bp
# Chr15: 195731055 bp
# Chr15: 195731055 bp
# Chr15: 195731055 bp
# Chr15: 195731055 bp
# Extracting spidroin sequences for Trichonephila_clavata
# Assembly: /home/gyk/project/spider_silkome/data/raw/spider_genome/Trichonephila_clavata/Trichonephila_clavata.fa
# Chr11: 181756043 bp
# Chr11: 181756043 bp
# Chr11: 181756043 bp
# Chr3: 217459091 bp
# Chr3: 217459091 bp
# Chr4: 215825192 bp
# Chr4: 215825192 bp
# Chr4: 215825192 bp
# Chr4: 215825192 bp
# Chr4: 215825192 bp
# Chr4: 215825192 bp
# Chr4: 215825192 bp
# Chr4: 215825192 bp
# Chr4: 215825192 bp
# Chr5: 212272694 bp
# Chr5: 212272694 bp
# Chr6: 202090426 bp
# Chr6: 202090426 bp
# Chr6: 202090426 bp
# Chr6: 202090426 bp
# Chr7: 201494964 bp
# Chr7: 201494964 bp
# Chr7: 201494964 bp
# Chr7: 201494964 bp
# Chr9: 193760084 bp
# Extracting spidroin sequences for Heteropoda_venatoria
# Assembly: /home/gyk/project/spider_silkome/data/raw/spider_genome/Heteropoda_venatoria/Heteropoda_venatoria.fa
# Chr13: 243479007 bp
# Chr21: 224132315 bp
# Chr21: 224132315 bp
# Chr21: 224132315 bp
# Chr21: 224132315 bp
# Chr21: 224132315 bp
# Chr21: 224132315 bp
# Chr21: 224132315 bp
# Chr6: 260181190 bp
# Extracting spidroin sequences for Pardosa_pseudoannulata
# Assembly: /home/gyk/project/spider_silkome/data/raw/spider_genome/Pardosa_pseudoannulata/Pardosa_pseudoannulata.fa
# Ppse_Chr01: 107539213 bp
# Ppse_Chr01: 107539213 bp
# Ppse_Chr01: 107539213 bp
# Ppse_Chr01: 107539213 bp
# Ppse_Chr01: 107539213 bp
# Ppse_Chr01: 107539213 bp
# Ppse_Chr01: 107539213 bp
# Ppse_Chr09: 201653302 bp
# Ppse_Chr09: 201653302 bp
# Ppse_Chr09: 201653302 bp
# Ppse_Chr09: 201653302 bp
# Ppse_Chr15: 151860623 bp
# Ppse_Chr15: 151860623 bp
# Extracting spidroin sequences for Evarcha_sp
# Assembly: /home/gyk/project/spider_silkome/data/raw/spider_genome/Evarcha_sp/Evarcha_sp.fa
# chr03: 627780826 bp
# chr04: 563094024 bp
# chr04: 563094024 bp
# chr04: 563094024 bp
# chr08: 480024937 bp
# chr11: 380654824 bp
# chr12: 374465288 bp
# chr12: 374465288 bp
# chr12: 374465288 bp
# chr12: 374465288 bp
# chr12: 374465288 bp
# chr12: 374465288 bp
# chr12: 374465288 bp
# chr12: 374465288 bp
# chr12: 374465288 bp
# chr12: 374465288 bp
# chr12: 374465288 bp
# Extracting spidroin sequences for Araneus_ventricosus
# Assembly: /home/gyk/project/spider_silkome/data/raw/spider_genome/Araneus_ventricosus/Araneus_ventricosus.fa
# chr1: 149487999 bp
# chr11: 99491334 bp
# chr12: 88293417 bp
# chr12: 88293417 bp
# chr12: 88293417 bp
# chr12: 88293417 bp
# chr12: 88293417 bp
# chr12: 88293417 bp
# chr12: 88293417 bp
# chr12: 88293417 bp
# chr12: 88293417 bp
# chr12: 88293417 bp
# chr12: 88293417 bp
# chr18: 74867352 bp
# chr18: 74867352 bp
# chr19: 72558090 bp
# chr19: 72558090 bp
# chr3: 134173772 bp
# chr3: 134173772 bp
# chr3: 134173772 bp
# chr3: 134173772 bp
# chr3: 134173772 bp
# chr3: 134173772 bp
# chr3: 134173772 bp
# chr3: 134173772 bp
# chr3: 134173772 bp
# chr3: 134173772 bp
# chr3: 134173772 bp
# chr4: 132296718 bp
# chr6: 130339731 bp
# chr7: 126042854 bp
# chr7: 126042854 bp
# chr7: 126042854 bp
# chr8: 116123201 bp
# chr8: 116123201 bp
# chr8: 116123201 bp
# Extracting spidroin sequences for Songthela_sp
# Assembly: /home/gyk/project/spider_silkome/data/raw/spider_genome/Songthela_sp/Songthela_sp.fa
# chr20: 75865054 bp
# Analysis complete!
# 2025-12-05 13:29:10.457 | SUCCESS  | spider_silkome_module.features:run_shell_command_with_check:53 - Command executed successfully, output file: /home/gyk/project/spider_silkome/data/processed/automated_spidroin_annotation/spidroin_analysis/spidroins_total.tsv
# True

# %% [markdown]
# ## Step 2: Spidroin Gene Prediction with Augustus
#
# Extract candidate spidroin sequences and predict gene structures using Augustus.

# %%
from Bio import SeqIO
from scripts.merge_gff import parse_augustus_gff, merge_gff_files

# Input: all spider spidroin sequences from spidroin analysis (fasta file)
spidroin_fasta_path = spidroin_analysis_output / "spidroin_sequences.fasta"
if not spidroin_fasta_path.exists():
    print(f"Warning: No spidroin sequences file found")
    exit(1)

# Load all sequences into list (can iterate multiple times)
all_spidroin_sequences = list(SeqIO.parse(spidroin_fasta_path, "fasta"))

# Output directory for merged GFFs
merged_gff_dir = spidroin_analysis_output / "GFF_merged"
os.makedirs(merged_gff_dir, exist_ok=True)

# Step 2: Extract spidroin sequences and make a hints.gff for the genes prediction with Augustus
for spider in spiders:
    print(f"\n{'='*60}")
    print(f"Gene prediction for: {spider}")
    print(f"{'='*60}")

    spider_output_dir = INTERIM_DATA_DIR / project_name / spider
    os.makedirs(spider_output_dir, exist_ok=True)
    candidate_gene_seq = spider_output_dir / "spidroin_seqs.fa"
    hints_gff = spider_output_dir / "hints.gff"

    # Filter sequences for current spider
    spider_records = [r for r in all_spidroin_sequences if r.id.startswith(spider)]

    if not spider_records:
        print(f"No spidroin sequences found for {spider}, skipping...")
        continue

    # Write all sequences for this spider at once
    SeqIO.write(spider_records, candidate_gene_seq, "fasta")

    with open(hints_gff, "w") as file:
        for record in spider_records:
            seqname = record.id
            start_hints = f"{seqname}\tmanual\tstart\t1\t3\t.\t+\t0\tgrp=1;pri=4;src=M"
            stop_hints = f"{seqname}\tmanual\tstop\t{len(record.seq)-2}\t{len(record.seq)}\t.\t+\t0\tgrp=1;pri=4;src=M"
            file.write(start_hints + "\n")
            file.write(stop_hints + "\n")

    # Run Augustus for gene prediction
    augustus_output = spider_output_dir / "augustus_output.gff"
    augustus_cmd = f"pixi run augustus --strand=forward --singlestrand=true \
        --extrinsicCfgFile={augustus_config_file} \
        --alternatives-from-evidence=true --gff3=on --uniqueGeneId=true \
        --genemodel=exactlyone --hintsfile={hints_gff} \
        --UTR=off --species=parasteatoda {candidate_gene_seq} > {augustus_output}"

    run_shell_command_with_check(augustus_cmd, augustus_output)
    print(f"Completed gene prediction for: {spider}")

    # Merge GFF files
    original_gff = spidroin_analysis_output / "GFF" / f"{spider}.gff"
    merged_gff = merged_gff_dir / f"{spider}.gff"
    augustus_preds = parse_augustus_gff(augustus_output)
    merge_gff_files(original_gff, augustus_preds, merged_gff)

print(f"\nAll merged GFF files saved to: {merged_gff_dir}")

# %% [markdown]
# ## Reapeat analysis

# %%
# Protein sequence extraction and visualization
for spider in spiders:
    spider_output_dir = INTERIM_DATA_DIR / project_name / spider
    augustus_output = spider_output_dir / "augustus_output.gff"
    candidate_gene_seq = spider_output_dir / "spidroin_seqs.fa"
    # Extract protein sequences using getAnnoFasta.pl
    protein_extraction_cmd = f"pixi run getAnnoFasta.pl --seqfile={candidate_gene_seq} {augustus_output}"
    print(protein_extraction_cmd)
    run_shell_command_with_check(protein_extraction_cmd, augustus_output.with_suffix('.aa'))
