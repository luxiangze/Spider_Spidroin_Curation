# %% [markdown]
# # HMMER search for all spider genomes using hmm profile

# %%
from spider_silkome_module import (
    RAW_DATA_DIR,
    INTERIM_DATA_DIR,
    PROCESSED_DATA_DIR,
    REFERENCES_DIR,
)
from spider_silkome_module import run_cmd
# Out:
# 2026-05-18 10:21:35.467 | INFO     | spider_silkome_module.config:<module>:11 - PROJ_ROOT path is: /home/gyk/projects/Spider_Spidroin_Curation

# %% [markdown]
# ## Configuration

# %%
task_name = "hmmer_search_20260518"

spider_genome_dir = RAW_DATA_DIR / "001-134spd"

# hmmer_search
hmmer_model_dir = REFERENCES_DIR / "2025_Schoneberg_data" / "hmmer_nucl_profile_trimmed"
nhmmer_search_output = INTERIM_DATA_DIR / task_name / "nhmmer_search"

# parse_hmmer_search_results
parse_nhmmer_search_results_output = PROCESSED_DATA_DIR / task_name / "nhmmer_search_parsed"

# %% [markdown]
# ## Hmmer search

# %%
run_cmd(
    f"pixi run python -m spider_silkome_module.run_nhmmer \
        --genome-path {spider_genome_dir} \
        --hmm-dir {hmmer_model_dir} \
        --output-path {nhmmer_search_output} \
        --threads 200 --force",
    [nhmmer_search_output],force=True
)
# Out:
# 2026-05-18 17:21:13.255 | INFO     | spider_silkome_module.config:<module>:11 - PROJ_ROOT path is: /home/gyk/projects/Spider_Spidroin_Curation
# Pressing HMM models:  31%|███▏      | 10/32 [00:00<00:00, 99.73it/s]
# 2026-05-18 17:21:13.285 | INFO     | __main__:main:143 - Genome path: /home/gyk/projects/Spider_Spidroin_Curation/data/raw/001-134spd
# 2026-05-18 17:21:13.286 | INFO     | __main__:main:144 - HMM directory: /home/gyk/projects/Spider_Spidroin_Curation/references/2025_Schoneberg_data/hmmer_nucl_profile_trimmed
# 2026-05-18 17:21:13.286 | INFO     | __main__:main:145 - Output path: /home/gyk/projects/Spider_Spidroin_Curation/data/interim/hmmer_search_20260518/nhmmer_search
# 2026-05-18 17:21:13.286 | INFO     | __main__:main:148 - Pressing HMM models...
# 2026-05-18 17:21:13.287 | INFO     | __main__:press_hmm_models:93 - Found 32 HMM models to press
# Working...    done.
# Pressed and indexed 1 HMMs (1 names).
# Models pressed into binary file:   /home/gyk/projects/Spider_Spidroin_Curation/references/2025_Schoneberg_data/hmmer_nucl_profile_trimmed/MiSp_NTD.hmm.h3m
# SSI index for binary model file:   /home/gyk/projects/Spider_Spidroin_Curation/references/2025_Schoneberg_data/hmmer_nucl_profile_trimmed/MiSp_NTD.hmm.h3i
# Profiles (MSV part) pressed into:  /home/gyk/projects/Spider_Spidroin_Curation/references/2025_Schoneberg_data/hmmer_nucl_profile_trimmed/MiSp_NTD.hmm.h3f
# Profiles (remainder) pressed into: /home/gyk/projects/Spider_Spidroin_Curation/references/2025_Schoneberg_data/hmmer_nucl_profile_trimmed/MiSp_NTD.hmm.h3p
# Working...    done.
# Pressed and indexed 1 HMMs (1 names).
# Models pressed into binary file:   /home/gyk/projects/Spider_Spidroin_Curation/references/2025_Schoneberg_data/hmmer_nucl_profile_trimmed/Flag_NTD.hmm.h3m
# SSI index for binary model file:   /home/gyk/projects/Spider_Spidroin_Curation/references/2025_Schoneberg_data/hmmer_nucl_profile_trimmed/Flag_NTD.hmm.h3i
# Profiles (MSV part) pressed into:  /home/gyk/projects/Spider_Spidroin_Curation/references/2025_Schoneberg_data/hmmer_nucl_profile_trimmed/Flag_NTD.hmm.h3f
# Profiles (remainder) pressed into: /home/gyk/projects/Spider_Spidroin_Curation/references/2025_Schoneberg_data/hmmer_nucl_profile_trimmed/Flag_NTD.hmm.h3p
# Working...    done.
# Pressed and indexed 1 HMMs (1 names).
# Models pressed into binary file:   /home/gyk/projects/Spider_Spidroin_Curation/references/2025_Schoneberg_data/hmmer_nucl_profile_trimmed/MaSp_NTD.hmm.h3m
# SSI index for binary model file:   /home/gyk/projects/Spider_Spidroin_Curation/references/2025_Schoneberg_data/hmmer_nucl_profile_trimmed/MaSp_NTD.hmm.h3i
# Profiles (MSV part) pressed into:  /home/gyk/projects/Spider_Spidroin_Curation/references/2025_Schoneberg_data/hmmer_nucl_profile_trimmed/MaSp_NTD.hmm.h3f
# Profiles (remainder) pressed into: /home/gyk/projects/Spider_Spidroin_Curation/references/2025_Schoneberg_data/hmmer_nucl_profile_trimmed/MaSp_NTD.hmm.h3p
# Working...    done.
# Pressed and indexed 1 HMMs (1 names).
# Models pressed into binary file:   /home/gyk/projects/Spider_Spidroin_Curation/references/2025_Schoneberg_data/hmmer_nucl_profile_trimmed/AcSp_NTD.hmm.h3m
# SSI index for binary model file:   /home/gyk/projects/Spider_Spidroin_Curation/references/2025_Schoneberg_data/hmmer_nucl_profile_trimmed/AcSp_NTD.hmm.h3i
# Profiles (MSV part) pressed into:  /home/gyk/projects/Spider_Spidroin_Curation/references/2025_Schoneberg_data/hmmer_nucl_profile_trimmed/AcSp_NTD.hmm.h3f
# Profiles (remainder) pressed into: /home/gyk/projects/Spider_Spidroin_Curation/references/2025_Schoneberg_data/hmmer_nucl_profile_trimmed/AcSp_NTD.hmm.h3p
# Working...    done.
# Pressed and indexed 1 HMMs (1 names).
# Models pressed into binary file:   /home/gyk/projects/Spider_Spidroin_Curation/references/2025_Schoneberg_data/hmmer_nucl_profile_trimmed/PySp_NTD.hmm.h3m
# SSI index for binary model file:   /home/gyk/projects/Spider_Spidroin_Curation/references/2025_Schoneberg_data/hmmer_nucl_profile_trimmed/PySp_NTD.hmm.h3i
# Profiles (MSV part) pressed into:  /home/gyk/projects/Spider_Spidroin_Curation/references/2025_Schoneberg_data/hmmer_nucl_profile_trimmed/PySp_NTD.hmm.h3f
# Profiles (remainder) pressed into: /home/gyk/projects/Spider_Spidroin_Curation/references/2025_Schoneberg_data/hmmer_nucl_profile_trimmed/PySp_NTD.hmm.h3p
# Working...    done.
# Pressed and indexed 1 HMMs (1 names).
# Models pressed into binary file:   /home/gyk/projects/Spider_Spidroin_Curation/references/2025_Schoneberg_data/hmmer_nucl_profile_trimmed/CySp_CTD.hmm.h3m
# SSI index for binary model file:   /home/gyk/projects/Spider_Spidroin_Curation/references/2025_Schoneberg_data/hmmer_nucl_profile_trimmed/CySp_CTD.hmm.h3i
# Profiles (MSV part) pressed into:  /home/gyk/projects/Spider_Spidroin_Curation/references/2025_Schoneberg_data/hmmer_nucl_profile_trimmed/CySp_CTD.hmm.h3f
# Profiles (remainder) pressed into: /home/gyk/projects/Spider_Spidroin_Curation/references/2025_Schoneberg_data/hmmer_nucl_profile_trimmed/CySp_CTD.hmm.h3p
# Working...    done.
# Pressed and indexed 1 HMMs (1 names).
# Models pressed into binary file:   /home/gyk/projects/Spider_Spidroin_Curation/references/2025_Schoneberg_data/hmmer_nucl_profile_trimmed/MaSp3_CTD.hmm.h3m
# SSI index for binary model file:   /home/gyk/projects/Spider_Spidroin_Curation/references/2025_Schoneberg_data/hmmer_nucl_profile_trimmed/MaSp3_CTD.hmm.h3i
# Profiles (MSV part) pressed into:  /home/gyk/projects/Spider_Spidroin_Curation/references/2025_Schoneberg_data/hmmer_nucl_profile_trimmed/MaSp3_CTD.hmm.h3f
# Profiles (remainder) pressed into: /home/gyk/projects/Spider_Spidroin_Curation/references/2025_Schoneberg_data/hmmer_nucl_profile_trimmed/MaSp3_CTD.hmm.h3p
# Working...    done.
# Pressed and indexed 1 HMMs (1 names).
# Models pressed into binary file:   /home/gyk/projects/Spider_Spidroin_Curation/references/2025_Schoneberg_data/hmmer_nucl_profile_trimmed/AgSp2_NTD.hmm.h3m
# SSI index for binary model file:   /home/gyk/projects/Spider_Spidroin_Curation/references/2025_Schoneberg_data/hmmer_nucl_profile_trimmed/AgSp2_NTD.hmm.h3i
# Profiles (MSV part) pressed into:  /home/gyk/projects/Spider_Spidroin_Curation/references/2025_Schoneberg_data/hmmer_nucl_profile_trimmed/AgSp2_NTD.hmm.h3f
# Profiles (remainder) pressed into: /home/gyk/projects/Spider_Spidroin_Curation/references/2025_Schoneberg_data/hmmer_nucl_profile_trimmed/AgSp2_NTD.hmm.h3p
# Working...    done.
# Pressed and indexed 1 HMMs (1 names).
# Models pressed into binary file:   /home/gyk/projects/Spider_Spidroin_Curation/references/2025_Schoneberg_data/hmmer_nucl_profile_trimmed/MaSp_CTD.hmm.h3m
# SSI index for binary model file:   /home/gyk/projects/Spider_Spidroin_Curation/references/2025_Schoneberg_data/hmmer_nucl_profile_trimmed/MaSp_CTD.hmm.h3i
# Profiles (MSV part) pressed into:  /home/gyk/projects/Spider_Spidroin_Curation/references/2025_Schoneberg_data/hmmer_nucl_profile_trimmed/MaSp_CTD.hmm.h3f
# Profiles (remainder) pressed into: /home/gyk/projects/Spider_Spidroin_Curation/references/2025_Schoneberg_data/hmmer_nucl_profile_trimmed/MaSp_CTD.hmm.h3p
# Working...    done.
# Pressed and indexed 1 HMMs (1 names).
# Models pressed into binary file:   /home/gyk/projects/Spider_Spidroin_Curation/references/2025_Schoneberg_data/hmmer_nucl_profile_trimmed/AcSp_CTD.hmm.h3m
# SSI index for binary model file:   /home/gyk/projects/Spider_Spidroin_Curation/references/2025_Schoneberg_data/hmmer_nucl_profile_trimmed/AcSp_CTD.hmm.h3i
# Profiles (MSV part) pressed into:  /home/gyk/projects/Spider_Spidroin_Curation/references/2025_Schoneberg_data/hmmer_nucl_profile_trimmed/AcSp_CTD.hmm.h3f
# Profiles (remainder) pressed into: /home/gyk/projects/Spider_Spidroin_Curation/references/2025_Schoneberg_data/hmmer_nucl_profile_trimmed/AcSp_CTD.hmm.h3p
# Working...    done.
# Pressed and indexed 1 HMMs (1 names).
# Models pressed into binary file:   /home/gyk/projects/Spider_Spidroin_Curation/references/2025_Schoneberg_data/hmmer_nucl_profile_trimmed/MaSp1_NTD.hmm.h3m
# SSI index for binary model file:   /home/gyk/projects/Spider_Spidroin_Curation/references/2025_Schoneberg_data/hmmer_nucl_profile_trimmed/MaSp1_NTD.hmm.h3i
# Profiles (MSV part) pressed into:  /home/gyk/projects/Spider_Spidroin_Curation/references/2025_Schoneberg_data/hmmer_nucl_profile_trimmed/MaSp1_NTD.hmm.h3f
# Profiles (remainder) pressed into: /home/gyk/projects/Spider_Spidroin_Curation/references/2025_Schoneberg_data/hmmer_nucl_profile_trimmed/MaSp1_NTD.hmm.h3p
# Working...    done.
# Pressed and indexed 1 HMMs (1 names).
# Models pressed into binary file:   /home/gyk/projects/Spider_Spidroin_Curation/references/2025_Schoneberg_data/hmmer_nucl_profile_trimmed/Spidroin_NTD.hmm.h3m
# SSI index for binary model file:   /home/gyk/projects/Spider_Spidroin_Curation/references/2025_Schoneberg_data/hmmer_nucl_profile_trimmed/Spidroin_NTD.hmm.h3i
# Profiles (MSV part) pressed into:  /home/gyk/projects/Spider_Spidroin_Curation/references/2025_Schoneberg_data/hmmer_nucl_profile_trimmed/Spidroin_NTD.hmm.h3f
# Profiles (remainder) pressed into: /home/gyk/projects/Spider_Spidroin_Curation/references/2025_Schoneberg_data/hmmer_nucl_profile_trimmed/Spidroin_NTD.hmm.h3p
# Working...    done.
# Pressed and indexed 1 HMMs (1 names).
# Models pressed into binary file:   /home/gyk/projects/Spider_Spidroin_Curation/references/2025_Schoneberg_data/hmmer_nucl_profile_trimmed/MaSp2B_NTD.hmm.h3m
# SSI index for binary model file:   /home/gyk/projects/Spider_Spidroin_Curation/references/2025_Schoneberg_data/hmmer_nucl_profile_trimmed/MaSp2B_NTD.hmm.h3i
# Profiles (MSV part) pressed into:  /home/gyk/projects/Spider_Spidroin_Curation/references/2025_Schoneberg_data/hmmer_nucl_profile_trimmed/MaSp2B_NTD.hmm.h3f
# Profiles (remainder) pressed into: /home/gyk/projects/Spider_Spidroin_Curation/references/2025_Schoneberg_data/hmmer_nucl_profile_trimmed/MaSp2B_NTD.hmm.h3p
# Working...    done.
# Pressed and indexed 1 HMMs (1 names).
# Models pressed into binary file:   /home/gyk/projects/Spider_Spidroin_Curation/references/2025_Schoneberg_data/hmmer_nucl_profile_trimmed/AgSp1_NTD.hmm.h3m
# SSI index for binary model file:   /home/gyk/projects/Spider_Spidroin_Curation/references/2025_Schoneberg_data/hmmer_nucl_profile_trimmed/AgSp1_NTD.hmm.h3i
# Profiles (MSV part) pressed into:  /home/gyk/projects/Spider_Spidroin_Curation/references/2025_Schoneberg_data/hmmer_nucl_profile_trimmed/AgSp1_NTD.hmm.h3f
# Profiles (remainder) pressed into: /home/gyk/projects/Spider_Spidroin_Curation/references/2025_Schoneberg_data/hmmer_nucl_profile_trimmed/AgSp1_NTD.hmm.h3p
# Working...    done.
# Pressed and indexed 1 HMMs (1 names).
# Models pressed into binary file:   /home/gyk/projects/Spider_Spidroin_Curation/references/2025_Schoneberg_data/hmmer_nucl_profile_trimmed/AgSp1_CTD.hmm.h3m
# SSI index for binary model file:   /home/gyk/projects/Spider_Spidroin_Curation/references/2025_Schoneberg_data/hmmer_nucl_profile_trimmed/AgSp1_CTD.hmm.h3i
# Profiles (MSV part) pressed into:  /home/gyk/projects/Spider_Spidroin_Curation/references/2025_Schoneberg_data/hmmer_nucl_profile_trimmed/AgSp1_CTD.hmm.h3f
# Profiles (remainder) pressed into: /home/gyk/projects/Spider_Spidroin_Curation/references/2025_Schoneberg_data/hmmer_nucl_profile_trimmed/AgSp1_CTD.hmm.h3p
# Working...    done.
# Pressed and indexed 1 HMMs (1 names).
# Models pressed into binary file:   /home/gyk/projects/Spider_Spidroin_Curation/references/2025_Schoneberg_data/hmmer_nucl_profile_trimmed/MaSp3B_NTD.hmm.h3m
# SSI index for binary model file:   /home/gyk/projects/Spider_Spidroin_Curation/references/2025_Schoneberg_data/hmmer_nucl_profile_trimmed/MaSp3B_NTD.hmm.h3i
# Profiles (MSV part) pressed into:  /home/gyk/projects/Spider_Spidroin_Curation/references/2025_Schoneberg_data/hmmer_nucl_profile_trimmed/MaSp3B_NTD.hmm.h3f
# Profiles (remainder) pressed into: /home/gyk/projects/Spider_Spidroin_Curation/references/2025_Schoneberg_data/hmmer_nucl_profile_trimmed/MaSp3B_NTD.hmm.h3p
# Working...    done.
# Pressed and indexed 1 HMMs (1 names).
# Models pressed into binary file:   /home/gyk/projects/Spider_Spidroin_Curation/references/2025_Schoneberg_data/hmmer_nucl_profile_trimmed/Pflag_NTD.hmm.h3m
# SSI index for binary model file:   /home/gyk/projects/Spider_Spidroin_Curation/references/2025_Schoneberg_data/hmmer_nucl_profile_trimmed/Pflag_NTD.hmm.h3i
# Profiles (MSV part) pressed into:  /home/gyk/projects/Spider_Spidroin_Curation/references/2025_Schoneberg_data/hmmer_nucl_profile_trimmed/Pflag_NTD.hmm.h3f
# Profiles (remainder) pressed into: /home/gyk/projects/Spider_Spidroin_Curation/references/2025_Schoneberg_data/hmmer_nucl_profile_trimmed/Pflag_NTD.hmm.h3p
# Working...    done.
# Pressed and indexed 1 HMMs (1 names).
# Models pressed into binary file:   /home/gyk/projects/Spider_Spidroin_Curation/references/2025_Schoneberg_data/hmmer_nucl_profile_trimmed/MaSp3B_CTD.hmm.h3m
# SSI index for binary model file:   /home/gyk/projects/Spider_Spidroin_Curation/references/2025_Schoneberg_data/hmmer_nucl_profile_trimmed/MaSp3B_CTD.hmm.h3i
# Profiles (MSV part) pressed into:  /home/gyk/projects/Spider_Spidroin_Curation/references/2025_Schoneberg_data/hmmer_nucl_profile_trimmed/MaSp3B_CTD.hmm.h3f
# Profiles (remainder) pressed into: /home/gyk/projects/Spider_Spidroin_Curation/references/2025_Schoneberg_data/hmmer_nucl_profile_trimmed/MaSp3B_CTD.hmm.h3p
# Working...    done.
# Pressed and indexed 1 HMMs (1 names).
# Models pressed into binary file:   /home/gyk/projects/Spider_Spidroin_Curation/references/2025_Schoneberg_data/hmmer_nucl_profile_trimmed/AgSp2_CTD.hmm.h3m
# SSI index for binary model file:   /home/gyk/projects/Spider_Spidroin_Curation/references/2025_Schoneberg_data/hmmer_nucl_profile_trimmed/AgSp2_CTD.hmm.h3i
# Profiles (MSV part) pressed into:  /home/gyk/projects/Spider_Spidroin_Curation/references/2025_Schoneberg_data/hmmer_nucl_profile_trimmed/AgSp2_CTD.hmm.h3f
# Profiles (remainder) pressed into: /home/gyk/projects/Spider_Spidroin_Curation/references/2025_Schoneberg_data/hmmer_nucl_profile_trimmed/AgSp2_CTD.hmm.h3p
# Working...    done.
# Pressed and indexed 1 HMMs (1 names).
# Models pressed into binary file:   /home/gyk/projects/Spider_Spidroin_Curation/references/2025_Schoneberg_data/hmmer_nucl_profile_trimmed/Spidroin_CTD.hmm.h3m
# SSI index for binary model file:   /home/gyk/projects/Spider_Spidroin_Curation/references/2025_Schoneberg_data/hmmer_nucl_profile_trimmed/Spidroin_CTD.hmm.h3i
# Profiles (MSV part) pressed into:  /home/gyk/projects/Spider_Spidroin_Curation/references/2025_Schoneberg_data/hmmer_nucl_profile_trimmed/Spidroin_CTD.hmm.h3f
# Profiles (remainder) pressed into: /home/gyk/projects/Spider_Spidroin_Curation/references/2025_Schoneberg_data/hmmer_nucl_profile_trimmed/Spidroin_CTD.hmm.h3p
# Working...    done.
# Pressed and indexed 1 HMMs (1 names).
# Models pressed into binary file:   /home/gyk/projects/Spider_Spidroin_Curation/references/2025_Schoneberg_data/hmmer_nucl_profile_trimmed/Pflag_CTD.hmm.h3m
# SSI index for binary model file:   /home/gyk/projects/Spider_Spidroin_Curation/references/2025_Schoneberg_data/hmmer_nucl_profile_trimmed/Pflag_CTD.hmm.h3i
# Profiles (MSV part) pressed into:  /home/gyk/projects/Spider_Spidroin_Curation/references/2025_Schoneberg_data/hmmer_nucl_profile_trimmed/Pflag_CTD.hmm.h3f
# Profiles (remainder) pressed into: /home/gyk/projects/Spider_Spidroin_Curation/references/2025_Schoneberg_data/hmmer_nucl_profile_trimmed/Pflag_CTD.hmm.h3p
# Working...    done.
# Pressed and indexed 1 HMMs (1 names).
# Models pressed into binary file:   /home/gyk/projects/Spider_Spidroin_Curation/references/2025_Schoneberg_data/hmmer_nucl_profile_trimmed/MaSp3_NTD.hmm.h3m
# SSI index for binary model file:   /home/gyk/projects/Spider_Spidroin_Curation/references/2025_Schoneberg_data/hmmer_nucl_profile_trimmed/MaSp3_NTD.hmm.h3i
# Profiles (MSV part) pressed into:  /home/gyk/projects/Spider_Spidroin_Curation/references/2025_Schoneberg_data/hmmer_nucl_profile_trimmed/MaSp3_NTD.hmm.h3f
# Profiles (remainder) pressed into: /home/gyk/projects/Spider_Spidroin_Curation/references/2025_Schoneberg_data/hmmer_nucl_profile_trimmed/MaSp3_NTD.hmm.h3p
# Working...    done.
# Pressed and indexed 1 HMMs (1 names).
# Models pressed into binary file:   /home/gyk/projects/Spider_Spidroin_Curation/references/2025_Schoneberg_data/hmmer_nucl_profile_trimmed/PySp_CTD.hmm.h3m
# SSI index for binary model file:   /home/gyk/projects/Spider_Spidroin_Curation/references/2025_Schoneberg_data/hmmer_nucl_profile_trimmed/PySp_CTD.hmm.h3i
# Profiles (MSV part) pressed into:  /home/gyk/projects/Spider_Spidroin_Curation/references/2025_Schoneberg_data/hmmer_nucl_profile_trimmed/PySp_CTD.hmm.h3f
# Profiles (remainder) pressed into: /home/gyk/projects/Spider_Spidroin_Curation/references/2025_Schoneberg_data/hmmer_nucl_profile_trimmed/PySp_CTD.hmm.h3p
# Working...    done.
# Pressed and indexed 1 HMMs (1 names).
# Models pressed into binary file:   /home/gyk/projects/Spider_Spidroin_Curation/references/2025_Schoneberg_data/hmmer_nucl_profile_trimmed/hypo_CTD.hmm.h3m
# SSI index for binary model file:   /home/gyk/projects/Spider_Spidroin_Curation/references/2025_Schoneberg_data/hmmer_nucl_profile_trimmed/hypo_CTD.hmm.h3i
# Profiles (MSV part) pressed into:  /home/gyk/projects/Spider_Spidroin_Curation/references/2025_Schoneberg_data/hmmer_nucl_profile_trimmed/hypo_CTD.hmm.h3f
# Profiles (remainder) pressed into: /home/gyk/projects/Spider_Spidroin_Curation/references/2025_Schoneberg_data/hmmer_nucl_profile_trimmed/hypo_CTD.hmm.h3p
# Working...    done.
# Pressed and indexed 1 HMMs (1 names).
# Models pressed into binary file:   /home/gyk/projects/Spider_Spidroin_Curation/references/2025_Schoneberg_data/hmmer_nucl_profile_trimmed/MaSp1_CTD.hmm.h3m
# SSI index for binary model file:   /home/gyk/projects/Spider_Spidroin_Curation/references/2025_Schoneberg_data/hmmer_nucl_profile_trimmed/MaSp1_CTD.hmm.h3i
# Profiles (MSV part) pressed into:  /home/gyk/projects/Spider_Spidroin_Curation/references/2025_Schoneberg_data/hmmer_nucl_profile_trimmed/MaSp1_CTD.hmm.h3f
# Profiles (remainder) pressed into: /home/gyk/projects/Spider_Spidroin_Curation/references/2025_Schoneberg_data/hmmer_nucl_profile_trimmed/MaSp1_CTD.hmm.h3p
# Working...    done.
# Pressed and indexed 1 HMMs (1 names).
# Models pressed into binary file:   /home/gyk/projects/Spider_Spidroin_Curation/references/2025_Schoneberg_data/hmmer_nucl_profile_trimmed/CrSp_CTD.hmm.h3m
# SSI index for binary model file:   /home/gyk/projects/Spider_Spidroin_Curation/references/2025_Schoneberg_data/hmmer_nucl_profile_trimmed/CrSp_CTD.hmm.h3i
# Profiles (MSV part) pressed into:  /home/gyk/projects/Spider_Spidroin_Curation/references/2025_Schoneberg_data/hmmer_nucl_profile_trimmed/CrSp_CTD.hmm.h3f
# Profiles (remainder) pressed into: /home/gyk/projects/Spider_Spidroin_Curation/references/2025_Schoneberg_data/hmmer_nucl_profile_trimmed/CrSp_CTD.hmm.h3p
# Working...    done.
# Pressed and indexed 1 HMMs (1 names).
# Models pressed into binary file:   /home/gyk/projects/Spider_Spidroin_Curation/references/2025_Schoneberg_data/hmmer_nucl_profile_trimmed/MaSp2B_CTD.hmm.h3m
# SSI index for binary model file:   /home/gyk/projects/Spider_Spidroin_Curation/references/2025_Schoneberg_data/hmmer_nucl_profile_trimmed/MaSp2B_CTD.hmm.h3i
# Profiles (MSV part) pressed into:  /home/gyk/projects/Spider_Spidroin_Curation/references/2025_Schoneberg_data/hmmer_nucl_profile_trimmed/MaSp2B_CTD.hmm.h3f
# Profiles (remainder) pressed into: /home/gyk/projects/Spider_Spidroin_Curation/references/2025_Schoneberg_data/hmmer_nucl_profile_trimmed/MaSp2B_CTD.hmm.h3p
# Working...    done.
# Pressed and indexed 1 HMMs (1 names).
# Models pressed into binary file:   /home/gyk/projects/Spider_Spidroin_Curation/references/2025_Schoneberg_data/hmmer_nucl_profile_trimmed/MaSp2_CTD.hmm.h3m
# SSI index for binary model file:   /home/gyk/projects/Spider_Spidroin_Curation/references/2025_Schoneberg_data/hmmer_nucl_profile_trimmed/MaSp2_CTD.hmm.h3i
# Profiles (MSV part) pressed into:  /home/gyk/projects/Spider_Spidroin_Curation/references/2025_Schoneberg_data/hmmer_nucl_profile_trimmed/MaSp2_CTD.hmm.h3f
# Profiles (remainder) pressed into: /home/gyk/projects/Spider_Spidroin_Curation/references/2025_Schoneberg_data/hmmer_nucl_profile_trimmed/MaSp2_CTD.hmm.h3p
# Working...    done.
# Pressed and indexed 1 HMMs (1 names).
# Models pressed into binary file:   /home/gyk/projects/Spider_Spidroin_Curation/references/2025_Schoneberg_data/hmmer_nucl_profile_trimmed/MaSp2_NTD.hmm.h3m
# SSI index for binary model file:   /home/gyk/projects/Spider_Spidroin_Curation/references/2025_Schoneberg_data/hmmer_nucl_profile_trimmed/MaSp2_NTD.hmm.h3i
# Profiles (MSV part) pressed into:  /home/gyk/projects/Spider_Spidroin_Curation/references/2025_Schoneberg_data/hmmer_nucl_profile_trimmed/MaSp2_NTD.hmm.h3f
# Profiles (remainder) pressed into: /home/gyk/projects/Spider_Spidroin_Curation/references/2025_Schoneberg_data/hmmer_nucl_profile_trimmed/MaSp2_NTD.hmm.h3p
# Working...    done.
# Pressed and indexed 1 HMMs (1 names).
# Models pressed into binary file:   /home/gyk/projects/Spider_Spidroin_Curation/references/2025_Schoneberg_data/hmmer_nucl_profile_trimmed/MiSp_CTD.hmm.h3m
# SSI index for binary model file:   /home/gyk/projects/Spider_Spidroin_Curation/references/2025_Schoneberg_data/hmmer_nucl_profile_trimmed/MiSp_CTD.hmm.h3i
# Profiles (MSV part) pressed into:  /home/gyk/projects/Spider_Spidroin_Curation/references/2025_Schoneberg_data/hmmer_nucl_profile_trimmed/MiSp_CTD.hmm.h3f
# Profiles (remainder) pressed into: /home/gyk/projects/Spider_Spidroin_Curation/references/2025_Schoneberg_data/hmmer_nucl_profile_trimmed/MiSp_CTD.hmm.h3p
# Working...    done.
# Pressed and indexed 1 HMMs (1 names).
# Models pressed into binary file:   /home/gyk/projects/Spider_Spidroin_Curation/references/2025_Schoneberg_data/hmmer_nucl_profile_trimmed/Flag_CTD.hmm.h3m
# SSI index for binary model file:   /home/gyk/projects/Spider_Spidroin_Curation/references/2025_Schoneberg_data/hmmer_nucl_profile_trimmed/Flag_CTD.hmm.h3i
# Profiles (MSV part) pressed into:  /home/gyk/projects/Spider_Spidroin_Curation/references/2025_Schoneberg_data/hmmer_nucl_profile_trimmed/Flag_CTD.hmm.h3f
# Profiles (remainder) pressed into: /home/gyk/projects/Spider_Spidroin_Curation/references/2025_Schoneberg_data/hmmer_nucl_profile_trimmed/Flag_CTD.hmm.h3p
# Working...    done.
# Pressed and indexed 1 HMMs (1 names).
# Models pressed into binary file:   /home/gyk/projects/Spider_Spidroin_Curation/references/2025_Schoneberg_data/hmmer_nucl_profile_trimmed/CySp_NTD.hmm.h3m
# SSI index for binary model file:   /home/gyk/projects/Spider_Spidroin_Curation/references/2025_Schoneberg_data/hmmer_nucl_profile_trimmed/CySp_NTD.hmm.h3i
# Profiles (MSV part) pressed into:  /home/gyk/projects/Spider_Spidroin_Curation/references/2025_Schoneberg_data/hmmer_nucl_profile_trimmed/CySp_NTD.hmm.h3f
# Profiles (remainder) pressed into: /home/gyk/projects/Spider_Spidroin_Curation/references/2025_Schoneberg_data/hmmer_nucl_profile_trimmed/CySp_NTD.hmm.h3p
# 2026-05-18 17:21:13.641 | INFO     | __main__:main:156 - Found 133 genome(s) to process
# 2026-05-18 17:21:13.641 | INFO     | __main__:main:159 - Found 32 HMM models
# 2026-05-18 17:21:13.642 | INFO     | __main__:main:164 - Processing Allagelena_difficilis: /home/gyk/projects/Spider_Spidroin_Curation/data/raw/001-134spd/001.Allagelena_difficilis/genome.softmasked.fa.gz
# Pressing HMM models: 100%|██████████| 32/32 [00:00<00:00, 98.75it/s]
# Processing genomes:   1%|          | 1/133 [34:15<75:22:47, 2055.82s/it]
# 2026-05-18 17:55:29.459 | INFO     | __main__:main:172 - Completed: Allagelena_difficilis
# 2026-05-18 17:55:29.460 | INFO     | __main__:main:164 - Processing Anyphaena_bomiensis: /home/gyk/projects/Spider_Spidroin_Curation/data/raw/001-134spd/002.Anyphaena_bomiensis/genome.softmasked.fa.gz
# 2026-05-18 18:10:02.747 | INFO     | __main__:main:172 - Completed: Anyphaena_bomiensis
# 2026-05-18 18:10:02.748 | INFO     | __main__:main:164 - Processing Atypus_heterothecus: /home/gyk/projects/Spider_Spidroin_Curation/data/raw/001-134spd/003.Atypus_heterothecus/genome.softmasked.fa.gz
# Processing genomes:   2%|▏         | 3/133 [56:51<34:38:10, 959.16s/it]
# 2026-05-18 18:18:04.651 | INFO     | __main__:main:172 - Completed: Atypus_heterothecus
# 2026-05-18 18:18:04.652 | INFO     | __main__:main:164 - Processing Borboropactus_sp: /home/gyk/projects/Spider_Spidroin_Curation/data/raw/001-134spd/004.Borboropactus_sp/genome.softmasked.fa.gz
# Processing genomes:   3%|▎         | 4/133 [1:18:15<38:58:23, 1087.62s/it]
# 2026-05-18 18:39:29.206 | INFO     | __main__:main:172 - Completed: Borboropactus_sp
# 2026-05-18 18:39:29.207 | INFO     | __main__:main:164 - Processing Bowie_medogensis: /home/gyk/projects/Spider_Spidroin_Curation/data/raw/001-134spd/005.Bowie_medogensis/genome.softmasked.fa.gz
# Processing genomes:   4%|▍         | 5/133 [1:40:38<41:56:26, 1179.58s/it]
# 2026-05-18 19:01:51.838 | INFO     | __main__:main:172 - Completed: Bowie_medogensis
# 2026-05-18 19:01:51.839 | INFO     | __main__:main:164 - Processing Cicurina_yinheensis: /home/gyk/projects/Spider_Spidroin_Curation/data/raw/001-134spd/006.Cicurina_yinheensis/genome.softmasked.fa.gz
# 2026-05-18 19:38:10.876 | INFO     | __main__:main:172 - Completed: Cicurina_yinheensis
# 2026-05-18 19:38:10.877 | INFO     | __main__:main:164 - Processing Ctenus_medogensis: /home/gyk/projects/Spider_Spidroin_Curation/data/raw/001-134spd/007.Ctenus_medogensis/genome.softmasked.fa.gz
# Processing genomes:   5%|▌         | 7/133 [2:39:21<51:10:27, 1462.13s/it]
# 2026-05-18 20:00:35.090 | INFO     | __main__:main:172 - Completed: Ctenus_medogensis
# 2026-05-18 20:00:35.091 | INFO     | __main__:main:164 - Processing Cybaeus_sp: /home/gyk/projects/Spider_Spidroin_Curation/data/raw/001-134spd/008.Cybaeus_sp/genome.softmasked.fa.gz
# Processing genomes:   6%|▌         | 8/133 [3:02:36<50:01:50, 1440.89s/it]
# 2026-05-18 20:23:50.500 | INFO     | __main__:main:172 - Completed: Cybaeus_sp
# 2026-05-18 20:23:50.501 | INFO     | __main__:main:164 - Processing Cyclocosmia_sp: /home/gyk/projects/Spider_Spidroin_Curation/data/raw/001-134spd/009.Cyclocosmia_sp/genome.softmasked.fa.gz
# Processing genomes:   7%|▋         | 9/133 [3:32:22<53:20:15, 1548.51s/it]
# 2026-05-18 20:53:35.661 | INFO     | __main__:main:172 - Completed: Cyclocosmia_sp
# 2026-05-18 20:53:35.662 | INFO     | __main__:main:164 - Processing Damarchus_sp: /home/gyk/projects/Spider_Spidroin_Curation/data/raw/001-134spd/010.Damarchus_sp/genome.softmasked.fa.gz

# %% [markdown]
# ## Parse hmmer search results

# %%
run_cmd(
    f"pixi run python -m spider_silkome_module.parse_nhmmer_results \
        --input-path {nhmmer_search_output} \
        --output-path {parse_nhmmer_search_results_output} \
        --e-value-threshold 1e-10 \
        --coverage-threshold 0.9",
    [parse_nhmmer_search_results_output]
)
