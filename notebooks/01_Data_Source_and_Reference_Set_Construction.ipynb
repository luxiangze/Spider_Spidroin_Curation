# %% [markdown]
# # 数据源与参考集构建
# 锚点序列来源于 Spider Silkome Database (https://spider-silkome.org/about)。
# ## 环境配置
# 确保已安装以下依赖 (Via Pixi):
# ```bash
# pixi init spider_silkome
# pixi add python pandas biopython mafft hmmer samtools flye minimap2 seqkit
# ```

# %%
import os
import subprocess
import glob
import pandas as pd
from spider_silkome_module.config import PROCESSED_DATA_DIR, RAW_DATA_DIR, SCRIPTS_DIR, EXTERNAL_DATA_DIR, INTERIM_DATA_DIR

from spider_silkome_module import run_shell_command_with_check
from typing import List, Dict, Optional, Tuple
from dataclasses import dataclass

# Global Configuration
class Config:
    """
    Configuration class to hold paths and thresholds.
    Using a centralized config makes modifications easier.
    """
    PROJECT_NAME = "spider_silkome_20251130"
    # Paths
    SEEDS_QC_DIR = INTERIM_DATA_DIR / PROJECT_NAME / "spidroin_seeds_qc"
    HMMBUILD_INPUT_DIR = INTERIM_DATA_DIR / PROJECT_NAME / "hmmbuild_input"
    HMMBUILD_OUTPUT_DIR = INTERIM_DATA_DIR / PROJECT_NAME / "hmmbuild_output"
    HMMSEARCH_OUTPUT_DIR = INTERIM_DATA_DIR / PROJECT_NAME / "hmmserch_output"



    # Threads
    THREADS = 8

    # Thresholds
    E_VALUE_THRES = 1e-10
    MIN_GENE_LEN = 500       # Minimum distance between NTD and CTD
    MAX_GENE_LEN = 100000    # Maximum distance (100kb)

    def __init__(self):
        # Create directories if they don't exist
        os.makedirs(Config.SEEDS_QC_DIR, exist_ok=True)
        os.makedirs(Config.HMMBUILD_INPUT_DIR, exist_ok=True)
        os.makedirs(Config.HMMBUILD_OUTPUT_DIR, exist_ok=True)
        os.makedirs(Config.HMMSEARCH_OUTPUT_DIR, exist_ok=True)

# Initialize configuration
config = Config()

spidroin_seeds = EXTERNAL_DATA_DIR / "spidroin_seeds_collection.faa"

# %% [markdown]
# ## 1. 种子序列的获取与清洗
# 蛛丝蛋白家族庞大，涵盖了大壶状腺丝（MaSp）、小壶状腺丝（MiSp）、鞭毛状腺丝（Flag）、葡萄状腺丝（AcSp）、梨状腺丝（PySp）、管状腺丝（TuSp/CySp）以及聚合腺丝（AgSp）等多种类型。此外，Schöneberg等人（2025）还报道了在中纺亚目中发现的独特spidroin类型。
# 操作步骤：
# 1. 下载分类： 从数据库中分别下载各亚家族的NTD和CTD氨基酸序列。
# 2. 质量控制： 剔除序列中简单的重复序列或长度异常（<50aa）的序列。
# 3. 去冗余： 使用CD-HIT工具在95%的相似度水平上去除高度重复的序列，以防止模型过拟合。

# %%
# 质量控制
qc_cmd = f"pixi run python3 {SCRIPTS_DIR}/extract_terminal_domains.py {spidroin_seeds} -o {config.SEEDS_QC_DIR} -l 50 --similarity 0.5"
run_shell_command_with_check(qc_cmd, config.SEEDS_QC_DIR/"processing_report.tsv", force=True)
# Out:
# 2025-11-30 17:15:06.116 | INFO     | spider_silkome_module.features:run_shell_command_with_check:50 - Execute command: pixi run python3 /home/gyk/project/spider_silkome/scripts/extract_terminal_domains.py /home/gyk/project/spider_silkome/data/external/spidroin_seeds_collection.faa -o /home/gyk/project/spider_silkome/data/interim/spider_silkome_20251130/spidroin_seeds_qc -l 50 --similarity 0.5
# Loaded 11155 sequences from /home/gyk/project/spider_silkome/data/external/spidroin_seeds_collection.faa
# 2025-11-30 17:16:54.692 | SUCCESS  | spider_silkome_module.features:run_shell_command_with_check:53 - Command executed successfully, output file: /home/gyk/project/spider_silkome/data/interim/spider_silkome_20251130/spidroin_seeds_qc/processing_report.tsv
#   MiSp_CTD: 754 sequences -> /home/gyk/project/spider_silkome/data/interim/spider_silkome_20251130/spidroin_seeds_qc/MiSp_CTD.faa
#   AcSp_CTD: 821 sequences -> /home/gyk/project/spider_silkome/data/interim/spider_silkome_20251130/spidroin_seeds_qc/AcSp_CTD.faa
#   TuSp_CySp_CTD: 267 sequences -> /home/gyk/project/spider_silkome/data/interim/spider_silkome_20251130/spidroin_seeds_qc/TuSp_CySp_CTD.faa
#   CrSp_CTD: 41 sequences -> /home/gyk/project/spider_silkome/data/interim/spider_silkome_20251130/spidroin_seeds_qc/CrSp_CTD.faa
#   Other_CTD: 330 sequences -> /home/gyk/project/spider_silkome/data/interim/spider_silkome_20251130/spidroin_seeds_qc/Other_CTD.faa
#   Flag_CTD: 371 sequences -> /home/gyk/project/spider_silkome/data/interim/spider_silkome_20251130/spidroin_seeds_qc/Flag_CTD.faa
#   MaSp1_CTD: 600 sequences -> /home/gyk/project/spider_silkome/data/interim/spider_silkome_20251130/spidroin_seeds_qc/MaSp1_CTD.faa
#   MaSp2_CTD: 531 sequences -> /home/gyk/project/spider_silkome/data/interim/spider_silkome_20251130/spidroin_seeds_qc/MaSp2_CTD.faa
#   PySp_CTD: 507 sequences -> /home/gyk/project/spider_silkome/data/interim/spider_silkome_20251130/spidroin_seeds_qc/PySp_CTD.faa
#   MaSp_CTD: 206 sequences -> /home/gyk/project/spider_silkome/data/interim/spider_silkome_20251130/spidroin_seeds_qc/MaSp_CTD.faa
#   MaSp3B_CTD: 54 sequences -> /home/gyk/project/spider_silkome/data/interim/spider_silkome_20251130/spidroin_seeds_qc/MaSp3B_CTD.faa
#   pFlag_CTD: 10 sequences -> /home/gyk/project/spider_silkome/data/interim/spider_silkome_20251130/spidroin_seeds_qc/pFlag_CTD.faa
#   AgSp1_CTD: 492 sequences -> /home/gyk/project/spider_silkome/data/interim/spider_silkome_20251130/spidroin_seeds_qc/AgSp1_CTD.faa
#   MaSp3_CTD: 60 sequences -> /home/gyk/project/spider_silkome/data/interim/spider_silkome_20251130/spidroin_seeds_qc/MaSp3_CTD.faa
#   AgSp1_NTD: 318 sequences -> /home/gyk/project/spider_silkome/data/interim/spider_silkome_20251130/spidroin_seeds_qc/AgSp1_NTD.faa
#   AgSp2_CTD: 447 sequences -> /home/gyk/project/spider_silkome/data/interim/spider_silkome_20251130/spidroin_seeds_qc/AgSp2_CTD.faa
#   MaSp1_NTD: 574 sequences -> /home/gyk/project/spider_silkome/data/interim/spider_silkome_20251130/spidroin_seeds_qc/MaSp1_NTD.faa
#   Flag_NTD: 399 sequences -> /home/gyk/project/spider_silkome/data/interim/spider_silkome_20251130/spidroin_seeds_qc/Flag_NTD.faa
#   MiSp_NTD: 1026 sequences -> /home/gyk/project/spider_silkome/data/interim/spider_silkome_20251130/spidroin_seeds_qc/MiSp_NTD.faa
#   AgSp2_NTD: 359 sequences -> /home/gyk/project/spider_silkome/data/interim/spider_silkome_20251130/spidroin_seeds_qc/AgSp2_NTD.faa
#   Other_NTD: 856 sequences -> /home/gyk/project/spider_silkome/data/interim/spider_silkome_20251130/spidroin_seeds_qc/Other_NTD.faa
#   AcSp_NTD: 215 sequences -> /home/gyk/project/spider_silkome/data/interim/spider_silkome_20251130/spidroin_seeds_qc/AcSp_NTD.faa
#   PySp_NTD: 223 sequences -> /home/gyk/project/spider_silkome/data/interim/spider_silkome_20251130/spidroin_seeds_qc/PySp_NTD.faa
#   MaSp2_NTD: 236 sequences -> /home/gyk/project/spider_silkome/data/interim/spider_silkome_20251130/spidroin_seeds_qc/MaSp2_NTD.faa
#   MaSp_NTD: 746 sequences -> /home/gyk/project/spider_silkome/data/interim/spider_silkome_20251130/spidroin_seeds_qc/MaSp_NTD.faa
#   TuSp_CySp_NTD: 174 sequences -> /home/gyk/project/spider_silkome/data/interim/spider_silkome_20251130/spidroin_seeds_qc/TuSp_CySp_NTD.faa
#   MaSp3_NTD: 22 sequences -> /home/gyk/project/spider_silkome/data/interim/spider_silkome_20251130/spidroin_seeds_qc/MaSp3_NTD.faa
#   MaSp3B_NTD: 60 sequences -> /home/gyk/project/spider_silkome/data/interim/spider_silkome_20251130/spidroin_seeds_qc/MaSp3B_NTD.faa
#   pFlag_NTD: 2 sequences -> /home/gyk/project/spider_silkome/data/interim/spider_silkome_20251130/spidroin_seeds_qc/pFlag_NTD.faa
#   PanSpidroin_CTD: 5491 sequences -> /home/gyk/project/spider_silkome/data/interim/spider_silkome_20251130/spidroin_seeds_qc/PanSpidroin_CTD.faa
#   PanSpidroin_NTD: 5210 sequences -> /home/gyk/project/spider_silkome/data/interim/spider_silkome_20251130/spidroin_seeds_qc/PanSpidroin_NTD.faa
#   Report: /home/gyk/project/spider_silkome/data/interim/spider_silkome_20251130/spidroin_seeds_qc/processing_report.tsv
# Done. Output written to /home/gyk/project/spider_silkome/data/interim/spider_silkome_20251130/spidroin_seeds_qc/
# True

# %%
# 使用cd-hit去除高度重复的序列
for input_path in Config.SEEDS_QC_DIR.glob("*TD.faa"):
    output_path = input_path.with_stem(f"{input_path.stem}_de_dup")
    de_dup_cmd = f"pixi run cd-hit -i {input_path} -o {output_path} -c 0.95 -T 0 -M 0"
    run_shell_command_with_check(de_dup_cmd, output_path)
# Out:
# 2025-11-30 17:19:39.486 | INFO     | spider_silkome_module.features:run_shell_command_with_check:50 - Execute command: pixi run cd-hit -i /home/gyk/project/spider_silkome/data/interim/spider_silkome_20251130/spidroin_seeds_qc/AcSp_CTD_de_dup.faa -o /home/gyk/project/spider_silkome/data/interim/spider_silkome_20251130/spidroin_seeds_qc/AcSp_CTD_de_dup_de_dup.faa -c 0.95 -T 0 -M 0
# ================================================================
# Program: CD-HIT, V4.8.1 (+OpenMP), Apr 24 2025, 22:00:32
# Command:
#          /home/gyk/project/spider_silkome/.pixi/envs/default/bin/cd-hit
#          -i
#          /home/gyk/project/spider_silkome/data/interim/spider_silkome_20251130/spidroin_seeds_qc/AcSp_CTD_de_dup.faa
#          -o
#          /home/gyk/project/spider_silkome/data/interim/spider_silkome_20251130/spidroin_seeds_qc/AcSp_CTD_de_dup_de_dup.faa
#          -c 0.95 -T 0 -M 0
#
# Started: Sun Nov 30 17:19:39 2025
# ================================================================
#                             Output
# ----------------------------------------------------------------
# total number of CPUs in the system is 80
# Actual number of CPUs to be used: 80
#
# total seq: 561
# longest and shortest : 1512 and 51
# Total letters: 137067
# Sequences have been sorted
#
# Approximated minimal memory consumption:
# Sequence        : 0M
# Buffer          : 80 X 16M = 1306M
# Table           : 2 X 65M = 130M
# Miscellaneous   : 0M
# Total           : 1437M
#
# Table limit with the given memory limit:
# Max number of representatives: 248606
# Max number of word counting entries: 12663781
#
# # comparing sequences from          0  to        561
# ---------- new table with      561 representatives
#
#       561  finished        561  clusters
#
# Approximated maximum memory consumption: 1438M
# writing new database
# writing clustering information
# program completed !
#
# Total CPU time 1.67
# 2025-11-30 17:19:40.864 | SUCCESS  | spider_silkome_module.features:run_shell_command_with_check:53 - Command executed successfully, output file: /home/gyk/project/spider_silkome/data/interim/spider_silkome_20251130/spidroin_seeds_qc/AcSp_CTD_de_dup_de_dup.faa
# 2025-11-30 17:19:40.864 | INFO     | spider_silkome_module.features:run_shell_command_with_check:46 - The output file already exists, skipping execution: /home/gyk/project/spider_silkome/data/interim/spider_silkome_20251130/spidroin_seeds_qc/MaSp3_NTD_de_dup.faa
# 2025-11-30 17:19:40.864 | INFO     | spider_silkome_module.features:run_shell_command_with_check:50 - Execute command: pixi run cd-hit -i /home/gyk/project/spider_silkome/data/interim/spider_silkome_20251130/spidroin_seeds_qc/CrSp_CTD_de_dup.faa -o /home/gyk/project/spider_silkome/data/interim/spider_silkome_20251130/spidroin_seeds_qc/CrSp_CTD_de_dup_de_dup.faa -c 0.95 -T 0 -M 0
# ================================================================
# Program: CD-HIT, V4.8.1 (+OpenMP), Apr 24 2025, 22:00:32
# Command:
#          /home/gyk/project/spider_silkome/.pixi/envs/default/bin/cd-hit
#          -i
#          /home/gyk/project/spider_silkome/data/interim/spider_silkome_20251130/spidroin_seeds_qc/CrSp_CTD_de_dup.faa
#          -o
#          /home/gyk/project/spider_silkome/data/interim/spider_silkome_20251130/spidroin_seeds_qc/CrSp_CTD_de_dup_de_dup.faa
#          -c 0.95 -T 0 -M 0
#
# Started: Sun Nov 30 17:19:41 2025
# ================================================================
#                             Output
# ----------------------------------------------------------------
# total number of CPUs in the system is 80
# Actual number of CPUs to be used: 80
#
# total seq: 30
# longest and shortest : 1371 and 62
# Total letters: 13574
# Sequences have been sorted
#
# Approximated minimal memory consumption:
# Sequence        : 0M
# Buffer          : 80 X 16M = 1303M
# Table           : 2 X 65M = 130M
# Miscellaneous   : 0M
# Total           : 1434M
#
# Table limit with the given memory limit:
# Max number of representatives: 248606
# Max number of word counting entries: 21920003
#
# # comparing sequences from          0  to         30
# ---------- new table with       30 representatives
#
#        30  finished         30  clusters
#
# Approximated maximum memory consumption: 1434M
# writing new database
# writing clustering information
# program completed !
#
# Total CPU time 1.55
# 2025-11-30 17:19:42.192 | SUCCESS  | spider_silkome_module.features:run_shell_command_with_check:53 - Command executed successfully, output file: /home/gyk/project/spider_silkome/data/interim/spider_silkome_20251130/spidroin_seeds_qc/CrSp_CTD_de_dup_de_dup.faa
# 2025-11-30 17:19:42.192 | INFO     | spider_silkome_module.features:run_shell_command_with_check:46 - The output file already exists, skipping execution: /home/gyk/project/spider_silkome/data/interim/spider_silkome_20251130/spidroin_seeds_qc/pFlag_NTD_de_dup.faa
# 2025-11-30 17:19:42.193 | INFO     | spider_silkome_module.features:run_shell_command_with_check:46 - The output file already exists, skipping execution: /home/gyk/project/spider_silkome/data/interim/spider_silkome_20251130/spidroin_seeds_qc/MaSp_NTD_de_dup.faa
# 2025-11-30 17:19:42.193 | INFO     | spider_silkome_module.features:run_shell_command_with_check:46 - The output file already exists, skipping execution: /home/gyk/project/spider_silkome/data/interim/spider_silkome_20251130/spidroin_seeds_qc/MaSp3_CTD_de_dup.faa
# 2025-11-30 17:19:42.193 | INFO     | spider_silkome_module.features:run_shell_command_with_check:50 - Execute command: pixi run cd-hit -i /home/gyk/project/spider_silkome/data/interim/spider_silkome_20251130/spidroin_seeds_qc/AgSp1_NTD_de_dup.faa -o /home/gyk/project/spider_silkome/data/interim/spider_silkome_20251130/spidroin_seeds_qc/AgSp1_NTD_de_dup_de_dup.faa -c 0.95 -T 0 -M 0
# ================================================================
# Program: CD-HIT, V4.8.1 (+OpenMP), Apr 24 2025, 22:00:32
# Command:
#          /home/gyk/project/spider_silkome/.pixi/envs/default/bin/cd-hit
#          -i
#          /home/gyk/project/spider_silkome/data/interim/spider_silkome_20251130/spidroin_seeds_qc/AgSp1_NTD_de_dup.faa
#          -o
#          /home/gyk/project/spider_silkome/data/interim/spider_silkome_20251130/spidroin_seeds_qc/AgSp1_NTD_de_dup_de_dup.faa
#          -c 0.95 -T 0 -M 0
#
# Started: Sun Nov 30 17:19:42 2025
# ================================================================
#                             Output
# ----------------------------------------------------------------
# total number of CPUs in the system is 80
# Actual number of CPUs to be used: 80
#
# total seq: 149
# longest and shortest : 342 and 63
# Total letters: 25692
# Sequences have been sorted
#
# Approximated minimal memory consumption:
# Sequence        : 0M
# Buffer          : 80 X 16M = 1286M
# Table           : 2 X 65M = 130M
# Miscellaneous   : 0M
# Total           : 1416M
#
# Table limit with the given memory limit:
# Max number of representatives: 248606
# Max number of word counting entries: 9333382
#
# # comparing sequences from          0  to        149
# ---------- new table with      149 representatives
#
#       149  finished        149  clusters
#
# Approximated maximum memory consumption: 1417M
# writing new database
# writing clustering information
# program completed !
#
# Total CPU time 1.57
# 2025-11-30 17:19:43.526 | SUCCESS  | spider_silkome_module.features:run_shell_command_with_check:53 - Command executed successfully, output file: /home/gyk/project/spider_silkome/data/interim/spider_silkome_20251130/spidroin_seeds_qc/AgSp1_NTD_de_dup_de_dup.faa
# 2025-11-30 17:19:43.526 | INFO     | spider_silkome_module.features:run_shell_command_with_check:50 - Execute command: pixi run cd-hit -i /home/gyk/project/spider_silkome/data/interim/spider_silkome_20251130/spidroin_seeds_qc/MaSp_NTD_de_dup.faa -o /home/gyk/project/spider_silkome/data/interim/spider_silkome_20251130/spidroin_seeds_qc/MaSp_NTD_de_dup_de_dup.faa -c 0.95 -T 0 -M 0
# ================================================================
# Program: CD-HIT, V4.8.1 (+OpenMP), Apr 24 2025, 22:00:32
# Command:
#          /home/gyk/project/spider_silkome/.pixi/envs/default/bin/cd-hit
#          -i
#          /home/gyk/project/spider_silkome/data/interim/spider_silkome_20251130/spidroin_seeds_qc/MaSp_NTD_de_dup.faa
#          -o
#          /home/gyk/project/spider_silkome/data/interim/spider_silkome_20251130/spidroin_seeds_qc/MaSp_NTD_de_dup_de_dup.faa
#          -c 0.95 -T 0 -M 0
#
# Started: Sun Nov 30 17:19:43 2025
# ================================================================
#                             Output
# ----------------------------------------------------------------
# total number of CPUs in the system is 80
# Actual number of CPUs to be used: 80
#
# total seq: 496
# longest and shortest : 795 and 81
# Total letters: 92222
# Sequences have been sorted
#
# Approximated minimal memory consumption:
# Sequence        : 0M
# Buffer          : 80 X 16M = 1294M
# Table           : 2 X 65M = 130M
# Miscellaneous   : 0M
# Total           : 1425M
#
# Table limit with the given memory limit:
# Max number of representatives: 248606
# Max number of word counting entries: 8632715
#
# # comparing sequences from          0  to        496
# ---------- new table with      496 representatives
#
#       496  finished        496  clusters
#
# Approximated maximum memory consumption: 1425M
# writing new database
# writing clustering information
# program completed !
#
# Total CPU time 1.60
# 2025-11-30 17:19:44.840 | SUCCESS  | spider_silkome_module.features:run_shell_command_with_check:53 - Command executed successfully, output file: /home/gyk/project/spider_silkome/data/interim/spider_silkome_20251130/spidroin_seeds_qc/MaSp_NTD_de_dup_de_dup.faa
# 2025-11-30 17:19:44.841 | INFO     | spider_silkome_module.features:run_shell_command_with_check:46 - The output file already exists, skipping execution: /home/gyk/project/spider_silkome/data/interim/spider_silkome_20251130/spidroin_seeds_qc/TuSp_CySp_NTD_de_dup.faa
# 2025-11-30 17:19:44.841 | INFO     | spider_silkome_module.features:run_shell_command_with_check:46 - The output file already exists, skipping execution: /home/gyk/project/spider_silkome/data/interim/spider_silkome_20251130/spidroin_seeds_qc/MiSp_NTD_de_dup.faa
# 2025-11-30 17:19:44.841 | INFO     | spider_silkome_module.features:run_shell_command_with_check:46 - The output file already exists, skipping execution: /home/gyk/project/spider_silkome/data/interim/spider_silkome_20251130/spidroin_seeds_qc/AcSp_NTD_de_dup.faa
# 2025-11-30 17:19:44.841 | INFO     | spider_silkome_module.features:run_shell_command_with_check:50 - Execute command: pixi run cd-hit -i /home/gyk/project/spider_silkome/data/interim/spider_silkome_20251130/spidroin_seeds_qc/Other_CTD_de_dup.faa -o /home/gyk/project/spider_silkome/data/interim/spider_silkome_20251130/spidroin_seeds_qc/Other_CTD_de_dup_de_dup.faa -c 0.95 -T 0 -M 0
# ================================================================
# Program: CD-HIT, V4.8.1 (+OpenMP), Apr 24 2025, 22:00:32
# Command:
#          /home/gyk/project/spider_silkome/.pixi/envs/default/bin/cd-hit
#          -i
#          /home/gyk/project/spider_silkome/data/interim/spider_silkome_20251130/spidroin_seeds_qc/Other_CTD_de_dup.faa
#          -o
#          /home/gyk/project/spider_silkome/data/interim/spider_silkome_20251130/spidroin_seeds_qc/Other_CTD_de_dup_de_dup.faa
#          -c 0.95 -T 0 -M 0
#
# Started: Sun Nov 30 17:19:44 2025
# ================================================================
#                             Output
# ----------------------------------------------------------------
# total number of CPUs in the system is 80
# Actual number of CPUs to be used: 80
#
# total seq: 278
# longest and shortest : 538 and 50
# Total letters: 41205
# Sequences have been sorted
#
# Approximated minimal memory consumption:
# Sequence        : 0M
# Buffer          : 80 X 16M = 1289M
# Table           : 2 X 65M = 130M
# Miscellaneous   : 0M
# Total           : 1420M
#
# Table limit with the given memory limit:
# Max number of representatives: 248606
# Max number of word counting entries: 7847832
#
# # comparing sequences from          0  to        278
# ---------- new table with      278 representatives
#
#       278  finished        278  clusters
#
# Approximated maximum memory consumption: 1420M
# writing new database
# writing clustering information
# program completed !
#
# Total CPU time 1.63
# 2025-11-30 17:19:46.183 | SUCCESS  | spider_silkome_module.features:run_shell_command_with_check:53 - Command executed successfully, output file: /home/gyk/project/spider_silkome/data/interim/spider_silkome_20251130/spidroin_seeds_qc/Other_CTD_de_dup_de_dup.faa
# 2025-11-30 17:19:46.183 | INFO     | spider_silkome_module.features:run_shell_command_with_check:50 - Execute command: pixi run cd-hit -i /home/gyk/project/spider_silkome/data/interim/spider_silkome_20251130/spidroin_seeds_qc/pFlag_NTD_de_dup.faa -o /home/gyk/project/spider_silkome/data/interim/spider_silkome_20251130/spidroin_seeds_qc/pFlag_NTD_de_dup_de_dup.faa -c 0.95 -T 0 -M 0
# ================================================================
# Program: CD-HIT, V4.8.1 (+OpenMP), Apr 24 2025, 22:00:32
# Command:
#          /home/gyk/project/spider_silkome/.pixi/envs/default/bin/cd-hit
#          -i
#          /home/gyk/project/spider_silkome/data/interim/spider_silkome_20251130/spidroin_seeds_qc/pFlag_NTD_de_dup.faa
#          -o
#          /home/gyk/project/spider_silkome/data/interim/spider_silkome_20251130/spidroin_seeds_qc/pFlag_NTD_de_dup_de_dup.faa
#          -c 0.95 -T 0 -M 0
#
# Started: Sun Nov 30 17:19:46 2025
# ================================================================
#                             Output
# ----------------------------------------------------------------
# total number of CPUs in the system is 80
# Actual number of CPUs to be used: 80
#
# total seq: 1
# longest and shortest : 230 and 230
# Total letters: 230
# Sequences have been sorted
#
# Approximated minimal memory consumption:
# Sequence        : 0M
# Buffer          : 80 X 16M = 1284M
# Table           : 2 X 65M = 130M
# Miscellaneous   : 0M
# Total           : 1414M
#
# Table limit with the given memory limit:
# Max number of representatives: 248606
# Max number of word counting entries: 10262177
#
# # comparing sequences from          0  to          1
# ---------- new table with        1 representatives
#
#         1  finished          1  clusters
#
# Approximated maximum memory consumption: 1414M
# writing new database
# writing clustering information
# program completed !
#
# Total CPU time 1.56
# 2025-11-30 17:19:47.482 | SUCCESS  | spider_silkome_module.features:run_shell_command_with_check:53 - Command executed successfully, output file: /home/gyk/project/spider_silkome/data/interim/spider_silkome_20251130/spidroin_seeds_qc/pFlag_NTD_de_dup_de_dup.faa
# 2025-11-30 17:19:47.482 | INFO     | spider_silkome_module.features:run_shell_command_with_check:50 - Execute command: pixi run cd-hit -i /home/gyk/project/spider_silkome/data/interim/spider_silkome_20251130/spidroin_seeds_qc/MaSp2_NTD_de_dup.faa -o /home/gyk/project/spider_silkome/data/interim/spider_silkome_20251130/spidroin_seeds_qc/MaSp2_NTD_de_dup_de_dup.faa -c 0.95 -T 0 -M 0
# ================================================================
# Program: CD-HIT, V4.8.1 (+OpenMP), Apr 24 2025, 22:00:32
# Command:
#          /home/gyk/project/spider_silkome/.pixi/envs/default/bin/cd-hit
#          -i
#          /home/gyk/project/spider_silkome/data/interim/spider_silkome_20251130/spidroin_seeds_qc/MaSp2_NTD_de_dup.faa
#          -o
#          /home/gyk/project/spider_silkome/data/interim/spider_silkome_20251130/spidroin_seeds_qc/MaSp2_NTD_de_dup_de_dup.faa
#          -c 0.95 -T 0 -M 0
#
# Started: Sun Nov 30 17:19:47 2025
# ================================================================
#                             Output
# ----------------------------------------------------------------
# total number of CPUs in the system is 80
# Actual number of CPUs to be used: 80
#
# total seq: 116
# longest and shortest : 328 and 100
# Total letters: 18667
# Sequences have been sorted
#
# Approximated minimal memory consumption:
# Sequence        : 0M
# Buffer          : 80 X 16M = 1285M
# Table           : 2 X 65M = 130M
# Miscellaneous   : 0M
# Total           : 1416M
#
# Table limit with the given memory limit:
# Max number of representatives: 248606
# Max number of word counting entries: 7623776
#
# # comparing sequences from          0  to        116
# ---------- new table with      116 representatives
#
#       116  finished        116  clusters
#
# Approximated maximum memory consumption: 1416M
# writing new database
# writing clustering information
# program completed !
#
# Total CPU time 1.56
# 2025-11-30 17:19:48.805 | SUCCESS  | spider_silkome_module.features:run_shell_command_with_check:53 - Command executed successfully, output file: /home/gyk/project/spider_silkome/data/interim/spider_silkome_20251130/spidroin_seeds_qc/MaSp2_NTD_de_dup_de_dup.faa
# 2025-11-30 17:19:48.805 | INFO     | spider_silkome_module.features:run_shell_command_with_check:50 - Execute command: pixi run cd-hit -i /home/gyk/project/spider_silkome/data/interim/spider_silkome_20251130/spidroin_seeds_qc/TuSp_CySp_CTD_de_dup.faa -o /home/gyk/project/spider_silkome/data/interim/spider_silkome_20251130/spidroin_seeds_qc/TuSp_CySp_CTD_de_dup_de_dup.faa -c 0.95 -T 0 -M 0
# ================================================================
# Program: CD-HIT, V4.8.1 (+OpenMP), Apr 24 2025, 22:00:32
# Command:
#          /home/gyk/project/spider_silkome/.pixi/envs/default/bin/cd-hit
#          -i
#          /home/gyk/project/spider_silkome/data/interim/spider_silkome_20251130/spidroin_seeds_qc/TuSp_CySp_CTD_de_dup.faa
#          -o
#          /home/gyk/project/spider_silkome/data/interim/spider_silkome_20251130/spidroin_seeds_qc/TuSp_CySp_CTD_de_dup_de_dup.faa
#          -c 0.95 -T 0 -M 0
#
# Started: Sun Nov 30 17:19:48 2025
# ================================================================
#                             Output
# ----------------------------------------------------------------
# total number of CPUs in the system is 80
# Actual number of CPUs to be used: 80
#
# total seq: 191
# longest and shortest : 531 and 50
# Total letters: 33327
# Sequences have been sorted
#
# Approximated minimal memory consumption:
# Sequence        : 0M
# Buffer          : 80 X 16M = 1289M
# Table           : 2 X 65M = 130M
# Miscellaneous   : 0M
# Total           : 1420M
#
# Table limit with the given memory limit:
# Max number of representatives: 248606
# Max number of word counting entries: 9618938
#
# # comparing sequences from          0  to        191
# ---------- new table with      191 representatives
#
#       191  finished        191  clusters
#
# Approximated maximum memory consumption: 1420M
# writing new database
# writing clustering information
# program completed !
#
# Total CPU time 1.60
# 2025-11-30 17:19:50.142 | SUCCESS  | spider_silkome_module.features:run_shell_command_with_check:53 - Command executed successfully, output file: /home/gyk/project/spider_silkome/data/interim/spider_silkome_20251130/spidroin_seeds_qc/TuSp_CySp_CTD_de_dup_de_dup.faa
# 2025-11-30 17:19:50.142 | INFO     | spider_silkome_module.features:run_shell_command_with_check:46 - The output file already exists, skipping execution: /home/gyk/project/spider_silkome/data/interim/spider_silkome_20251130/spidroin_seeds_qc/AcSp_CTD_de_dup.faa
# 2025-11-30 17:19:50.143 | INFO     | spider_silkome_module.features:run_shell_command_with_check:50 - Execute command: pixi run cd-hit -i /home/gyk/project/spider_silkome/data/interim/spider_silkome_20251130/spidroin_seeds_qc/MaSp2_CTD_de_dup.faa -o /home/gyk/project/spider_silkome/data/interim/spider_silkome_20251130/spidroin_seeds_qc/MaSp2_CTD_de_dup_de_dup.faa -c 0.95 -T 0 -M 0
# ================================================================
# Program: CD-HIT, V4.8.1 (+OpenMP), Apr 24 2025, 22:00:32
# Command:
#          /home/gyk/project/spider_silkome/.pixi/envs/default/bin/cd-hit
#          -i
#          /home/gyk/project/spider_silkome/data/interim/spider_silkome_20251130/spidroin_seeds_qc/MaSp2_CTD_de_dup.faa
#          -o
#          /home/gyk/project/spider_silkome/data/interim/spider_silkome_20251130/spidroin_seeds_qc/MaSp2_CTD_de_dup_de_dup.faa
#          -c 0.95 -T 0 -M 0
#
# Started: Sun Nov 30 17:19:50 2025
# ================================================================
#                             Output
# ----------------------------------------------------------------
# total number of CPUs in the system is 80
# Actual number of CPUs to be used: 80
#
# total seq: 274
# longest and shortest : 682 and 53
# Total letters: 41820
# Sequences have been sorted
#
# Approximated minimal memory consumption:
# Sequence        : 0M
# Buffer          : 80 X 16M = 1292M
# Table           : 2 X 65M = 130M
# Miscellaneous   : 0M
# Total           : 1422M
#
# Table limit with the given memory limit:
# Max number of representatives: 248606
# Max number of word counting entries: 8535976
#
# # comparing sequences from          0  to        274
# ---------- new table with      274 representatives
#
#       274  finished        274  clusters
#
# Approximated maximum memory consumption: 1423M
# writing new database
# writing clustering information
# program completed !
#
# Total CPU time 1.56
# 2025-11-30 17:19:51.449 | SUCCESS  | spider_silkome_module.features:run_shell_command_with_check:53 - Command executed successfully, output file: /home/gyk/project/spider_silkome/data/interim/spider_silkome_20251130/spidroin_seeds_qc/MaSp2_CTD_de_dup_de_dup.faa
# 2025-11-30 17:19:51.450 | INFO     | spider_silkome_module.features:run_shell_command_with_check:50 - Execute command: pixi run cd-hit -i /home/gyk/project/spider_silkome/data/interim/spider_silkome_20251130/spidroin_seeds_qc/PanSpidroin_CTD.faa -o /home/gyk/project/spider_silkome/data/interim/spider_silkome_20251130/spidroin_seeds_qc/PanSpidroin_CTD_de_dup.faa -c 0.95 -T 0 -M 0
# ================================================================
# Program: CD-HIT, V4.8.1 (+OpenMP), Apr 24 2025, 22:00:32
# Command:
#          /home/gyk/project/spider_silkome/.pixi/envs/default/bin/cd-hit
#          -i
#          /home/gyk/project/spider_silkome/data/interim/spider_silkome_20251130/spidroin_seeds_qc/PanSpidroin_CTD.faa
#          -o
#          /home/gyk/project/spider_silkome/data/interim/spider_silkome_20251130/spidroin_seeds_qc/PanSpidroin_CTD_de_dup.faa
#          -c 0.95 -T 0 -M 0
#
# Started: Sun Nov 30 17:19:51 2025
# ================================================================
#                             Output
# ----------------------------------------------------------------
# total number of CPUs in the system is 80
# Actual number of CPUs to be used: 80
#
# total seq: 5491
# longest and shortest : 1538 and 50
# Total letters: 970049
# Sequences have been sorted
#
# Approximated minimal memory consumption:
# Sequence        : 1M
# Buffer          : 80 X 16M = 1311M
# Table           : 2 X 65M = 130M
# Miscellaneous   : 0M
# Total           : 1444M
#
# Table limit with the given memory limit:
# Max number of representatives: 248606
# Max number of word counting entries: 9370549
#
# # comparing sequences from          0  to         66
# ---------- new table with       51 representatives
# # comparing sequences from         66  to        132
# ................---------- new table with       47 representatives
# # comparing sequences from        132  to        197
# ..............---------- new table with       33 representatives
# # comparing sequences from        197  to        261
# ...............---------- new table with       52 representatives
# # comparing sequences from        261  to        324
# ..............---------- new table with       48 representatives
# # comparing sequences from        324  to        387
# ...............---------- new table with       52 representatives
# # comparing sequences from        387  to        449
# ................---------- new table with       55 representatives
# # comparing sequences from        449  to        510
# ..............---------- new table with       50 representatives
# # comparing sequences from        510  to        570
# ...............---------- new table with       54 representatives
# # comparing sequences from        570  to        630
# .............---------- new table with       45 representatives
# # comparing sequences from        630  to        689
# ...................---------- new table with       44 representatives
# # comparing sequences from        689  to        747
# ...................---------- new table with       49 representatives
# # comparing sequences from        747  to        804
# .................---------- new table with       47 representatives
# # comparing sequences from        804  to        861
# ...............---------- new table with       50 representatives
# # comparing sequences from        861  to        917
# ..................---------- new table with       48 representatives
# # comparing sequences from        917  to        972
# ..............---------- new table with       43 representatives
# # comparing sequences from        972  to       1027
# ............---------- new table with       41 representatives
# # comparing sequences from       1027  to       1081
# ..............---------- new table with       48 representatives
# # comparing sequences from       1081  to       1134
# ..............---------- new table with       41 representatives
# # comparing sequences from       1134  to       1187
# ...........---------- new table with       31 representatives
# # comparing sequences from       1187  to       1239
# ........---------- new table with       18 representatives
# # comparing sequences from       1239  to       1290
# ..............---------- new table with       31 representatives
# # comparing sequences from       1290  to       1341
# ................---------- new table with       26 representatives
# # comparing sequences from       1341  to       1391
# .................---------- new table with       19 representatives
# # comparing sequences from       1391  to       1441
# ............---------- new table with       29 representatives
# # comparing sequences from       1441  to       1490
# ..............---------- new table with       28 representatives
# # comparing sequences from       1490  to       1538
# ...........---------- new table with       15 representatives
# # comparing sequences from       1538  to       1586
# ........---------- new table with       28 representatives
# # comparing sequences from       1586  to       1633
# ..............---------- new table with       29 representatives
# # comparing sequences from       1633  to       1680
# .............---------- new table with       30 representatives
# # comparing sequences from       1680  to       1726
# ...............---------- new table with       29 representatives
# # comparing sequences from       1726  to       1771
# .............---------- new table with       36 representatives
# # comparing sequences from       1771  to       1816
# ............---------- new table with       31 representatives
# # comparing sequences from       1816  to       1860
# .......---------- new table with       28 representatives
# # comparing sequences from       1860  to       1904
# ...........---------- new table with       31 representatives
# # comparing sequences from       1904  to       1947
# .........---------- new table with       29 representatives
# # comparing sequences from       1947  to       1990
# ...........---------- new table with       31 representatives
# # comparing sequences from       1990  to       2032
# ...............---------- new table with       35 representatives
# # comparing sequences from       2032  to       2074
# ........---------- new table with       27 representatives
# # comparing sequences from       2074  to       2115
# .............---------- new table with       33 representatives
# # comparing sequences from       2115  to       2156
# ..........---------- new table with       34 representatives
# # comparing sequences from       2156  to       2196
# ............---------- new table with       34 representatives
# # comparing sequences from       2196  to       2236
# .............---------- new table with       33 representatives
# # comparing sequences from       2236  to       2275
# .........---------- new table with       21 representatives
# # comparing sequences from       2275  to       2314
# .................---------- new table with       26 representatives
# # comparing sequences from       2314  to       2352
# ..........---------- new table with       25 representatives
# # comparing sequences from       2352  to       2390
# ...........---------- new table with       15 representatives
# # comparing sequences from       2390  to       2427
# .................---------- new table with       29 representatives
# # comparing sequences from       2427  to       2464
# ..............---------- new table with       25 representatives
# # comparing sequences from       2464  to       2500
# ..........---------- new table with       19 representatives
# # comparing sequences from       2500  to       2536
# .............---------- new table with       28 representatives
# # comparing sequences from       2536  to       2572
# ............---------- new table with       22 representatives
# # comparing sequences from       2572  to       2607
# ............---------- new table with       21 representatives
# # comparing sequences from       2607  to       2642
# ...........---------- new table with       19 representatives
# # comparing sequences from       2642  to       2676
# .............---------- new table with       21 representatives
# # comparing sequences from       2676  to       2710
# ..............---------- new table with       26 representatives
# # comparing sequences from       2710  to       2743
# ..............---------- new table with       23 representatives
# # comparing sequences from       2743  to       2776
# ............---------- new table with       22 representatives
# # comparing sequences from       2776  to       2809
# ..........---------- new table with       18 representatives
# # comparing sequences from       2809  to       2841
# ..............---------- new table with       23 representatives
# # comparing sequences from       2841  to       2873
# ..........---------- new table with       21 representatives
# # comparing sequences from       2873  to       2904
# .....---------- new table with       14 representatives
# # comparing sequences from       2904  to       2935
# .........---------- new table with       17 representatives
# # comparing sequences from       2935  to       2966
# .......---------- new table with       15 representatives
# # comparing sequences from       2966  to       2996
# .........---------- new table with       13 representatives
# # comparing sequences from       2996  to       3026
# ..........---------- new table with       17 representatives
# # comparing sequences from       3026  to       3056
# ............---------- new table with       16 representatives
# # comparing sequences from       3056  to       3085
# ..........---------- new table with       14 representatives
# # comparing sequences from       3085  to       3114
# ...........---------- new table with       19 representatives
# # comparing sequences from       3114  to       3142
# ..........---------- new table with       19 representatives
# # comparing sequences from       3142  to       3170
# .........---------- new table with       17 representatives
# # comparing sequences from       3170  to       3198
# ..---------- new table with        5 representatives
# # comparing sequences from       3198  to       3225
# ..........---------- new table with       20 representatives
# # comparing sequences from       3225  to       3252
# ..........---------- new table with       20 representatives
# # comparing sequences from       3252  to       3279
# .....---------- new table with       13 representatives
# # comparing sequences from       3279  to       3305
# ........---------- new table with       15 representatives
# # comparing sequences from       3305  to       3331
# .......---------- new table with       14 representatives
# # comparing sequences from       3331  to       3357
# ........---------- new table with       13 representatives
# # comparing sequences from       3357  to       3383
# .........---------- new table with       19 representatives
# # comparing sequences from       3383  to       3408
# ...........---------- new table with       18 representatives
# # comparing sequences from       3408  to       3433
# ........---------- new table with       15 representatives
# # comparing sequences from       3433  to       3458
# ..........---------- new table with       13 representatives
# # comparing sequences from       3458  to       3482
# ........---------- new table with       13 representatives
# # comparing sequences from       3482  to       3506
# ..........---------- new table with       14 representatives
# # comparing sequences from       3506  to       3530
# ......---------- new table with       13 representatives
# # comparing sequences from       3530  to       3553
# .......---------- new table with        9 representatives
# # comparing sequences from       3553  to       3576
# .........---------- new table with       17 representatives
# # comparing sequences from       3576  to       3599
# .......---------- new table with       10 representatives
# # comparing sequences from       3599  to       3622
# ......---------- new table with       12 representatives
# # comparing sequences from       3622  to       3644
# ....---------- new table with       11 representatives
# # comparing sequences from       3644  to       3666
# ...........---------- new table with       17 representatives
# # comparing sequences from       3666  to       3688
# 98.4%---------- new table with        2 representatives
# # comparing sequences from       3688  to       3709
# .......---------- new table with        8 representatives
# # comparing sequences from       3709  to       3730
# .......---------- new table with       14 representatives
# # comparing sequences from       3730  to       3751
# ........---------- new table with       13 representatives
# # comparing sequences from       3751  to       3772
# .....---------- new table with        6 representatives
# # comparing sequences from       3772  to       3792
# ........---------- new table with       17 representatives
# # comparing sequences from       3792  to       3812
# .....---------- new table with        9 representatives
# # comparing sequences from       3812  to       3832
# .......---------- new table with       11 representatives
# # comparing sequences from       3832  to       3852
# ....---------- new table with        8 representatives
# # comparing sequences from       3852  to       3871
# ...............---------- new table with       14 representatives
# # comparing sequences from       3871  to       3890
# .............---------- new table with       13 representatives
# # comparing sequences from       3890  to       3909
# ............---------- new table with       12 representatives
# # comparing sequences from       3909  to       3928
# .........---------- new table with        8 representatives
# # comparing sequences from       3928  to       3947
# 97.3%---------- new table with        4 representatives
# # comparing sequences from       3947  to       3965
# .........---------- new table with        8 representatives
# # comparing sequences from       3965  to       3983
# .............---------- new table with       12 representatives
# # comparing sequences from       3983  to       4001
# .............---------- new table with       11 representatives
# # comparing sequences from       4001  to       4019
# .............---------- new table with       13 representatives
# # comparing sequences from       4019  to       4036
# ...........---------- new table with       10 representatives
# # comparing sequences from       4036  to       4053
# ...........---------- new table with       11 representatives
# # comparing sequences from       4053  to       4070
# ..........---------- new table with       10 representatives
# # comparing sequences from       4070  to       4087
# ..........---------- new table with       10 representatives
# # comparing sequences from       4087  to       4104
# ...........---------- new table with       11 representatives
# # comparing sequences from       4104  to       4120
# .........---------- new table with        9 representatives
# # comparing sequences from       4120  to       4136
# ........---------- new table with        6 representatives
# # comparing sequences from       4136  to       4152
# ............---------- new table with       12 representatives
# # comparing sequences from       4152  to       4168
# ............---------- new table with        9 representatives
# # comparing sequences from       4168  to       4184
# ..........---------- new table with        8 representatives
# # comparing sequences from       4184  to       4199
# .....---------- new table with        5 representatives
# # comparing sequences from       4199  to       4214
# .....---------- new table with        5 representatives
# # comparing sequences from       4214  to       4229
# .......---------- new table with        7 representatives
# # comparing sequences from       4229  to       4244
# ..........---------- new table with       10 representatives
# # comparing sequences from       4244  to       4259
# .........---------- new table with        9 representatives
# # comparing sequences from       4259  to       4274
# .......---------- new table with        7 representatives
# # comparing sequences from       4274  to       4288
# ............---------- new table with       10 representatives
# # comparing sequences from       4288  to       4302
# .............---------- new table with       11 representatives
# # comparing sequences from       4302  to       4316
# ........---------- new table with        8 representatives
# # comparing sequences from       4316  to       4330
# ..........---------- new table with       10 representatives
# # comparing sequences from       4330  to       4344
# ..........---------- new table with        7 representatives
# # comparing sequences from       4344  to       4357
# 94.0%---------- new table with        4 representatives
# # comparing sequences from       4357  to       4370
# ......---------- new table with        5 representatives
# # comparing sequences from       4370  to       4383
# ...........---------- new table with       10 representatives
# # comparing sequences from       4383  to       4396
# ........---------- new table with        7 representatives
# # comparing sequences from       4396  to       4409
# ........---------- new table with        7 representatives
# # comparing sequences from       4409  to       4422
# .........---------- new table with        7 representatives
# # comparing sequences from       4422  to       4435
# 94.3%---------- new table with        3 representatives
# # comparing sequences from       4435  to       4447
# ....---------- new table with        4 representatives
# # comparing sequences from       4447  to       4459
# ......---------- new table with        6 representatives
# # comparing sequences from       4459  to       4471
# .......---------- new table with        6 representatives
# # comparing sequences from       4471  to       4483
# 100.0%---------- new table with        2 representatives
# # comparing sequences from       4483  to       4495
# 99.9%---------- new table with        3 representatives
# # comparing sequences from       4495  to       5491
# ..............---------- new table with      479 representatives
#
#      5491  finished       3350  clusters
#
# Approximated maximum memory consumption: 1444M
# writing new database
# writing clustering information
# program completed !
#
# Total CPU time 110.75
# 2025-11-30 17:19:55.371 | SUCCESS  | spider_silkome_module.features:run_shell_command_with_check:53 - Command executed successfully, output file: /home/gyk/project/spider_silkome/data/interim/spider_silkome_20251130/spidroin_seeds_qc/PanSpidroin_CTD_de_dup.faa
# 2025-11-30 17:19:55.371 | INFO     | spider_silkome_module.features:run_shell_command_with_check:46 - The output file already exists, skipping execution: /home/gyk/project/spider_silkome/data/interim/spider_silkome_20251130/spidroin_seeds_qc/MaSp3B_CTD_de_dup.faa
# 2025-11-30 17:19:55.371 | INFO     | spider_silkome_module.features:run_shell_command_with_check:50 - Execute command: pixi run cd-hit -i /home/gyk/project/spider_silkome/data/interim/spider_silkome_20251130/spidroin_seeds_qc/MaSp1_NTD_de_dup.faa -o /home/gyk/project/spider_silkome/data/interim/spider_silkome_20251130/spidroin_seeds_qc/MaSp1_NTD_de_dup_de_dup.faa -c 0.95 -T 0 -M 0
# ================================================================
# Program: CD-HIT, V4.8.1 (+OpenMP), Apr 24 2025, 22:00:32
# Command:
#          /home/gyk/project/spider_silkome/.pixi/envs/default/bin/cd-hit
#          -i
#          /home/gyk/project/spider_silkome/data/interim/spider_silkome_20251130/spidroin_seeds_qc/MaSp1_NTD_de_dup.faa
#          -o
#          /home/gyk/project/spider_silkome/data/interim/spider_silkome_20251130/spidroin_seeds_qc/MaSp1_NTD_de_dup_de_dup.faa
#          -c 0.95 -T 0 -M 0
#
# Started: Sun Nov 30 17:19:55 2025
# ================================================================
#                             Output
# ----------------------------------------------------------------
# total number of CPUs in the system is 80
# Actual number of CPUs to be used: 80
#
# total seq: 284
# longest and shortest : 515 and 100
# Total letters: 48274
# Sequences have been sorted
#
# Approximated minimal memory consumption:
# Sequence        : 0M
# Buffer          : 80 X 16M = 1289M
# Table           : 2 X 65M = 130M
# Miscellaneous   : 0M
# Total           : 1420M
#
# Table limit with the given memory limit:
# Max number of representatives: 248606
# Max number of word counting entries: 7940345
#
# # comparing sequences from          0  to        284
# ---------- new table with      284 representatives
#
#       284  finished        284  clusters
#
# Approximated maximum memory consumption: 1420M
# writing new database
# writing clustering information
# program completed !
#
# Total CPU time 1.67
# 2025-11-30 17:19:56.708 | SUCCESS  | spider_silkome_module.features:run_shell_command_with_check:53 - Command executed successfully, output file: /home/gyk/project/spider_silkome/data/interim/spider_silkome_20251130/spidroin_seeds_qc/MaSp1_NTD_de_dup_de_dup.faa
# 2025-11-30 17:19:56.709 | INFO     | spider_silkome_module.features:run_shell_command_with_check:46 - The output file already exists, skipping execution: /home/gyk/project/spider_silkome/data/interim/spider_silkome_20251130/spidroin_seeds_qc/pFlag_CTD_de_dup.faa
# 2025-11-30 17:19:56.709 | INFO     | spider_silkome_module.features:run_shell_command_with_check:46 - The output file already exists, skipping execution: /home/gyk/project/spider_silkome/data/interim/spider_silkome_20251130/spidroin_seeds_qc/Flag_NTD_de_dup.faa
# 2025-11-30 17:19:56.709 | INFO     | spider_silkome_module.features:run_shell_command_with_check:46 - The output file already exists, skipping execution: /home/gyk/project/spider_silkome/data/interim/spider_silkome_20251130/spidroin_seeds_qc/MaSp1_NTD_de_dup.faa
# 2025-11-30 17:19:56.709 | INFO     | spider_silkome_module.features:run_shell_command_with_check:46 - The output file already exists, skipping execution: /home/gyk/project/spider_silkome/data/interim/spider_silkome_20251130/spidroin_seeds_qc/AgSp1_CTD_de_dup.faa
# 2025-11-30 17:19:56.709 | INFO     | spider_silkome_module.features:run_shell_command_with_check:50 - Execute command: pixi run cd-hit -i /home/gyk/project/spider_silkome/data/interim/spider_silkome_20251130/spidroin_seeds_qc/TuSp_CySp_NTD_de_dup.faa -o /home/gyk/project/spider_silkome/data/interim/spider_silkome_20251130/spidroin_seeds_qc/TuSp_CySp_NTD_de_dup_de_dup.faa -c 0.95 -T 0 -M 0
# ================================================================
# Program: CD-HIT, V4.8.1 (+OpenMP), Apr 24 2025, 22:00:32
# Command:
#          /home/gyk/project/spider_silkome/.pixi/envs/default/bin/cd-hit
#          -i
#          /home/gyk/project/spider_silkome/data/interim/spider_silkome_20251130/spidroin_seeds_qc/TuSp_CySp_NTD_de_dup.faa
#          -o
#          /home/gyk/project/spider_silkome/data/interim/spider_silkome_20251130/spidroin_seeds_qc/TuSp_CySp_NTD_de_dup_de_dup.faa
#          -c 0.95 -T 0 -M 0
#
# Started: Sun Nov 30 17:19:56 2025
# ================================================================
#                             Output
# ----------------------------------------------------------------
# total number of CPUs in the system is 80
# Actual number of CPUs to be used: 80
#
# total seq: 122
# longest and shortest : 394 and 50
# Total letters: 18127
# Sequences have been sorted
#
# Approximated minimal memory consumption:
# Sequence        : 0M
# Buffer          : 80 X 16M = 1287M
# Table           : 2 X 65M = 130M
# Miscellaneous   : 0M
# Total           : 1417M
#
# Table limit with the given memory limit:
# Max number of representatives: 248606
# Max number of word counting entries: 8340571
#
# # comparing sequences from          0  to        122
# ---------- new table with      122 representatives
#
#       122  finished        122  clusters
#
# Approximated maximum memory consumption: 1417M
# writing new database
# writing clustering information
# program completed !
#
# Total CPU time 1.59
# 2025-11-30 17:19:58.021 | SUCCESS  | spider_silkome_module.features:run_shell_command_with_check:53 - Command executed successfully, output file: /home/gyk/project/spider_silkome/data/interim/spider_silkome_20251130/spidroin_seeds_qc/TuSp_CySp_NTD_de_dup_de_dup.faa
# 2025-11-30 17:19:58.021 | INFO     | spider_silkome_module.features:run_shell_command_with_check:50 - Execute command: pixi run cd-hit -i /home/gyk/project/spider_silkome/data/interim/spider_silkome_20251130/spidroin_seeds_qc/MaSp_CTD_de_dup.faa -o /home/gyk/project/spider_silkome/data/interim/spider_silkome_20251130/spidroin_seeds_qc/MaSp_CTD_de_dup_de_dup.faa -c 0.95 -T 0 -M 0
# ================================================================
# Program: CD-HIT, V4.8.1 (+OpenMP), Apr 24 2025, 22:00:32
# Command:
#          /home/gyk/project/spider_silkome/.pixi/envs/default/bin/cd-hit
#          -i
#          /home/gyk/project/spider_silkome/data/interim/spider_silkome_20251130/spidroin_seeds_qc/MaSp_CTD_de_dup.faa
#          -o
#          /home/gyk/project/spider_silkome/data/interim/spider_silkome_20251130/spidroin_seeds_qc/MaSp_CTD_de_dup_de_dup.faa
#          -c 0.95 -T 0 -M 0
#
# Started: Sun Nov 30 17:19:58 2025
# ================================================================
#                             Output
# ----------------------------------------------------------------
# total number of CPUs in the system is 80
# Actual number of CPUs to be used: 80
#
# total seq: 138
# longest and shortest : 504 and 50
# Total letters: 18979
# Sequences have been sorted
#
# Approximated minimal memory consumption:
# Sequence        : 0M
# Buffer          : 80 X 16M = 1289M
# Table           : 2 X 65M = 130M
# Miscellaneous   : 0M
# Total           : 1419M
#
# Table limit with the given memory limit:
# Max number of representatives: 248606
# Max number of word counting entries: 7846776
#
# # comparing sequences from          0  to        138
# ---------- new table with      138 representatives
#
#       138  finished        138  clusters
#
# Approximated maximum memory consumption: 1419M
# writing new database
# writing clustering information
# program completed !
#
# Total CPU time 1.58
# 2025-11-30 17:19:59.372 | SUCCESS  | spider_silkome_module.features:run_shell_command_with_check:53 - Command executed successfully, output file: /home/gyk/project/spider_silkome/data/interim/spider_silkome_20251130/spidroin_seeds_qc/MaSp_CTD_de_dup_de_dup.faa
# 2025-11-30 17:19:59.372 | INFO     | spider_silkome_module.features:run_shell_command_with_check:50 - Execute command: pixi run cd-hit -i /home/gyk/project/spider_silkome/data/interim/spider_silkome_20251130/spidroin_seeds_qc/AgSp2_CTD_de_dup.faa -o /home/gyk/project/spider_silkome/data/interim/spider_silkome_20251130/spidroin_seeds_qc/AgSp2_CTD_de_dup_de_dup.faa -c 0.95 -T 0 -M 0
# ================================================================
# Program: CD-HIT, V4.8.1 (+OpenMP), Apr 24 2025, 22:00:32
# ...
# total number of CPUs in the system is 80
# Actual number of CPUs to be used: 80
#
# total seq: 635
# longest and shortest : 1160 and 61
# Total letters: 117810
# Sequences have been sorted
#
# Approximated minimal memory consumption:
# Sequence        : 0M
# Buffer          : 80 X 16M = 1300M
# Table           : 2 X 65M = 130M
# Miscellaneous   : 0M
# Total           : 1431M
#
# Table limit with the given memory limit:
# Max number of representatives: 248606
# Max number of word counting entries: 8426527
#
# # comparing sequences from          0  to        635
# ---------- new table with      635 representatives
#
#       635  finished        635  clusters
#
# Approximated maximum memory consumption: 1432M
# writing new database
# writing clustering information
# program completed !
#
# Total CPU time 1.65
# 2025-11-30 17:20:17.762 | SUCCESS  | spider_silkome_module.features:run_shell_command_with_check:53 - Command executed successfully, output file: /home/gyk/project/spider_silkome/data/interim/spider_silkome_20251130/spidroin_seeds_qc/Other_NTD_de_dup_de_dup.faa
# 2025-11-30 17:20:17.762 | INFO     | spider_silkome_module.features:run_shell_command_with_check:46 - The output file already exists, skipping execution: /home/gyk/project/spider_silkome/data/interim/spider_silkome_20251130/spidroin_seeds_qc/MaSp2_NTD_de_dup.faa
# 2025-11-30 17:20:17.762 | INFO     | spider_silkome_module.features:run_shell_command_with_check:46 - The output file already exists, skipping execution: /home/gyk/project/spider_silkome/data/interim/spider_silkome_20251130/spidroin_seeds_qc/MaSp2_CTD_de_dup.faa
# 2025-11-30 17:20:17.763 | INFO     | spider_silkome_module.features:run_shell_command_with_check:50 - Execute command: pixi run cd-hit -i /home/gyk/project/spider_silkome/data/interim/spider_silkome_20251130/spidroin_seeds_qc/AgSp1_CTD_de_dup.faa -o /home/gyk/project/spider_silkome/data/interim/spider_silkome_20251130/spidroin_seeds_qc/AgSp1_CTD_de_dup_de_dup.faa -c 0.95 -T 0 -M 0
# ================================================================
# Program: CD-HIT, V4.8.1 (+OpenMP), Apr 24 2025, 22:00:32
# Command:
#          /home/gyk/project/spider_silkome/.pixi/envs/default/bin/cd-hit
#          -i
#          /home/gyk/project/spider_silkome/data/interim/spider_silkome_20251130/spidroin_seeds_qc/AgSp1_CTD_de_dup.faa
#          -o
#          /home/gyk/project/spider_silkome/data/interim/spider_silkome_20251130/spidroin_seeds_qc/AgSp1_CTD_de_dup_de_dup.faa
#          -c 0.95 -T 0 -M 0
#
# Started: Sun Nov 30 17:20:17 2025
# ================================================================
#                             Output
# ----------------------------------------------------------------
# total number of CPUs in the system is 80
# Actual number of CPUs to be used: 80
#
# total seq: 222
# longest and shortest : 1538 and 96
# Total letters: 82535
# Sequences have been sorted
#
# Approximated minimal memory consumption:
# Sequence        : 0M
# Buffer          : 80 X 16M = 1306M
# Table           : 2 X 65M = 130M
# Miscellaneous   : 0M
# Total           : 1437M
#
# Table limit with the given memory limit:
# Max number of representatives: 248606
# Max number of word counting entries: 19718807
#
# # comparing sequences from          0  to        222
# ---------- new table with      222 representatives
#
#       222  finished        222  clusters
#
# Approximated maximum memory consumption: 1438M
# writing new database
# writing clustering information
# program completed !
#
# Total CPU time 1.59
# 2025-11-30 17:20:19.092 | SUCCESS  | spider_silkome_module.features:run_shell_command_with_check:53 - Command executed successfully, output file: /home/gyk/project/spider_silkome/data/interim/spider_silkome_20251130/spidroin_seeds_qc/AgSp1_CTD_de_dup_de_dup.faa
# 2025-11-30 17:20:19.092 | INFO     | spider_silkome_module.features:run_shell_command_with_check:46 - The output file already exists, skipping execution: /home/gyk/project/spider_silkome/data/interim/spider_silkome_20251130/spidroin_seeds_qc/PySp_CTD_de_dup.faa
# 2025-11-30 17:20:19.093 | INFO     | spider_silkome_module.features:run_shell_command_with_check:50 - Execute command: pixi run cd-hit -i /home/gyk/project/spider_silkome/data/interim/spider_silkome_20251130/spidroin_seeds_qc/PySp_NTD_de_dup.faa -o /home/gyk/project/spider_silkome/data/interim/spider_silkome_20251130/spidroin_seeds_qc/PySp_NTD_de_dup_de_dup.faa -c 0.95 -T 0 -M 0
# ================================================================
# Program: CD-HIT, V4.8.1 (+OpenMP), Apr 24 2025, 22:00:32
# Command:
#          /home/gyk/project/spider_silkome/.pixi/envs/default/bin/cd-hit
#          -i
#          /home/gyk/project/spider_silkome/data/interim/spider_silkome_20251130/spidroin_seeds_qc/PySp_NTD_de_dup.faa
#          -o
#          /home/gyk/project/spider_silkome/data/interim/spider_silkome_20251130/spidroin_seeds_qc/PySp_NTD_de_dup_de_dup.faa
#          -c 0.95 -T 0 -M 0
#
# Started: Sun Nov 30 17:20:19 2025
# ================================================================
#                             Output
# ----------------------------------------------------------------
# total number of CPUs in the system is 80
# Actual number of CPUs to be used: 80
#
# total seq: 142
# longest and shortest : 398 and 100
# Total letters: 26116
# Sequences have been sorted
#
# Approximated minimal memory consumption:
# Sequence        : 0M
# Buffer          : 80 X 16M = 1287M
# Table           : 2 X 65M = 130M
# Miscellaneous   : 0M
# Total           : 1417M
#
# Table limit with the given memory limit:
# Max number of representatives: 248606
# Max number of word counting entries: 8993288
#
# # comparing sequences from          0  to        142
# ---------- new table with      142 representatives
#
#       142  finished        142  clusters
#
# Approximated maximum memory consumption: 1418M
# writing new database
# writing clustering information
# program completed !
#
# Total CPU time 1.56
# 2025-11-30 17:20:20.400 | SUCCESS  | spider_silkome_module.features:run_shell_command_with_check:53 - Command executed successfully, output file: /home/gyk/project/spider_silkome/data/interim/spider_silkome_20251130/spidroin_seeds_qc/PySp_NTD_de_dup_de_dup.faa
# 2025-11-30 17:20:20.400 | INFO     | spider_silkome_module.features:run_shell_command_with_check:50 - Execute command: pixi run cd-hit -i /home/gyk/project/spider_silkome/data/interim/spider_silkome_20251130/spidroin_seeds_qc/MaSp1_CTD_de_dup.faa -o /home/gyk/project/spider_silkome/data/interim/spider_silkome_20251130/spidroin_seeds_qc/MaSp1_CTD_de_dup_de_dup.faa -c 0.95 -T 0 -M 0
# ================================================================
# Program: CD-HIT, V4.8.1 (+OpenMP), Apr 24 2025, 22:00:32
# Command:
#          /home/gyk/project/spider_silkome/.pixi/envs/default/bin/cd-hit
#          -i
#          /home/gyk/project/spider_silkome/data/interim/spider_silkome_20251130/spidroin_seeds_qc/MaSp1_CTD_de_dup.faa
#          -o
#          /home/gyk/project/spider_silkome/data/interim/spider_silkome_20251130/spidroin_seeds_qc/MaSp1_CTD_de_dup_de_dup.faa
#          -c 0.95 -T 0 -M 0
#
# Started: Sun Nov 30 17:20:20 2025
# ================================================================
#                             Output
# ----------------------------------------------------------------
# total number of CPUs in the system is 80
# Actual number of CPUs to be used: 80
#
# total seq: 327
# longest and shortest : 524 and 52
# Total letters: 50437
# Sequences have been sorted
#
# Approximated minimal memory consumption:
# Sequence        : 0M
# Buffer          : 80 X 16M = 1289M
# Table           : 2 X 65M = 130M
# Miscellaneous   : 0M
# Total           : 1420M
#
# Table limit with the given memory limit:
# Max number of representatives: 248606
# Max number of word counting entries: 8189232
#
# # comparing sequences from          0  to        327
# ---------- new table with      327 representatives
#
#       327  finished        327  clusters
#
# Approximated maximum memory consumption: 1420M
# writing new database
# writing clustering information
# program completed !
#
# Total CPU time 1.65
# 2025-11-30 17:20:21.723 | SUCCESS  | spider_silkome_module.features:run_shell_command_with_check:53 - Command executed successfully, output file: /home/gyk/project/spider_silkome/data/interim/spider_silkome_20251130/spidroin_seeds_qc/MaSp1_CTD_de_dup_de_dup.faa
# 2025-11-30 17:20:21.724 | INFO     | spider_silkome_module.features:run_shell_command_with_check:46 - The output file already exists, skipping execution: /home/gyk/project/spider_silkome/data/interim/spider_silkome_20251130/spidroin_seeds_qc/MaSp3B_NTD_de_dup.faa
# 2025-11-30 17:20:21.724 | INFO     | spider_silkome_module.features:run_shell_command_with_check:46 - The output file already exists, skipping execution: /home/gyk/project/spider_silkome/data/interim/spider_silkome_20251130/spidroin_seeds_qc/MaSp_CTD_de_dup.faa
# 2025-11-30 17:20:21.724 | INFO     | spider_silkome_module.features:run_shell_command_with_check:46 - The output file already exists, skipping execution: /home/gyk/project/spider_silkome/data/interim/spider_silkome_20251130/spidroin_seeds_qc/AgSp2_NTD_de_dup.faa
# 2025-11-30 17:20:21.724 | INFO     | spider_silkome_module.features:run_shell_command_with_check:50 - Execute command: pixi run cd-hit -i /home/gyk/project/spider_silkome/data/interim/spider_silkome_20251130/spidroin_seeds_qc/MaSp3B_CTD_de_dup.faa -o /home/gyk/project/spider_silkome/data/interim/spider_silkome_20251130/spidroin_seeds_qc/MaSp3B_CTD_de_dup_de_dup.faa -c 0.95 -T 0 -M 0
# ================================================================
# Program: CD-HIT, V4.8.1 (+OpenMP), Apr 24 2025, 22:00:32
# Command:
#          /home/gyk/project/spider_silkome/.pixi/envs/default/bin/cd-hit
#          -i
#          /home/gyk/project/spider_silkome/data/interim/spider_silkome_20251130/spidroin_seeds_qc/MaSp3B_CTD_de_dup.faa
#          -o
#          /home/gyk/project/spider_silkome/data/interim/spider_silkome_20251130/spidroin_seeds_qc/MaSp3B_CTD_de_dup_de_dup.faa
#          -c 0.95 -T 0 -M 0
#
# Started: Sun Nov 30 17:20:21 2025
# ================================================================
#                             Output
# ----------------------------------------------------------------
# total number of CPUs in the system is 80
# Actual number of CPUs to be used: 80
#
# total seq: 12
# longest and shortest : 325 and 97
# Total letters: 1923
# Sequences have been sorted
#
# Approximated minimal memory consumption:
# Sequence        : 0M
# Buffer          : 80 X 16M = 1285M
# Table           : 2 X 65M = 130M
# Miscellaneous   : 0M
# Total           : 1416M
#
# Table limit with the given memory limit:
# Max number of representatives: 248606
# Max number of word counting entries: 8151972
#
# # comparing sequences from          0  to         12
# ---------- new table with       12 representatives
#
#        12  finished         12  clusters
#
# Approximated maximum memory consumption: 1416M
# writing new database
# writing clustering information
# program completed !
#
# Total CPU time 1.59
# 2025-11-30 17:20:23.033 | SUCCESS  | spider_silkome_module.features:run_shell_command_with_check:53 - Command executed successfully, output file: /home/gyk/project/spider_silkome/data/interim/spider_silkome_20251130/spidroin_seeds_qc/MaSp3B_CTD_de_dup_de_dup.faa
# 2025-11-30 17:20:23.034 | INFO     | spider_silkome_module.features:run_shell_command_with_check:46 - The output file already exists, skipping execution: /home/gyk/project/spider_silkome/data/interim/spider_silkome_20251130/spidroin_seeds_qc/Flag_CTD_de_dup.faa
# 2025-11-30 17:20:23.034 | INFO     | spider_silkome_module.features:run_shell_command_with_check:50 - Execute command: pixi run cd-hit -i /home/gyk/project/spider_silkome/data/interim/spider_silkome_20251130/spidroin_seeds_qc/Flag_NTD_de_dup.faa -o /home/gyk/project/spider_silkome/data/interim/spider_silkome_20251130/spidroin_seeds_qc/Flag_NTD_de_dup_de_dup.faa -c 0.95 -T 0 -M 0
# ================================================================
# Program: CD-HIT, V4.8.1 (+OpenMP), Apr 24 2025, 22:00:32
# Command:
#          /home/gyk/project/spider_silkome/.pixi/envs/default/bin/cd-hit
#          -i
#          /home/gyk/project/spider_silkome/data/interim/spider_silkome_20251130/spidroin_seeds_qc/Flag_NTD_de_dup.faa
#          -o
#          /home/gyk/project/spider_silkome/data/interim/spider_silkome_20251130/spidroin_seeds_qc/Flag_NTD_de_dup_de_dup.faa
#          -c 0.95 -T 0 -M 0
#
# Started: Sun Nov 30 17:20:23 2025
# ================================================================
#                             Output
# ----------------------------------------------------------------
# total number of CPUs in the system is 80
# Actual number of CPUs to be used: 80
#
# total seq: 139
# longest and shortest : 609 and 136
# Total letters: 26033
# Sequences have been sorted
#
# Approximated minimal memory consumption:
# Sequence        : 0M
# Buffer          : 80 X 16M = 1290M
# Table           : 2 X 65M = 130M
# Miscellaneous   : 0M
# Total           : 1421M
#
# Table limit with the given memory limit:
# Max number of representatives: 248606
# Max number of word counting entries: 8720163
#
# # comparing sequences from          0  to        139
# ---------- new table with      139 representatives
#
#       139  finished        139  clusters
#
# Approximated maximum memory consumption: 1421M
# writing new database
# writing clustering information
# program completed !
#
# Total CPU time 1.60
# 2025-11-30 17:20:24.360 | SUCCESS  | spider_silkome_module.features:run_shell_command_with_check:53 - Command executed successfully, output file: /home/gyk/project/spider_silkome/data/interim/spider_silkome_20251130/spidroin_seeds_qc/Flag_NTD_de_dup_de_dup.faa
# 2025-11-30 17:20:24.361 | INFO     | spider_silkome_module.features:run_shell_command_with_check:46 - The output file already exists, skipping execution: /home/gyk/project/spider_silkome/data/interim/spider_silkome_20251130/spidroin_seeds_qc/MaSp1_CTD_de_dup.faa
# 2025-11-30 17:20:24.361 | INFO     | spider_silkome_module.features:run_shell_command_with_check:50 - Execute command: pixi run cd-hit -i /home/gyk/project/spider_silkome/data/interim/spider_silkome_20251130/spidroin_seeds_qc/MaSp3_NTD_de_dup.faa -o /home/gyk/project/spider_silkome/data/interim/spider_silkome_20251130/spidroin_seeds_qc/MaSp3_NTD_de_dup_de_dup.faa -c 0.95 -T 0 -M 0
# ================================================================
# Program: CD-HIT, V4.8.1 (+OpenMP), Apr 24 2025, 22:00:32
# Command:
#          /home/gyk/project/spider_silkome/.pixi/envs/default/bin/cd-hit
#          -i
#          /home/gyk/project/spider_silkome/data/interim/spider_silkome_20251130/spidroin_seeds_qc/MaSp3_NTD_de_dup.faa
#          -o
#          /home/gyk/project/spider_silkome/data/interim/spider_silkome_20251130/spidroin_seeds_qc/MaSp3_NTD_de_dup_de_dup.faa
#          -c 0.95 -T 0 -M 0
#
# Started: Sun Nov 30 17:20:24 2025
# ================================================================
#                             Output
# ----------------------------------------------------------------
# total number of CPUs in the system is 80
# Actual number of CPUs to be used: 80
#
# total seq: 16
# longest and shortest : 485 and 122
# Total letters: 3791
# Sequences have been sorted
#
# Approximated minimal memory consumption:
# Sequence        : 0M
# Buffer          : 80 X 16M = 1288M
# Table           : 2 X 65M = 130M
# Miscellaneous   : 0M
# Total           : 1419M
#
# Table limit with the given memory limit:
# Max number of representatives: 248606
# Max number of word counting entries: 10953770
#
# # comparing sequences from          0  to         16
# ---------- new table with       16 representatives
#
#        16  finished         16  clusters
#
# Approximated maximum memory consumption: 1419M
# writing new database
# writing clustering information
# program completed !
#
# Total CPU time 1.55
# 2025-11-30 17:20:25.667 | SUCCESS  | spider_silkome_module.features:run_shell_command_with_check:53 - Command executed successfully, output file: /home/gyk/project/spider_silkome/data/interim/spider_silkome_20251130/spidroin_seeds_qc/MaSp3_NTD_de_dup_de_dup.faa

# %% [markdown]
# ## 2 多序列比对与pHMM构建
# 为了提高搜索的灵敏度，特别是针对远缘物种（如从圆网蛛到中纺亚目蜘蛛的跨越），必须构建Profile HMM。
#
# - 技术细节：
#   - 工具选择： HMMER 3.4 suite (hmmbuild)。
#   - 比对策略： 使用 MAFFT 的 L-INS-i 算法进行多序列比对（MSA）。该算法对捕捉局部结构特征（如NTD中的保守半胱氨酸残基或特定的α-螺旋结构）最为准确。
#
# - 模型训练：
#   - 构建亚家族特异性模型（如 MaSp_NTD.hmm）：用于精准分类。
#   - 构建泛蛛丝蛋白模型（如 PanSpidroin_NTD.hmm）：用于发现未分类或新型蛛丝蛋白（如  中提到的 Ectatosticta davidi 的 discordant spidroins）。
#
# - 校准： 使用 hmmpress 对模型进行二进制压缩与索引。

# %%
# 比对
for input_path in Config.SEEDS_QC_DIR.glob("*_de_dup.faa"):
    name = input_path.stem.split("_de")[0]
    mafft_output_path = Config.HMMBUILD_INPUT_DIR / f"{name}_aln.faa"
    mafft_cmd = f"mafft --maxiterate 1000 --localpair --thread -1 {input_path} > {mafft_output_path}"
    run_shell_command_with_check(mafft_cmd, mafft_output_path)
# Out:
# 2025-11-30 20:00:17.313 | INFO     | spider_silkome_module.features:run_shell_command_with_check:50 - Execute command: mafft --maxiterate 1000 --localpair --thread -1 /home/gyk/project/spider_silkome/data/interim/spider_silkome_20251130/spidroin_seeds_qc/AcSp_CTD_de_dup.faa > /home/gyk/project/spider_silkome/data/interim/spider_silkome_20251130/hmmbuild_input/AcSp_CTD_aln.faa
# OS = linux
# The number of physical cores =  40
# outputhat23=16
# treein = 0
# compacttree = 0
# stacksize: 8192 kb
# rescale = 1
# All-to-all alignment.
# tbfast-pair (aa) Version 7.526
# alg=L, model=BLOSUM62, 2.00, -0.10, +0.10, noshift, amax=0.0
# 40 thread(s)
#
# outputhat23=16
# Loading 'hat3.seed' ...
# done.
# Writing hat3 for iterative refinement
# rescale = 1
# Gap Penalty = -1.53, +0.00, +0.00
# tbutree = 1, compacttree = 0
# Constructing a UPGMA tree ...
#   550 / 561
# done.
#
# Progressive alignment ...
# STEP   512 /560 (thread   11)
# Reallocating (by thread 8) ..done. *alloclen = 4425
# STEP   547 /560 (thread    9)
# Reallocating (by thread 3) ..done. *alloclen = 5623
# STEP   560 /560 (thread    2)
# done.
# tbfast (aa) Version 7.526
# alg=A, model=BLOSUM62, 1.53, -0.00, -0.00, noshift, amax=0.0
# 16 thread(s)
#
# minimumweight = 0.000010
# autosubalignment = 0.000000
# nthread = 8
# randomseed = 0
# blosum 62 / kimura 200
# poffset = 0
# niter = 16
# sueff_global = 0.100000
# nadd = 16
# Loading 'hat3' ... done.
# rescale = 1
#
#   550 / 561
# Segment   1/  1    1-3371
# 004-1118-1 (thread    3) worse         001-0016-0 (thread    7) identical     001-0029-1 (thread    3) identical     001-0039-1 (thread    5) identical     001-0044-0 (thread    1) identical     001-0057-1 (thread    4) identical     001-0076-1 (thread    2) identical     001-0090-1 (thread    3) identical     001-0102-1 (thread    8) identical     001-0135-1 (thread    3) identical     001-0145-0 (thread    6) identical     001-0163-1 (thread    2) identical     001-0173-0 (thread    5) identical     001-0179-1 (thread    5) identical     001-0189-0 (thread    3) identical     001-0193-0 (thread    2) identical     001-0202-1 (thread    2) identical     001-0208-0 (thread    5) identical     001-0214-1 (thread    5) identical     001-0218-1 (thread    1) identical     001-0223-1 (thread    1) identical     001-0233-0 (thread    6) identical     001-0239-0 (thread    7) identical     001-0250-1 (thread    5) identical     001-0259-1 (thread    5) identical     001-0267-0 (thread    5) identical     001-0281-0 (thread    2) identical     001-0292-1 (thread    3) identical     001-0301-0 (thread    6) identical     001-0305-1 (thread    6) identical     001-0312-1 (thread    3) identical     001-0324-0 (thread    4) identical     001-0338-1 (thread    1) identical     001-0347-0 (thread    1) identical     001-0360-1 (thread    5) identical     001-0368-0 (thread    5) identical     001-0376-1 (thread    5) identical     001-0382-1 (thread    2) identical     001-0388-0 (thread    2) identical     001-0394-0 (thread    6) identical     001-0407-1 (thread    1) identical     001-0415-1 (thread    2) identical     001-0422-1 (thread    2) identical     001-0426-0 (thread    3) identical     001-0434-0 (thread    2) identical     001-0441-0 (thread    7) identical     001-0449-1 (thread    1) identical     001-0457-1 (thread    1) identical     001-0464-1 (thread    7) identical     001-0470-1 (thread    5) identical     001-0475-1 (thread    1) identical     001-0478-1 (thread    1) identical     001-0484-1 (thread    4) identical     001-0486-1 (thread    4) identical     001-0492-1 (thread    7) identical     001-0496-0 (thread    4) identical     001-0500-0 (thread    4) identical     001-0505-0 (thread    7) identical     001-0508-1 (thread    1) identical     001-0513-0 (thread    4) identical     001-0520-0 (thread    2) identical     001-0531-1 (thread    3) identical     001-0538-1 (thread    2) identical     001-0543-1 (thread    5) identical     001-0548-1 (thread    5) identical     001-0551-1 (thread    3) identical     001-0554-1 (thread    3) identical     001-0557-0 (thread    3) identical     001-0565-0 (thread    2) identical     001-0572-1 (thread    6) identical     001-0578-0 (thread    4) identical     001-0581-0 (thread    6) identical     001-0585-1 (thread    6) identical     001-0590-1 (thread    6) identical     001-0594-1 (thread    4) identical     001-0596-1 (thread    2) identical     001-0600-0 (thread    7) identical     001-0603-0 (thread    7) identical     001-0608-0 (thread    6) identical     001-0612-0 (thread    8) worse      001-0617-0 (thread    6) identical     001-0622-1 (thread    8) identical     001-0626-0 (thread    7) identical     001-0628-1 (thread    8) identical     001-0630-1 (thread    8) identical     001-0632-1 (thread    8) identical     001-0634-1 (thread    8) identical     001-0637-0 (thread    8) identical     001-0639-0 (thread    8) identical     001-0642-0 (thread    5) identical     001-0648-1 (thread    1) identical     001-0652-1 (thread    6) identical     001-0658-1 (thread    5) identical     001-0661-0 (thread    6) identical     001-0665-1 (thread    6) identical     001-0670-0 (thread    1) identical     001-0676-0 (thread    1) identical     001-0679-0 (thread    3) identical     001-0684-1 (thread    6) identical     001-0691-1 (thread    3) identical     001-0696-0 (thread    8) identical     001-0705-1 (thread    1) identical     001-0708-1 (thread    3)  ...
# Converged2.
# done
# dvtditr (aa) Version 7.526
# alg=A, model=BLOSUM62, 1.53, -0.00, -0.00, noshift, amax=0.0
# 8 thread(s)
#
#
# Strategy:
#  L-INS-i (Probably most accurate, very slow)
#  Iterative refinement method (<16) with LOCAL pairwise alignment information
#
# If unsure which option to use, try 'mafft --auto input > output'.
# For more information, see 'mafft --help', 'mafft --man' and the mafft page.
#
# The default gap scoring scheme has been changed in version 7.110 (2013 Oct).
# It tends to insert more gaps into gap-rich regions than previous versions.
# To disable this change, add the --leavegappyregion option.
#
# OS = linux
# The number of physical cores =  40
# 2025-11-30 20:04:43.835 | SUCCESS  | spider_silkome_module.features:run_shell_command_with_check:53 - Command executed successfully, output file: /home/gyk/project/spider_silkome/data/interim/spider_silkome_20251130/hmmbuild_input/AcSp_CTD_aln.faa
# 2025-11-30 20:04:43.836 | INFO     | spider_silkome_module.features:run_shell_command_with_check:50 - Execute command: mafft --maxiterate 1000 --localpair --thread -1 /home/gyk/project/spider_silkome/data/interim/spider_silkome_20251130/spidroin_seeds_qc/CrSp_CTD_de_dup.faa > /home/gyk/project/spider_silkome/data/interim/spider_silkome_20251130/hmmbuild_input/CrSp_CTD_aln.faa
# outputhat23=16
# treein = 0
# compacttree = 0
# stacksize: 8192 kb
# rescale = 1
# All-to-all alignment.
# tbfast-pair (aa) Version 7.526
# alg=L, model=BLOSUM62, 2.00, -0.10, +0.10, noshift, amax=0.0
# 40 thread(s)
#
# outputhat23=16
# Loading 'hat3.seed' ...
# done.
# Writing hat3 for iterative refinement
# rescale = 1
# Gap Penalty = -1.53, +0.00, +0.00
# tbutree = 1, compacttree = 0
# Constructing a UPGMA tree ...
#    20 / 30
# done.
#
# Progressive alignment ...
# STEP    29 /29 (thread    7)
# done.
# tbfast (aa) Version 7.526
# alg=A, model=BLOSUM62, 1.53, -0.00, -0.00, noshift, amax=0.0
# 16 thread(s)
#
# minimumweight = 0.000010
# autosubalignment = 0.000000
# nthread = 8
# randomseed = 0
# blosum 62 / kimura 200
# poffset = 0
# niter = 16
# sueff_global = 0.100000
# nadd = 16
# Loading 'hat3' ... done.
# rescale = 1
#
#    20 / 30
# Segment   1/  1    1-1735
# 003-0056-1 (thread    2) identical     001-0009-0 (thread    1) identical     001-0037-1 (thread    4) identical     001-0051-0 (thread    2) identical     002-0016-0 (thread    4) identical     002-0047-1 (thread    6) identical     003-0019-1 (thread    6) identical     003-0053-0 (thread    6) identical
# Converged2.
# done
# dvtditr (aa) Version 7.526
# alg=A, model=BLOSUM62, 1.53, -0.00, -0.00, noshift, amax=0.0
# 8 thread(s)
#
#
# Strategy:
#  L-INS-i (Probably most accurate, very slow)
#  Iterative refinement method (<16) with LOCAL pairwise alignment information
#
# If unsure which option to use, try 'mafft --auto input > output'.
# For more information, see 'mafft --help', 'mafft --man' and the mafft page.
#
# The default gap scoring scheme has been changed in version 7.110 (2013 Oct).
# It tends to insert more gaps into gap-rich regions than previous versions.
# To disable this change, add the --leavegappyregion option.
#
# OS = linux
# The number of physical cores =  40
# outputhat23=16
# treein = 0
# compacttree = 0
# stacksize: 8192 kb
# rescale = 1
# All-to-all alignment.
#     0 / 149 (by thread   0)
# 2025-11-30 20:04:46.195 | SUCCESS  | spider_silkome_module.features:run_shell_command_with_check:53 - Command executed successfully, output file: /home/gyk/project/spider_silkome/data/interim/spider_silkome_20251130/hmmbuild_input/CrSp_CTD_aln.faa
# 2025-11-30 20:04:46.195 | INFO     | spider_silkome_module.features:run_shell_command_with_check:50 - Execute command: mafft --maxiterate 1000 --localpair --thread -1 /home/gyk/project/spider_silkome/data/interim/spider_silkome_20251130/spidroin_seeds_qc/AgSp1_NTD_de_dup.faa > /home/gyk/project/spider_silkome/data/interim/spider_silkome_20251130/hmmbuild_input/AgSp1_NTD_aln.faa
# tbfast-pair (aa) Version 7.526
# alg=L, model=BLOSUM62, 2.00, -0.10, +0.10, noshift, amax=0.0
# 40 thread(s)
#
# outputhat23=16
# Loading 'hat3.seed' ...
# done.
# Writing hat3 for iterative refinement
# rescale = 1
# Gap Penalty = -1.53, +0.00, +0.00
# tbutree = 1, compacttree = 0
# Constructing a UPGMA tree ...
#   140 / 149
# done.
#
# Progressive alignment ...
# STEP   126 /148 (thread   15)
# Reallocating (by thread 0) ..done. *alloclen = 1711
# STEP   148 /148 (thread    1)
# done.
# tbfast (aa) Version 7.526
# alg=A, model=BLOSUM62, 1.53, -0.00, -0.00, noshift, amax=0.0
# 16 thread(s)
#
# minimumweight = 0.000010
# autosubalignment = 0.000000
# nthread = 8
# randomseed = 0
# blosum 62 / kimura 200
# poffset = 0
# niter = 16
# sueff_global = 0.100000
# nadd = 16
# Loading 'hat3' ... done.
# rescale = 1
#
#   140 / 149
# Segment   1/  1    1- 562
# 004-0294-0 (thread    2) identical     001-0037-1 (thread    3) identical     001-0246-0 (thread    4) identical     002-0111-1 (thread    3) identical     002-0274-0 (thread    2) identical     003-0242-1 (thread    5) identical     004-0203-1 (thread    5) identical
# Converged2.
# done
# dvtditr (aa) Version 7.526
# alg=A, model=BLOSUM62, 1.53, -0.00, -0.00, noshift, amax=0.0
# 8 thread(s)
#
#
# Strategy:
#  L-INS-i (Probably most accurate, very slow)
#  Iterative refinement method (<16) with LOCAL pairwise alignment information
#
# If unsure which option to use, try 'mafft --auto input > output'.
# For more information, see 'mafft --help', 'mafft --man' and the mafft page.
#
# The default gap scoring scheme has been changed in version 7.110 (2013 Oct).
# It tends to insert more gaps into gap-rich regions than previous versions.
# To disable this change, add the --leavegappyregion option.
# 2025-11-30 20:04:47.911 | SUCCESS  | spider_silkome_module.features:run_shell_command_with_check:53 - Command executed successfully, output file: /home/gyk/project/spider_silkome/data/interim/spider_silkome_20251130/hmmbuild_input/AgSp1_NTD_aln.faa
# 2025-11-30 20:04:47.912 | INFO     | spider_silkome_module.features:run_shell_command_with_check:50 - Execute command: mafft --maxiterate 1000 --localpair --thread -1 /home/gyk/project/spider_silkome/data/interim/spider_silkome_20251130/spidroin_seeds_qc/PanSpidroin_NTD_de_dup.faa > /home/gyk/project/spider_silkome/data/interim/spider_silkome_20251130/hmmbuild_input/PanSpidroin_NTD_aln.faa
# OS = linux
# The number of physical cores =  40
# outputhat23=16
# treein = 0
# compacttree = 0
# stacksize: 8192 kb
# rescale = 1
# All-to-all alignment.
# tbfast-pair (aa) Version 7.526
# alg=L, model=BLOSUM62, 2.00, -0.10, +0.10, noshift, amax=0.0
# 40 thread(s)
#
# outputhat23=16
# Loading 'hat3.seed' ...
# done.
# Writing hat3 for iterative refinement
# rescale = 1
# Gap Penalty = -1.53, +0.00, +0.00
# tbutree = 1, compacttree = 0
# Constructing a UPGMA tree ...
#  2980 / 2985
# done.
#
# Progressive alignment ...
# STEP  2901 /2984 (thread    4)
# Reallocating (by thread 2) ..done. *alloclen = 4165
#
# Reallocating (by thread 2) ..done. *alloclen = 5170
#
# done.
# tbfast (aa) Version 7.526
# alg=A, model=BLOSUM62, 1.53, -0.00, -0.00, noshift, amax=0.0
# 16 thread(s)
#
# minimumweight = 0.000010
# autosubalignment = 0.000000
# nthread = 8
# randomseed = 0
# blosum 62 / kimura 200
# poffset = 0
# niter = 16
# sueff_global = 0.100000
# nadd = 16
# Loading 'hat3' ... done.
# rescale = 1
#
#  2980 / 2985
# Segment   1/  1    1-3489
# 007-5964-0 (thread    3) worse         001-0008-1 (thread    7) identical     001-0009-1 (thread    4) identical     001-0014-1 (thread    5) identical     001-0017-0 (thread    6) identical     001-0021-0 (thread    3) identical     001-0022-0 (thread    5) identical     001-0025-1 (thread    6) identical     001-0029-1 (thread    3) identical     001-0030-0 (thread    5) identical     001-0031-1 (thread    7) identical     001-0035-1 (thread    2) identical     001-0037-0 (thread    4) identical     001-0043-0 (thread    1) identical     001-0045-0 (thread    5) identical     001-0049-1 (thread    3) identical     001-0053-1 (thread    5) identical     001-0057-0 (thread    6) identical     001-0063-0 (thread    4) identical     001-0065-1 (thread    6) identical     001-0067-0 (thread    1) identical     001-0071-0 (thread    8) identical     001-0075-1 (thread    1) identical     001-0079-1 (thread    8) identical     001-0083-1 (thread    1) identical     001-0087-1 (thread    6) identical     001-0090-0 (thread    4) identical     001-0091-1 (thread    1) identical     001-0093-0 (thread    5) identical     001-0100-1 (thread    1) identical     001-0101-1 (thread    5) identical     001-0106-1 (thread    2) identical     001-0109-1 (thread    5) identical     001-0113-0 (thread    7) identical     001-0117-1 (thread    5) identical     001-0119-0 (thread    6) identical     001-0124-0 (thread    2) identical     001-0129-0 (thread    1) identical     001-0131-1 (thread    8) identical     001-0132-0 (thread    5) identical     001-0137-1 (thread    1) identical     001-0139-1 (thread    8) identical     001-0140-0 (thread    5) identical     001-0145-1 (thread    1) identical     001-0146-1 (thread    6) identical     001-0151-0 (thread    7) identical     001-0155-0 (thread    6) identical     001-0159-1 (thread    7) identical     001-0161-0 (thread    8) identical     001-0165-1 (thread    6) identical     001-0169-1 (thread    8) identical     001-0173-0 (thread    1) identical     001-0177-1 (thread    8) identical     001-0181-0 (thread    6) identical     001-0185-1 (thread    8) identical     001-0189-1 (thread    6) identical     001-0193-1 (thread    8) identical     001-0197-0 (thread    2) identical     001-0201-0 (thread    5) identical     001-0205-1 (thread    2) identical     001-0209-1 (thread    5) identical     001-0213-1 (thread    2) identical     001-0217-1 (thread    5) identical     001-0220-0 (thread    6) identical     001-0225-1 (thread    5) identical     001-0227-1 (thread    8) identical     001-0230-0 (thread    3) identical     001-0233-1 (thread    5) identical     001-0234-0 (thread    4) identical     001-0238-0 (thread    3) identical     001-0241-1 (thread    5) identical     001-0247-1 (thread    2) identical     001-0249-0 (thread    3) identical     001-0252-1 (thread    1) identical     001-0256-1 (thread    6) identical     001-0259-1 (thread    4) identical     001-0262-0 (thread    2) identical     001-0264-1 (thread    2) identical     001-0269-1 (thread    4) identical     001-0271-0 (thread    1) identical     001-0272-1 (thread    3) identical     001-0279-1 (thread    1) identical     001-0280-0 (thread    3) identical     001-0285-0 (thread    6) identical     001-0289-0 (thread    3) identical     001-0293-1 (thread    6) identical     001-0297-1 (thread    3) identical     001-0300-0 (thread    7) identical     001-0301-1 (thread    6) identical     001-0305-1 (thread    3) identical     001-0306-0 (thread    5) identical     001-0313-0 (thread    8) identical     001-0316-1 (thread    3) identical     001-0320-1 (thread    4) identical     001-0325-0 (thread    3) identical     001-0328-0 (thread    4) identical     001-0333-0 (thread    6) identical     001-0335-1 (thread    2) identical     001-0336-0 (thread    4) identical     001-0338-1 (thread    5) identical     001-0344-0 (thread    3) identical     001-0345-0 (thread    4) identical     001-0346-0 (thread     ...
# Converged.
#
# Converged2.
# done
# dvtditr (aa) Version 7.526
# alg=A, model=BLOSUM62, 1.53, -0.00, -0.00, noshift, amax=0.0
# 8 thread(s)
#
#
# Strategy:
#  L-INS-i (Probably most accurate, very slow)
#  Iterative refinement method (<16) with LOCAL pairwise alignment information
#
# If unsure which option to use, try 'mafft --auto input > output'.
# For more information, see 'mafft --help', 'mafft --man' and the mafft page.
#
# The default gap scoring scheme has been changed in version 7.110 (2013 Oct).
# It tends to insert more gaps into gap-rich regions than previous versions.
# To disable this change, add the --leavegappyregion option.
# 2025-11-30 22:38:52.127 | SUCCESS  | spider_silkome_module.features:run_shell_command_with_check:53 - Command executed successfully, output file: /home/gyk/project/spider_silkome/data/interim/spider_silkome_20251130/hmmbuild_input/PanSpidroin_NTD_aln.faa
# 2025-11-30 22:38:52.128 | INFO     | spider_silkome_module.features:run_shell_command_with_check:50 - Execute command: mafft --maxiterate 1000 --localpair --thread -1 /home/gyk/project/spider_silkome/data/interim/spider_silkome_20251130/spidroin_seeds_qc/MaSp_NTD_de_dup.faa > /home/gyk/project/spider_silkome/data/interim/spider_silkome_20251130/hmmbuild_input/MaSp_NTD_aln.faa
# OS = linux
# The number of physical cores =  40
# outputhat23=16
# treein = 0
# compacttree = 0
# stacksize: 8192 kb
# rescale = 1
# All-to-all alignment.
# tbfast-pair (aa) Version 7.526
# alg=L, model=BLOSUM62, 2.00, -0.10, +0.10, noshift, amax=0.0
# 40 thread(s)
#
# outputhat23=16
# Loading 'hat3.seed' ...
# done.
# Writing hat3 for iterative refinement
# rescale = 1
# Gap Penalty = -1.53, +0.00, +0.00
# tbutree = 1, compacttree = 0
# Constructing a UPGMA tree ...
#   490 / 496
# done.
#
# Progressive alignment ...
# STEP   465 /495 (thread   10)
# Reallocating (by thread 4) ..done. *alloclen = 2595
# STEP   495 /495 (thread    8)
# done.
# tbfast (aa) Version 7.526
# alg=A, model=BLOSUM62, 1.53, -0.00, -0.00, noshift, amax=0.0
# 16 thread(s)
#
# minimumweight = 0.000010
# autosubalignment = 0.000000
# nthread = 8
# randomseed = 0
# blosum 62 / kimura 200
# poffset = 0
# niter = 16
# sueff_global = 0.100000
# nadd = 16
# Loading 'hat3' ... done.
# rescale = 1
#
#   490 / 496
# Segment   1/  1    1-1333
# 005-0988-0 (thread    1) worse         001-0064-0 (thread    1) identical     001-0111-1 (thread    5) identical     001-0159-0 (thread    1) identical     001-0223-1 (thread    8) identical     001-0271-1 (thread    4) identical     001-0317-1 (thread    2) identical     001-0390-0 (thread    1) identical     001-0421-0 (thread    6) identical     001-0449-0 (thread    3) identical     001-0486-0 (thread    3) identical     001-0519-1 (thread    3) identical     001-0554-0 (thread    1) identical     001-0585-1 (thread    1) identical     001-0602-1 (thread    7) identical     001-0623-0 (thread    2) identical     001-0659-0 (thread    1) better     001-0683-0 (thread    3) identical     001-0707-0 (thread    8) identical     001-0727-0 (thread    4) identical     001-0769-1 (thread    3) identical     001-0785-0 (thread    7) identical     001-0797-1 (thread    3) identical     001-0809-0 (thread    4) identical     001-0832-0 (thread    5) identical     001-0846-1 (thread    6) identical     001-0856-1 (thread    1) identical     001-0865-0 (thread    7) identical     001-0879-0 (thread    6) identical     001-0892-1 (thread    1) identical     001-0906-1 (thread    7) identical     001-0910-0 (thread    1) identical     001-0923-0 (thread    5) identical     001-0929-0 (thread    8) identical     001-0931-0 (thread    5) identical     001-0943-1 (thread    4) identical     001-0951-0 (thread    2) identical     001-0959-0 (thread    8) better     001-0967-1 (thread    7) identical     001-0973-0 (thread    7) identical     001-0987-0 (thread    4) identical     002-0039-1 (thread    2) identical     002-0099-1 (thread    6) identical     002-0142-1 (thread    8) identical     002-0214-1 (thread    8) identical     002-0268-0 (thread    7) identical     002-0320-1 (thread    1) identical     002-0377-1 (thread    7) identical     002-0418-0 (thread    7) identical     002-0469-1 (thread    8) identical     002-0508-0 (thread    2) identical     002-0556-0 (thread    7) identical     002-0606-1 (thread    3) identical     002-0640-0 (thread    2) identical     002-0685-0 (thread    8) identical     002-0707-1 (thread    2) identical     002-0731-1 (thread    4) identical     002-0760-1 (thread    3) identical     002-0786-1 (thread    4) identical     002-0800-0 (thread    5) identical     002-0812-1 (thread    7) identical     002-0827-0 (thread    2) identical     002-0845-0 (thread    5) identical     002-0862-1 (thread    4) identical     002-0900-1 (thread    3) identical     002-0913-0 (thread    5) worse      002-0923-0 (thread    5) worse      002-0926-1 (thread    4) identical     002-0939-1 (thread    2) identical     002-0948-0 (thread    6) identical     002-0955-0 (thread    1) identical     002-0985-0 (thread    8) identical     002-0988-0 (thread    2) identical     003-0040-1 (thread    4) identical     003-0108-0 (thread    3) identical     003-0181-1 (thread    8) worse      003-0248-1 (thread    5) identical     003-0317-1 (thread    1) identical     003-0372-1 (thread    5) identical     003-0479-0 (thread    5) identical     003-0535-1 (thread    6) identical     003-0587-0 (thread    6) identical     003-0639-0 (thread    8) identical     003-0661-0 (thread    2) worse      003-0875-1 (thread    3) identical     003-0891-1 (thread    3) identical     003-0909-0 (thread    7) identical     003-0919-0 (thread    7) identical     003-0930-0 (thread    7) worse      003-0937-0 (thread    8) identical     003-0950-0 (thread    8) identical     003-0963-1 (thread    3) identical     003-0988-1 (thread    4) identical     004-0063-1 (thread    5) identical     004-0132-0 (thread    1) identical     004-0208-0 (thread    2) identical     004-0277-0 (thread    5) identical     004-0347-0 (thread    6) identical     004-0399-0 (thread    2) identical     004-0460-0 (thread    8) identical     004-0518-1 (thread    3) identical     004-0577-1 (thread    6) identical     004-0620-0 (thread    4) identical     004- ...
# Converged2.
# done
# dvtditr (aa) Version 7.526
# alg=A, model=BLOSUM62, 1.53, -0.00, -0.00, noshift, amax=0.0
# 8 thread(s)
#
#
# Strategy:
#  L-INS-i (Probably most accurate, very slow)
#  Iterative refinement method (<16) with LOCAL pairwise alignment information
#
# If unsure which option to use, try 'mafft --auto input > output'.
# For more information, see 'mafft --help', 'mafft --man' and the mafft page.
#
# The default gap scoring scheme has been changed in version 7.110 (2013 Oct).
# It tends to insert more gaps into gap-rich regions than previous versions.
# To disable this change, add the --leavegappyregion option.
# 2025-11-30 22:39:28.960 | SUCCESS  | spider_silkome_module.features:run_shell_command_with_check:53 - Command executed successfully, output file: /home/gyk/project/spider_silkome/data/interim/spider_silkome_20251130/hmmbuild_input/MaSp_NTD_aln.faa
# 2025-11-30 22:39:28.961 | INFO     | spider_silkome_module.features:run_shell_command_with_check:50 - Execute command: mafft --maxiterate 1000 --localpair --thread -1 /home/gyk/project/spider_silkome/data/interim/spider_silkome_20251130/spidroin_seeds_qc/Other_CTD_de_dup.faa > /home/gyk/project/spider_silkome/data/interim/spider_silkome_20251130/hmmbuild_input/Other_CTD_aln.faa
# OS = linux
# The number of physical cores =  40
# outputhat23=16
# treein = 0
# compacttree = 0
# stacksize: 8192 kb
# rescale = 1
# All-to-all alignment.
# tbfast-pair (aa) Version 7.526
# alg=L, model=BLOSUM62, 2.00, -0.10, +0.10, noshift, amax=0.0
# 40 thread(s)
#
# outputhat23=16
# Loading 'hat3.seed' ...
# done.
# Writing hat3 for iterative refinement
# rescale = 1
# Gap Penalty = -1.53, +0.00, +0.00
# tbutree = 1, compacttree = 0
# Constructing a UPGMA tree ...
#   270 / 278
# done.
#
# Progressive alignment ...
# STEP   182 /277 (thread    3)
# Reallocating (by thread 7) ..done. *alloclen = 2125
# STEP   277 /277 (thread    8)
# done.
# tbfast (aa) Version 7.526
# alg=A, model=BLOSUM62, 1.53, -0.00, -0.00, noshift, amax=0.0
# 16 thread(s)
#
# minimumweight = 0.000010
# autosubalignment = 0.000000
# nthread = 8
# randomseed = 0
# blosum 62 / kimura 200
# poffset = 0
# niter = 16
# sueff_global = 0.100000
# nadd = 16
# Loading 'hat3' ... done.
# rescale = 1
#
#   270 / 278
# Segment   1/  1    1-1378
# 006-0552-0 (thread    7) worse         001-0060-1 (thread    4) identical     001-0094-1 (thread    5) identical     001-0133-1 (thread    7) identical     001-0162-0 (thread    4) identical     001-0195-0 (thread    3) identical     001-0223-1 (thread    1) identical     001-0242-1 (thread    7) identical     001-0261-1 (thread    8) identical     001-0289-1 (thread    3) identical     001-0302-1 (thread    3) identical     001-0318-1 (thread    1) identical     001-0328-1 (thread    8) identical     001-0330-1 (thread    8) identical     001-0363-0 (thread    5) identical     001-0376-0 (thread    6) identical     001-0387-0 (thread    4) identical     001-0401-0 (thread    2) identical     001-0407-0 (thread    5) identical     001-0419-0 (thread    3) identical     001-0421-0 (thread    7) identical     001-0443-1 (thread    3) identical     001-0455-0 (thread    3) identical     001-0477-1 (thread    4) identical     001-0489-0 (thread    4) identical     001-0499-0 (thread    6) identical     001-0509-1 (thread    5) identical     001-0521-0 (thread    5) identical     001-0539-0 (thread    2) identical     002-0075-0 (thread    4) identical     002-0122-0 (thread    5) identical     002-0149-0 (thread    4) identical     002-0175-1 (thread    8) identical     002-0217-0 (thread    1) identical     002-0257-1 (thread    4) identical     002-0283-0 (thread    5) identical     002-0306-0 (thread    3) identical     002-0336-0 (thread    8) identical     002-0365-0 (thread    6) identical     002-0389-0 (thread    2) identical     002-0417-0 (thread    8) identical     002-0434-1 (thread    3) identical     002-0450-1 (thread    8) identical     002-0455-0 (thread    8) identical     002-0465-0 (thread    8) identical     002-0473-0 (thread    3) identical     002-0483-1 (thread    1) identical     002-0500-1 (thread    7) identical     002-0526-0 (thread    7) identical     002-0551-1 (thread    8) identical     003-0062-0 (thread    5) identical     003-0100-0 (thread    3) identical     003-0184-0 (thread    6) identical     003-0223-1 (thread    8) identical     003-0264-1 (thread    2) identical     003-0295-0 (thread    5) identical     003-0304-0 (thread    2) identical     003-0329-1 (thread    6) identical     003-0371-0 (thread    5) identical     003-0407-0 (thread    3) identical     003-0427-0 (thread    3) identical     003-0439-0 (thread    2) identical     003-0458-1 (thread    1) identical     003-0483-1 (thread    2) identical     003-0503-0 (thread    7) identical     004-0061-1 (thread    2) identical     004-0116-1 (thread    8) identical     004-0169-1 (thread    6) identical     004-0262-1 (thread    5) identical     004-0298-0 (thread    6) identical     004-0319-1 (thread    7) identical     004-0365-1 (thread    8) identical     004-0415-0 (thread    1) identical     004-0427-0 (thread    5) identical     004-0442-1 (thread    4) identical     004-0450-1 (thread    6) identical     004-0476-1 (thread    7) identical     004-0491-0 (thread    8) worse      004-0543-1 (thread    6) identical     005-0035-0 (thread    8) identical     005-0098-0 (thread    1) identical     005-0155-0 (thread    1) identical     005-0209-1 (thread    1) identical     005-0255-0 (thread    1) identical     005-0294-1 (thread    3) identical     005-0323-0 (thread    1) identical     005-0371-1 (thread    7) identical     005-0396-0 (thread    3) worse      005-0420-0 (thread    5) identical     005-0434-1 (thread    6) identical     005-0440-1 (thread    5) identical     005-0460-1 (thread    4) identical     005-0478-0 (thread    7) worse      005-0498-1 (thread    2) identical     005-0518-1 (thread    6) identical     005-0543-1 (thread    3) identical     006-0059-0 (thread    5) identical     006-0162-0 (thread    8) identical     006-0207-0 (thread    4) identical     006-0257-0 (thread    4) identical     006-0294-1 (thread    6) identical     006-0332-1 (thread    2) identical     006-0368-0 (thread    5) identi ...
# Converged2.
# done
# dvtditr (aa) Version 7.526
# alg=A, model=BLOSUM62, 1.53, -0.00, -0.00, noshift, amax=0.0
# 8 thread(s)
#
#
# Strategy:
#  L-INS-i (Probably most accurate, very slow)
#  Iterative refinement method (<16) with LOCAL pairwise alignment information
#
# If unsure which option to use, try 'mafft --auto input > output'.
# For more information, see 'mafft --help', 'mafft --man' and the mafft page.
#
# The default gap scoring scheme has been changed in version 7.110 (2013 Oct).
# It tends to insert more gaps into gap-rich regions than previous versions.
# To disable this change, add the --leavegappyregion option.
# 2025-11-30 22:39:58.483 | SUCCESS  | spider_silkome_module.features:run_shell_command_with_check:53 - Command executed successfully, output file: /home/gyk/project/spider_silkome/data/interim/spider_silkome_20251130/hmmbuild_input/Other_CTD_aln.faa
# 2025-11-30 22:39:58.484 | INFO     | spider_silkome_module.features:run_shell_command_with_check:50 - Execute command: mafft --maxiterate 1000 --localpair --thread -1 /home/gyk/project/spider_silkome/data/interim/spider_silkome_20251130/spidroin_seeds_qc/pFlag_NTD_de_dup.faa > /home/gyk/project/spider_silkome/data/interim/spider_silkome_20251130/hmmbuild_input/pFlag_NTD_aln.faa
# 2025-11-30 22:39:58.655 | SUCCESS  | spider_silkome_module.features:run_shell_command_with_check:53 - Command executed successfully, output file: /home/gyk/project/spider_silkome/data/interim/spider_silkome_20251130/hmmbuild_input/pFlag_NTD_aln.faa
# 2025-11-30 22:39:58.655 | INFO     | spider_silkome_module.features:run_shell_command_with_check:50 - Execute command: mafft --maxiterate 1000 --localpair --thread -1 /home/gyk/project/spider_silkome/data/interim/spider_silkome_20251130/spidroin_seeds_qc/MaSp2_NTD_de_dup.faa > /home/gyk/project/spider_silkome/data/interim/spider_silkome_20251130/hmmbuild_input/MaSp2_NTD_aln.faa
# OS = linux
# The number of physical cores =  40
# outputhat23=16
# treein = 0
# compacttree = 0
# Warning: Only 1 sequence found.
# minimumweight = 0.000010
# autosubalignment = 0.000000
# nthread = 8
# randomseed = 0
# blosum 62 / kimura 200
# poffset = 0
# niter = 16
# sueff_global = 0.100000
# nadd = 16
# Warning: Only 1 sequence found.
#
# Strategy:
#  L-INS-i (Probably most accurate, very slow)
#  Iterative refinement method (<16) with LOCAL pairwise alignment information
#
# If unsure which option to use, try 'mafft --auto input > output'.
# For more information, see 'mafft --help', 'mafft --man' and the mafft page.
#
# The default gap scoring scheme has been changed in version 7.110 (2013 Oct).
# It tends to insert more gaps into gap-rich regions than previous versions.
# To disable this change, add the --leavegappyregion option.
#
# OS = linux
# The number of physical cores =  40
# outputhat23=16
# treein = 0
# compacttree = 0
# stacksize: 8192 kb
# rescale = 1
# All-to-all alignment.
# tbfast-pair (aa) Version 7.526
# alg=L, model=BLOSUM62, 2.00, -0.10, +0.10, noshift, amax=0.0
# 40 thread(s)
#
# outputhat23=16
# Loading 'hat3.seed' ...
# done.
# Writing hat3 for iterative refinement
# rescale = 1
# Gap Penalty = -1.53, +0.00, +0.00
# tbutree = 1, compacttree = 0
# Constructing a UPGMA tree ...
#   110 / 116
# done.
#
# Progressive alignment ...
# STEP   114 /115 (thread   14)
# Reallocating (by thread 13) ..done. *alloclen = 1744
# STEP   115 /115 (thread   13)
# done.
# tbfast (aa) Version 7.526
# alg=A, model=BLOSUM62, 1.53, -0.00, -0.00, noshift, amax=0.0
# 16 thread(s)
#
# minimumweight = 0.000010
# autosubalignment = 0.000000
# nthread = 8
# randomseed = 0
# blosum 62 / kimura 200
# poffset = 0
# niter = 16
# sueff_global = 0.100000
# nadd = 16
# Loading 'hat3' ... done.
# rescale = 1
#
#   110 / 116
# Segment   1/  1    1- 443
# 004-0228-1 (thread    1) worse         002-0201-0 (thread    3) identical
# Converged.
#
# Converged2.
# done
# dvtditr (aa) Version 7.526
# alg=A, model=BLOSUM62, 1.53, -0.00, -0.00, noshift, amax=0.0
# 8 thread(s)
#
#
# Strategy:
#  L-INS-i (Probably most accurate, very slow)
#  Iterative refinement method (<16) with LOCAL pairwise alignment information
#
# If unsure which option to use, try 'mafft --auto input > output'.
# For more information, see 'mafft --help', 'mafft --man' and the mafft page.
#
# The default gap scoring scheme has been changed in version 7.110 (2013 Oct).
# It tends to insert more gaps into gap-rich regions than previous versions.
# To disable this change, add the --leavegappyregion option.
# 2025-11-30 22:39:59.430 | SUCCESS  | spider_silkome_module.features:run_shell_command_with_check:53 - Command executed successfully, output file: /home/gyk/project/spider_silkome/data/interim/spider_silkome_20251130/hmmbuild_input/MaSp2_NTD_aln.faa
# 2025-11-30 22:39:59.431 | INFO     | spider_silkome_module.features:run_shell_command_with_check:50 - Execute command: mafft --maxiterate 1000 --localpair --thread -1 /home/gyk/project/spider_silkome/data/interim/spider_silkome_20251130/spidroin_seeds_qc/TuSp_CySp_CTD_de_dup.faa > /home/gyk/project/spider_silkome/data/interim/spider_silkome_20251130/hmmbuild_input/TuSp_CySp_CTD_aln.faa
# OS = linux
# The number of physical cores =  40
# outputhat23=16
# treein = 0
# compacttree = 0
# stacksize: 8192 kb
# rescale = 1
# All-to-all alignment.
# tbfast-pair (aa) Version 7.526
# alg=L, model=BLOSUM62, 2.00, -0.10, +0.10, noshift, amax=0.0
# 40 thread(s)
#
# outputhat23=16
# Loading 'hat3.seed' ...
# done.
# Writing hat3 for iterative refinement
# rescale = 1
# Gap Penalty = -1.53, +0.00, +0.00
# tbutree = 1, compacttree = 0
# Constructing a UPGMA tree ...
#   180 / 191
# done.
#
# Progressive alignment ...
# STEP   186 /190 (thread    3)
# Reallocating (by thread 5) ..done. *alloclen = 2171
# STEP   190 /190 (thread    9)
# done.
# tbfast (aa) Version 7.526
# alg=A, model=BLOSUM62, 1.53, -0.00, -0.00, noshift, amax=0.0
# 16 thread(s)
#
# minimumweight = 0.000010
# autosubalignment = 0.000000
# nthread = 8
# randomseed = 0
# blosum 62 / kimura 200
# poffset = 0
# niter = 16
# sueff_global = 0.100000
# nadd = 16
# Loading 'hat3' ... done.
# rescale = 1
#
#   180 / 191
# Segment   1/  1    1- 859
# 003-0378-0 (thread    5) identical     001-0160-0 (thread    4) identical     001-0233-1 (thread    2) identical     001-0271-0 (thread    2) identical     001-0297-0 (thread    1) identical     001-0338-1 (thread    4) identical     001-0359-1 (thread    2) identical     001-0372-0 (thread    5) identical     002-0084-1 (thread    2) identical     002-0195-0 (thread    6) identical     002-0251-1 (thread    7) identical     002-0290-0 (thread    8) identical     002-0326-1 (thread    4) identical     003-0115-0 (thread    2) identical     003-0233-0 (thread    3) identical     003-0279-0 (thread    3) identical     003-0333-0 (thread    5) identical     003-0374-1 (thread    7) identical
# Converged2.
# done
# dvtditr (aa) Version 7.526
# alg=A, model=BLOSUM62, 1.53, -0.00, -0.00, noshift, amax=0.0
# 8 thread(s)
#
#
# Strategy:
#  L-INS-i (Probably most accurate, very slow)
#  Iterative refinement method (<16) with LOCAL pairwise alignment information
#
# If unsure which option to use, try 'mafft --auto input > output'.
# For more information, see 'mafft --help', 'mafft --man' and the mafft page.
#
# The default gap scoring scheme has been changed in version 7.110 (2013 Oct).
# It tends to insert more gaps into gap-rich regions than previous versions.
# To disable this change, add the --leavegappyregion option.
#
# OS = linux
# The number of physical cores =  40
# outputhat23=16
# treein = 0
# compacttree = 0
# stacksize: 8192 kb
# 2025-11-30 22:40:04.361 | SUCCESS  | spider_silkome_module.features:run_shell_command_with_check:53 - Command executed successfully, output file: /home/gyk/project/spider_silkome/data/interim/spider_silkome_20251130/hmmbuild_input/TuSp_CySp_CTD_aln.faa
# 2025-11-30 22:40:04.361 | INFO     | spider_silkome_module.features:run_shell_command_with_check:50 - Execute command: mafft --maxiterate 1000 --localpair --thread -1 /home/gyk/project/spider_silkome/data/interim/spider_silkome_20251130/spidroin_seeds_qc/MaSp2_CTD_de_dup.faa > /home/gyk/project/spider_silkome/data/interim/spider_silkome_20251130/hmmbuild_input/MaSp2_CTD_aln.faa
# rescale = 1
# All-to-all alignment.
# tbfast-pair (aa) Version 7.526
# alg=L, model=BLOSUM62, 2.00, -0.10, +0.10, noshift, amax=0.0
# 40 thread(s)
#
# outputhat23=16
# Loading 'hat3.seed' ...
# done.
# Writing hat3 for iterative refinement
# rescale = 1
# Gap Penalty = -1.53, +0.00, +0.00
# tbutree = 1, compacttree = 0
# Constructing a UPGMA tree ...
#   270 / 274
# done.
#
# Progressive alignment ...
# STEP   266 /273 (thread    0)
# Reallocating (by thread 7) ..done. *alloclen = 2474
# STEP   273 /273 (thread   10)
# done.
# tbfast (aa) Version 7.526
# alg=A, model=BLOSUM62, 1.53, -0.00, -0.00, noshift, amax=0.0
# 16 thread(s)
#
# minimumweight = 0.000010
# autosubalignment = 0.000000
# nthread = 8
# randomseed = 0
# blosum 62 / kimura 200
# poffset = 0
# niter = 16
# sueff_global = 0.100000
# nadd = 16
# Loading 'hat3' ... done.
# rescale = 1
#
#   270 / 274
# Segment   1/  1    1-1329
# 003-0543-0 (thread    5) better        001-0061-0 (thread    5) identical     001-0109-1 (thread    1) identical     001-0166-0 (thread    4) identical     001-0205-0 (thread    2) identical     001-0238-1 (thread    3) identical     001-0276-1 (thread    6) identical     001-0303-1 (thread    3) identical     001-0331-0 (thread    6) identical     001-0361-0 (thread    2) identical     001-0379-1 (thread    5) identical     001-0393-0 (thread    1) identical     001-0411-1 (thread    8) identical     001-0426-1 (thread    6) identical     001-0441-0 (thread    7) identical     001-0452-1 (thread    3) identical     001-0467-1 (thread    2) identical     001-0476-0 (thread    3) identical     001-0484-1 (thread    4) identical     001-0495-0 (thread    8) identical     001-0501-0 (thread    1) identical     001-0511-0 (thread    3) worse      001-0524-1 (thread    6) identical     002-0025-1 (thread    8) identical     002-0099-1 (thread    8) identical     002-0165-1 (thread    7) identical     002-0226-0 (thread    7) identical     002-0266-1 (thread    6) identical     002-0341-0 (thread    1) identical     002-0368-0 (thread    6) identical     002-0407-1 (thread    4) identical     002-0452-1 (thread    2) identical     002-0463-1 (thread    2) identical     002-0478-0 (thread    6) identical     002-0498-1 (thread    1) identical     002-0517-0 (thread    6) identical     002-0526-0 (thread    6) identical     002-0533-0 (thread    6) identical     002-0539-0 (thread    6) identical     002-0543-0 (thread    5) identical     003-0019-0 (thread    8) identical     003-0098-1 (thread    1) identical     003-0181-1 (thread    7) better     003-0238-0 (thread    2) identical     003-0272-1 (thread    7) identical     003-0422-1 (thread    2) identical     003-0451-0 (thread    3) identical     003-0491-1 (thread    6) identical     003-0512-1 (thread    1) identical     003-0526-1 (thread    4) identical     003-0544-1 (thread    2) worse
# Converged2.
# done
# dvtditr (aa) Version 7.526
# alg=A, model=BLOSUM62, 1.53, -0.00, -0.00, noshift, amax=0.0
# 8 thread(s)
#
#
# Strategy:
#  L-INS-i (Probably most accurate, very slow)
#  Iterative refinement method (<16) with LOCAL pairwise alignment information
#
# If unsure which option to use, try 'mafft --auto input > output'.
# For more information, see 'mafft --help', 'mafft --man' and the mafft page.
#
# The default gap scoring scheme has been changed in version 7.110 (2013 Oct).
# It tends to insert more gaps into gap-rich regions than previous versions.
# To disable this change, add the --leavegappyregion option.
#
# OS = linux
# The number of physical cores =  40
# 2025-11-30 22:40:18.301 | SUCCESS  | spider_silkome_module.features:run_shell_command_with_check:53 - Command executed successfully, output file: /home/gyk/project/spider_silkome/data/interim/spider_silkome_20251130/hmmbuild_input/MaSp2_CTD_aln.faa
# 2025-11-30 22:40:18.302 | INFO     | spider_silkome_module.features:run_shell_command_with_check:50 - Execute command: mafft --maxiterate 1000 --localpair --thread -1 /home/gyk/project/spider_silkome/data/interim/spider_silkome_20251130/spidroin_seeds_qc/MaSp1_NTD_de_dup.faa > /home/gyk/project/spider_silkome/data/interim/spider_silkome_20251130/hmmbuild_input/MaSp1_NTD_aln.faa
# outputhat23=16
# treein = 0
# compacttree = 0
# stacksize: 8192 kb
# rescale = 1
# All-to-all alignment.
# tbfast-pair (aa) Version 7.526
# alg=L, model=BLOSUM62, 2.00, -0.10, +0.10, noshift, amax=0.0
# 40 thread(s)
#
# outputhat23=16
# Loading 'hat3.seed' ...
# done.
# Writing hat3 for iterative refinement
# rescale = 1
# Gap Penalty = -1.53, +0.00, +0.00
# tbutree = 1, compacttree = 0
# Constructing a UPGMA tree ...
#   280 / 284
# done.
#
# Progressive alignment ...
# STEP   262 /283 (thread   13)
# Reallocating (by thread 8) ..done. *alloclen = 2083
# STEP   283 /283 (thread    9)
# done.
# tbfast (aa) Version 7.526
# alg=A, model=BLOSUM62, 1.53, -0.00, -0.00, noshift, amax=0.0
# 16 thread(s)
#
# minimumweight = 0.000010
# autosubalignment = 0.000000
# nthread = 8
# randomseed = 0
# blosum 62 / kimura 200
# poffset = 0
# niter = 16
# sueff_global = 0.100000
# nadd = 16
# Loading 'hat3' ... done.
# rescale = 1
#
#   280 / 284
# Segment   1/  1    1- 953
# 005-0564-0 (thread    7) identical     001-0131-1 (thread    8) identical     001-0234-1 (thread    8) identical     001-0330-0 (thread    5) identical     001-0390-1 (thread    5) identical     001-0440-1 (thread    5) identical     001-0481-1 (thread    8) identical     001-0544-1 (thread    3) identical     001-0564-1 (thread    5) identical     002-0245-0 (thread    5) identical     002-0406-0 (thread    1) identical     002-0471-0 (thread    6) identical     002-0507-0 (thread    2) identical     002-0525-0 (thread    6) identical     002-0562-0 (thread    6) identical     003-0100-0 (thread    7) identical     003-0339-0 (thread    4) identical     003-0462-0 (thread    4) identical     003-0509-0 (thread    7) worse      003-0530-1 (thread    4) identical     003-0564-1 (thread    1) better     004-0270-0 (thread    5) worse      004-0451-0 (thread    5) identical     004-0504-0 (thread    8) identical     004-0528-1 (thread    7) identical     004-0560-0 (thread    8) identical     005-0034-1 (thread    3) identical     005-0188-0 (thread    7) identical     005-0313-0 (thread    4) worse      005-0403-0 (thread    5) better     005-0468-0 (thread    6) worse      005-0549-1 (thread    4) identical
# Converged2.
# done
# dvtditr (aa) Version 7.526
# alg=A, model=BLOSUM62, 1.53, -0.00, -0.00, noshift, amax=0.0
# 8 thread(s)
#
#
# Strategy:
#  L-INS-i (Probably most accurate, very slow)
#  Iterative refinement method (<16) with LOCAL pairwise alignment information
#
# If unsure which option to use, try 'mafft --auto input > output'.
# For more information, see 'mafft --help', 'mafft --man' and the mafft page.
#
# The default gap scoring scheme has been changed in version 7.110 (2013 Oct).
# It tends to insert more gaps into gap-rich regions than previous versions.
# To disable this change, add the --leavegappyregion option.
#
# OS = linux
# The number of physical cores =  40
# 2025-11-30 22:40:27.988 | SUCCESS  | spider_silkome_module.features:run_shell_command_with_check:53 - Command executed successfully, output file: /home/gyk/project/spider_silkome/data/interim/spider_silkome_20251130/hmmbuild_input/MaSp1_NTD_aln.faa
# 2025-11-30 22:40:27.988 | INFO     | spider_silkome_module.features:run_shell_command_with_check:50 - Execute command: mafft --maxiterate 1000 --localpair --thread -1 /home/gyk/project/spider_silkome/data/interim/spider_silkome_20251130/spidroin_seeds_qc/TuSp_CySp_NTD_de_dup.faa > /home/gyk/project/spider_silkome/data/interim/spider_silkome_20251130/hmmbuild_input/TuSp_CySp_NTD_aln.faa
# outputhat23=16
# treein = 0
# compacttree = 0
# stacksize: 8192 kb
# rescale = 1
# All-to-all alignment.
# tbfast-pair (aa) Version 7.526
# alg=L, model=BLOSUM62, 2.00, -0.10, +0.10, noshift, amax=0.0
# 40 thread(s)
#
# outputhat23=16
# Loading 'hat3.seed' ...
# done.
# Writing hat3 for iterative refinement
# rescale = 1
# Gap Penalty = -1.53, +0.00, +0.00
# tbutree = 1, compacttree = 0
# Constructing a UPGMA tree ...
#   120 / 122
# done.
#
# Progressive alignment ...
# STEP   121 /121 (thread    3)
# done.
# tbfast (aa) Version 7.526
# alg=A, model=BLOSUM62, 1.53, -0.00, -0.00, noshift, amax=0.0
# 16 thread(s)
#
# minimumweight = 0.000010
# autosubalignment = 0.000000
# nthread = 8
# randomseed = 0
# blosum 62 / kimura 200
# poffset = 0
# niter = 16
# sueff_global = 0.100000
# nadd = 16
# Loading 'hat3' ... done.
# rescale = 1
#
#   120 / 122
# Segment   1/  1    1- 508
# 005-0240-0 (thread    8) identical     001-0175-1 (thread    7) identical     002-0183-1 (thread    5) identical     003-0236-0 (thread    8) identical     005-0161-1 (thread    8) identical
# Converged2.
# done
# dvtditr (aa) Version 7.526
# alg=A, model=BLOSUM62, 1.53, -0.00, -0.00, noshift, amax=0.0
# 8 thread(s)
#
#
# Strategy:
#  L-INS-i (Probably most accurate, very slow)
#  Iterative refinement method (<16) with LOCAL pairwise alignment information
#
# If unsure which option to use, try 'mafft --auto input > output'.
# For more information, see 'mafft --help', 'mafft --man' and the mafft page.
#
# The default gap scoring scheme has been changed in version 7.110 (2013 Oct).
# It tends to insert more gaps into gap-rich regions than previous versions.
# To disable this change, add the --leavegappyregion option.
#
# OS = linux
# The number of physical cores =  40
# 2025-11-30 22:40:29.239 | SUCCESS  | spider_silkome_module.features:run_shell_command_with_check:53 - Command executed successfully, output file: /home/gyk/project/spider_silkome/data/interim/spider_silkome_20251130/hmmbuild_input/TuSp_CySp_NTD_aln.faa
# 2025-11-30 22:40:29.239 | INFO     | spider_silkome_module.features:run_shell_command_with_check:50 - Execute command: mafft --maxiterate 1000 --localpair --thread -1 /home/gyk/project/spider_silkome/data/interim/spider_silkome_20251130/spidroin_seeds_qc/MaSp_CTD_de_dup.faa > /home/gyk/project/spider_silkome/data/interim/spider_silkome_20251130/hmmbuild_input/MaSp_CTD_aln.faa
# outputhat23=16
# treein = 0
# compacttree = 0
# stacksize: 8192 kb
# rescale = 1
# All-to-all alignment.
# tbfast-pair (aa) Version 7.526
# alg=L, model=BLOSUM62, 2.00, -0.10, +0.10, noshift, amax=0.0
# 40 thread(s)
#
# outputhat23=16
# Loading 'hat3.seed' ...
# done.
# Writing hat3 for iterative refinement
# rescale = 1
# Gap Penalty = -1.53, +0.00, +0.00
# tbutree = 1, compacttree = 0
# Constructing a UPGMA tree ...
#   130 / 138
# done.
#
# Progressive alignment ...
# STEP   100 /137 (thread   15)
# STEP   126 /137 (thread   15) done. *alloclen = 2101
# STEP   137 /137 (thread   10)
# done.
# tbfast (aa) Version 7.526
# alg=A, model=BLOSUM62, 1.53, -0.00, -0.00, noshift, amax=0.0
# 16 thread(s)
#
# minimumweight = 0.000010
# autosubalignment = 0.000000
# nthread = 8
# randomseed = 0
# blosum 62 / kimura 200
# poffset = 0
# niter = 16
# sueff_global = 0.100000
# nadd = 16
# Loading 'hat3' ... done.
# rescale = 1
#
#   130 / 138
# Segment   1/  1    1- 911
# 003-0272-0 (thread    4) identical     001-0118-1 (thread    6) identical     001-0262-1 (thread    8) identical     002-0177-1 (thread    3) identical     002-0245-0 (thread    2) identical     003-0113-1 (thread    5) identical     003-0223-0 (thread    6) identical
# Converged2.
# done
# dvtditr (aa) Version 7.526
# alg=A, model=BLOSUM62, 1.53, -0.00, -0.00, noshift, amax=0.0
# 8 thread(s)
#
#
# Strategy:
#  L-INS-i (Probably most accurate, very slow)
# ...
# Converged2.
# done
# dvtditr (aa) Version 7.526
# alg=A, model=BLOSUM62, 1.53, -0.00, -0.00, noshift, amax=0.0
# 8 thread(s)
#
#
# Strategy:
#  L-INS-i (Probably most accurate, very slow)
#  Iterative refinement method (<16) with LOCAL pairwise alignment information
#
# If unsure which option to use, try 'mafft --auto input > output'.
# For more information, see 'mafft --help', 'mafft --man' and the mafft page.
#
# The default gap scoring scheme has been changed in version 7.110 (2013 Oct).
# It tends to insert more gaps into gap-rich regions than previous versions.
# To disable this change, add the --leavegappyregion option.
#
# OS = linux
# The number of physical cores =  40
# outputhat23=16
# treein = 0
# compacttree = 0
# stacksize: 8192 kb
# 2025-11-30 22:40:46.812 | SUCCESS  | spider_silkome_module.features:run_shell_command_with_check:53 - Command executed successfully, output file: /home/gyk/project/spider_silkome/data/interim/spider_silkome_20251130/hmmbuild_input/AcSp_NTD_aln.faa
# 2025-11-30 22:40:46.812 | INFO     | spider_silkome_module.features:run_shell_command_with_check:50 - Execute command: mafft --maxiterate 1000 --localpair --thread -1 /home/gyk/project/spider_silkome/data/interim/spider_silkome_20251130/spidroin_seeds_qc/MiSp_NTD_de_dup.faa > /home/gyk/project/spider_silkome/data/interim/spider_silkome_20251130/hmmbuild_input/MiSp_NTD_aln.faa
# rescale = 1
# All-to-all alignment.
# tbfast-pair (aa) Version 7.526
# alg=L, model=BLOSUM62, 2.00, -0.10, +0.10, noshift, amax=0.0
# 40 thread(s)
#
# outputhat23=16
# Loading 'hat3.seed' ...
# done.
# Writing hat3 for iterative refinement
# rescale = 1
# Gap Penalty = -1.53, +0.00, +0.00
# tbutree = 1, compacttree = 0
# Constructing a UPGMA tree ...
#   660 / 667
# done.
#
# Progressive alignment ...
# STEP   666 /666 (thread    1)
# done.
# tbfast (aa) Version 7.526
# alg=A, model=BLOSUM62, 1.53, -0.00, -0.00, noshift, amax=0.0
# 16 thread(s)
#
# minimumweight = 0.000010
# autosubalignment = 0.000000
# nthread = 8
# randomseed = 0
# blosum 62 / kimura 200
# poffset = 0
# niter = 16
# sueff_global = 0.100000
# nadd = 16
# Loading 'hat3' ... done.
# rescale = 1
#
#   660 / 667
# Segment   1/  1    1- 820
# 005-1330-1 (thread    5) worse         001-0086-0 (thread    3) identical     001-0173-1 (thread    7) identical     001-0239-0 (thread    5) worse      001-0306-0 (thread    4) identical     001-0344-1 (thread    5) identical     001-0412-1 (thread    2) identical     001-0444-0 (thread    8) identical     001-0507-0 (thread    2) identical     001-0539-0 (thread    7) identical     001-0572-1 (thread    4) identical     001-0608-1 (thread    2) identical     001-0642-0 (thread    1) identical     001-0668-1 (thread    2) identical     001-0705-1 (thread    2) identical     001-0744-1 (thread    8) identical     001-0780-1 (thread    2) identical     001-0809-0 (thread    1) identical     001-0839-1 (thread    2) identical     001-0871-1 (thread    7) identical     001-0892-1 (thread    7) identical     001-0923-1 (thread    5) identical     001-0952-0 (thread    5) identical     001-0978-1 (thread    6) identical     001-0997-1 (thread    5) identical     001-1009-0 (thread    5) identical     001-1021-0 (thread    8) worse      001-1038-1 (thread    2) identical     001-1047-0 (thread    5) identical     001-1104-0 (thread    7) worse      001-1122-1 (thread    1) identical     001-1138-1 (thread    1) identical     001-1152-1 (thread    6) identical     001-1163-0 (thread    8) identical     001-1173-0 (thread    7) worse      001-1185-0 (thread    1) worse      001-1188-1 (thread    3) identical     001-1208-0 (thread    3) identical     001-1219-0 (thread    1) identical     001-1233-0 (thread    1) identical     001-1241-0 (thread    6) identical     001-1245-0 (thread    4) identical     001-1251-0 (thread    6) identical     001-1261-1 (thread    3) identical     001-1262-0 (thread    6) identical     001-1269-0 (thread    7) worse      001-1271-1 (thread    2) identical     001-1279-0 (thread    3) identical     001-1281-0 (thread    3) identical     001-1288-0 (thread    7) worse      001-1295-0 (thread    2) identical     001-1305-1 (thread    6) identical     001-1308-1 (thread    1) identical     001-1327-0 (thread    6) identical     001-1329-0 (thread    3) identical     002-0081-1 (thread    4) identical     002-0159-0 (thread    1) identical     002-0236-1 (thread    7) identical     002-0305-0 (thread    8) identical     002-0371-0 (thread    1) identical     002-0438-1 (thread    2) better     002-0498-0 (thread    8) identical     002-0555-0 (thread    6) identical     002-0598-0 (thread    7) identical     002-0630-0 (thread    2) identical     002-0688-1 (thread    4) identical     002-0790-1 (thread    4) identical     002-0831-1 (thread    1) identical     002-0872-1 (thread    1) identical     002-0902-1 (thread    5) identical     002-0931-1 (thread    1) identical     002-0967-1 (thread    4) identical     002-0995-1 (thread    4) identical     002-1036-0 (thread    1) identical     002-1063-0 (thread    7) identical     002-1099-1 (thread    5) identical     002-1124-1 (thread    7) identical     002-1142-0 (thread    8) worse      002-1171-0 (thread    6) identical     002-1192-1 (thread    5) identical     002-1219-1 (thread    5) identical     002-1233-1 (thread    2) identical     002-1249-1 (thread    3) identical     002-1260-1 (thread    2) identical     002-1264-1 (thread    1) identical     002-1265-0 (thread    1) identical     002-1273-0 (thread    4) identical     002-1287-0 (thread    2) identical     002-1296-1 (thread    7) identical     002-1308-1 (thread    4) identical     002-1310-0 (thread    1) identical     002-1330-1 (thread    4) identical     003-0068-1 (thread    4) identical     003-0148-1 (thread    4) identical     003-0234-1 (thread    2) identical     003-0311-1 (thread    8) identical     003-0371-0 (thread    4) identical     003-0433-1 (thread    2) identical     003-0501-1 (thread    1) identical     003-0556-0 (thread    4) identical     003-0601-1 (thread    8) identical     003-0658-1 (thread    6) identical     003-0698-1 (thread    4) identical     003-0746-1 ...
# Converged2.
# done
# dvtditr (aa) Version 7.526
# alg=A, model=BLOSUM62, 1.53, -0.00, -0.00, noshift, amax=0.0
# 8 thread(s)
#
#
# Strategy:
#  L-INS-i (Probably most accurate, very slow)
#  Iterative refinement method (<16) with LOCAL pairwise alignment information
#
# If unsure which option to use, try 'mafft --auto input > output'.
# For more information, see 'mafft --help', 'mafft --man' and the mafft page.
#
# The default gap scoring scheme has been changed in version 7.110 (2013 Oct).
# It tends to insert more gaps into gap-rich regions than previous versions.
# To disable this change, add the --leavegappyregion option.
# 2025-11-30 22:41:35.497 | SUCCESS  | spider_silkome_module.features:run_shell_command_with_check:53 - Command executed successfully, output file: /home/gyk/project/spider_silkome/data/interim/spider_silkome_20251130/hmmbuild_input/MiSp_NTD_aln.faa
# 2025-11-30 22:41:35.498 | INFO     | spider_silkome_module.features:run_shell_command_with_check:50 - Execute command: mafft --maxiterate 1000 --localpair --thread -1 /home/gyk/project/spider_silkome/data/interim/spider_silkome_20251130/spidroin_seeds_qc/PanSpidroin_CTD_de_dup.faa > /home/gyk/project/spider_silkome/data/interim/spider_silkome_20251130/hmmbuild_input/PanSpidroin_CTD_aln.faa
# OS = linux
# The number of physical cores =  40
# outputhat23=16
# treein = 0
# compacttree = 0
# stacksize: 8192 kb
# rescale = 1
# All-to-all alignment.
# tbfast-pair (aa) Version 7.526
# alg=L, model=BLOSUM62, 2.00, -0.10, +0.10, noshift, amax=0.0
# 40 thread(s)
#
# outputhat23=16
# Loading 'hat3.seed' ...
# done.
# Writing hat3 for iterative refinement
# rescale = 1
# Gap Penalty = -1.53, +0.00, +0.00
# tbutree = 1, compacttree = 0
# Constructing a UPGMA tree ...
#  3340 / 3350
# done.
#
# Progressive alignment ...
# STEP  2901 /3349 (thread   11)
# Reallocating (by thread 3) ..done. *alloclen = 4636
# STEP  3201 /3349 (thread    3)
# Reallocating (by thread 5) ..done. *alloclen = 7040
# STEP  3301 /3349 (thread    9)
# Reallocating (by thread 5) ..done. *alloclen = 8308
#
# Reallocating (by thread 0) ..done. *alloclen = 10583
#
# done.
# tbfast (aa) Version 7.526
# alg=A, model=BLOSUM62, 1.53, -0.00, -0.00, noshift, amax=0.0
# 16 thread(s)
#
# minimumweight = 0.000010
# autosubalignment = 0.000000
# nthread = 8
# randomseed = 0
# blosum 62 / kimura 200
# poffset = 0
# niter = 16
# sueff_global = 0.100000
# nadd = 16
# Loading 'hat3' ... done.
# rescale = 1
#
#  3340 / 3350
# Segment   1/  1    1-8065
# 007-2588-0 (thread    3) worse         001-0005-1 (thread    3) identical     001-0008-1 (thread    5) identical     001-0011-0 (thread    8) identical     001-0012-1 (thread    8) identical     001-0013-0 (thread    7) identical     001-0016-1 (thread    2) identical     001-0017-0 (thread    5) identical     001-0018-0 (thread    4) identical     001-0020-0 (thread    8) identical     001-0021-0 (thread    1) identical     001-0024-0 (thread    2) identical     001-0025-0 (thread    4) identical     001-0027-1 (thread    6) identical     001-0028-0 (thread    8) identical     001-0030-0 (thread    7) identical     001-0032-0 (thread    5) identical     001-0035-1 (thread    4) identical     001-0037-0 (thread    8) identical     001-0038-1 (thread    1) identical     001-0039-0 (thread    7) identical     001-0040-0 (thread    5) identical     001-0041-1 (thread    3) identical     001-0044-1 (thread    6) identical     001-0045-1 (thread    8) identical     001-0046-0 (thread    1) identical     001-0048-1 (thread    7) identical     001-0049-0 (thread    5) identical     001-0050-1 (thread    3) identical     001-0051-0 (thread    6) identical     001-0052-1 (thread    8) identical     001-0053-0 (thread    4) identical     001-0055-0 (thread    2) identical     001-0056-0 (thread    7) identical     001-0058-1 (thread    5) identical     001-0060-0 (thread    3) identical     001-0061-0 (thread    3) identical     001-0065-0 (thread    7) identical     001-0068-1 (thread    6) identical     001-0069-0 (thread    1) identical     001-0071-0 (thread    4) identical     001-0073-1 (thread    5) identical     001-0074-1 (thread    7) identical     001-0076-0 (thread    6) identical     001-0077-0 (thread    8) identical     001-0079-0 (thread    4) identical     001-0082-1 (thread    2) identical     001-0084-0 (thread    6) identical     001-0085-1 (thread    8) identical     001-0087-0 (thread    1) identical     001-0090-0 (thread    6) identical     001-0091-0 (thread    3) identical     001-0092-1 (thread    7) identical     001-0093-0 (thread    2) identical     001-0094-1 (thread    8) identical     001-0095-1 (thread    1) identical     001-0097-0 (thread    5) identical     001-0099-0 (thread    6) identical     001-0101-1 (thread    2) identical     001-0102-1 (thread    3) identical     001-0104-1 (thread    1) identical     001-0105-1 (thread    5) identical     001-0106-1 (thread    6) identical     001-0108-0 (thread    7) identical     001-0110-1 (thread    2) identical     001-0111-0 (thread    2) identical     001-0112-0 (thread    1) identical     001-0114-1 (thread    3) identical     001-0116-1 (thread    5) identical     001-0117-0 (thread    6) identical     001-0118-0 (thread    7) identical     001-0120-1 (thread    2) identical     001-0121-0 (thread    1) identical     001-0122-0 (thread    3) identical     001-0123-1 (thread    4) identical     001-0125-1 (thread    6) identical     001-0126-1 (thread    8) identical     001-0128-0 (thread    2) identical     001-0129-1 (thread    1) identical     001-0130-0 (thread    3) identical     001-0132-0 (thread    4) identical     001-0133-1 (thread    6) identical     001-0134-0 (thread    8) identical     001-0135-1 (thread    7) identical     001-0136-0 (thread    2) identical     001-0137-1 (thread    1) identical     001-0138-0 (thread    3) identical     001-0140-0 (thread    4) identical     001-0141-0 (thread    4) identical     001-0142-1 (thread    6) identical     001-0144-0 (thread    8) identical     001-0146-1 (thread    1) identical     001-0147-1 (thread    5) identical     001-0149-1 (thread    4) identical     001-0150-0 (thread    6) identical     001-0151-1 (thread    7) identical     001-0153-1 (thread    2) identical     001-0154-1 (thread    2) identical     001-0157-0 (thread    1) identical     001-0158-1 (thread    4) identical     001-0159-0 (thread    6) identical     001-0160-1 (thread    7) identical     001-0162-1 (thread     ...
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[33], line 6
#       4 mafft_output_path = Config.HMMBUILD_INPUT_DIR / f"{name}_aln.faa"
#       5 mafft_cmd = f"mafft --maxiterate 1000 --localpair --thread -1 {input_path} > {mafft_output_path}"
# ----> 6 run_shell_command_with_check(mafft_cmd, mafft_output_path)
#
# File ~/project/spider_silkome/spider_silkome_module/features.py:52, in run_shell_command_with_check(command, output_file, force)
#      50 logger.info(f"Execute command: {command}")
#      51 try:
# ---> 52     subprocess.run(command, shell=True)
#      53     logger.success(f"Command executed successfully, output file: {output_file}")
#      54     return True
#
# File ~/project/spider_silkome/.pixi/envs/default/lib/python3.10/subprocess.py:505, in run(input, capture_output, timeout, check, *popenargs, **kwargs)
#     503 with Popen(*popenargs, **kwargs) as process:
#     504     try:
# --> 505         stdout, stderr = process.communicate(input, timeout=timeout)
#     506     except TimeoutExpired as exc:
#     507         process.kill()
#
# File ~/project/spider_silkome/.pixi/envs/default/lib/python3.10/subprocess.py:1146, in Popen.communicate(self, input, timeout)
#    1144         stderr = self.stderr.read()
#    1145         self.stderr.close()
# -> 1146     self.wait()
#    1147 else:
#    1148     if timeout is not None:
#
# File ~/project/spider_silkome/.pixi/envs/default/lib/python3.10/subprocess.py:1209, in Popen.wait(self, timeout)
#    1207     endtime = _time() + timeout
#    1208 try:
# -> 1209     return self._wait(timeout=timeout)
#    1210 except KeyboardInterrupt:
#    1211     # https://bugs.python.org/issue25942
#    1212     # The first keyboard interrupt waits briefly for the child to
#    1213     # exit under the common assumption that it also received the ^C
#    1214     # generated SIGINT and will exit rapidly.
#    1215     if timeout is not None:
#
# File ~/project/spider_silkome/.pixi/envs/default/lib/python3.10/subprocess.py:1959, in Popen._wait(self, timeout)
#    1957 if self.returncode is not None:
#    1958     break  # Another thread waited.
# -> 1959 (pid, sts) = self._try_wait(0)
#    1960 # Check the pid and loop as waitpid has been known to
#    1961 # return 0 even without WNOHANG in odd situations.
#    1962 # http://bugs.python.org/issue14396.
#    1963 if pid == self.pid:
#
# File ~/project/spider_silkome/.pixi/envs/default/lib/python3.10/subprocess.py:1917, in Popen._try_wait(self, wait_flags)
#    1915 """All callers to this function MUST hold self._waitpid_lock."""
#    1916 try:
# -> 1917     (pid, sts) = os.waitpid(self.pid, wait_flags)
#    1918 except ChildProcessError:
#    1919     # This happens if SIGCLD is set to be ignored or waiting
#    1920     # for child processes has otherwise been disabled for our
#    1921     # process.  This child is dead, we can't get the status.
#    1922     pid = self.pid
#
# KeyboardInterrupt:

# %%
# 构建 hmm 模型
for input_path in Config.HMM_INPUT_DIR.glob("*_aln.faa"):
    name = input_path.stem.split("_")[0]
    hmmbuild_output_path = Config.HMM_OUTPUT_DIR / f"{name}.hmm"
    hmmbuild_cmd = f"hmmbuild -n {name} --amino --cpu 70 {hmmbuild_output_path} {input_path}"
    run_shell_command_with_check(hmmbuild_cmd, hmmbuild_output_path)
    hmmpress_cmd = f"hmmpress {hmmbuild_output_path}"
    run_shell_command_with_check(hmmpress_cmd, f"{hmmbuild_output_path}.h3m")

# %% [markdown]
# ## 3 基因组扫描策略
# 传统的BLAST搜索在处理高分歧序列时往往会产生大量假阴性。相比之下，nhmmer（HMMER组件）可以直接将蛋白的pHMM模型映射到核酸序列上，或者使用DNA-to-DNA的HMM搜索，从而在保持高特异性的同时极大提升灵敏度。
#
# **执行方案：**
#
# - 全基因组扫描： 使用 nhmmer 对目标基因组进行六框翻译搜索（或直接核酸搜索，取决于模型类型）。
# - 参数设定： E-value 阈值设为 $1e^{-10}$ 以保证高置信度；--qcov（查询覆盖度）需大于70%，确保找到的是完整的结构域而非碎片。
# - 结果过滤： 剔除低复杂度的非特异性匹配。蛛丝蛋白基因组中常含有大量的简单重复序列（Simple Repeats），需利用RepeatMasker的输出结果对HMM hits进行软过滤。
