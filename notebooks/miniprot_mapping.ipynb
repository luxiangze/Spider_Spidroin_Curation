# %% [markdown]
# # Miniprot mapping
# Setting up the required Python packages

# %%
import os
import pandas as pd
import subprocess
import time
from pathlib import Path

from spider_silkome_module import (
    RAW_DATA_DIR,
    INTERIM_DATA_DIR,
    EXTERNAL_DATA_DIR,
    PROCESSED_DATA_DIR
)
from spider_silkome_module.utils import run_cmd

# %% [markdown]
# ## Configure
#
# Definition of the path for relevant data

# %%
task_name = "miniprot_mapping_20260127"

spidroin_fasta_file = EXTERNAL_DATA_DIR / "spider-silkome-database.v1.prot.fixed.renamed.fasta"
spider_genome_path = RAW_DATA_DIR / "spider_genome"

# dedup
dedup_output_dir = INTERIM_DATA_DIR / task_name / "cdhit"
spidroin_fasta_file_rep = dedup_output_dir / "cdhit_rep_seq.fa"
shortest_seq_file = dedup_output_dir / "cdhit_shortest_seq.fa"

# miniprot
miniprot_output_path = PROCESSED_DATA_DIR / task_name / "miniprot_output"

# %% [markdown]
# Perform redundancy reduction on the N/C terminal sequences of Spidroin proteins using cd-hit.
#
# <zh>使用 cd-hit 对 Spidroin 蛋白的 N/C 端序列进行去冗余。</zh>

# %%
cdhit_cmd = f"pixi run cd-hit -i {spidroin_fasta_file} -o {spidroin_fasta_file_rep} -c 0.9 -T 0 -M 0 -d 0"
shortest_seq_cmd = f"pixi run python -m spider_silkome_module.extract_shortest_seq --clstr-path {spidroin_fasta_file_rep}.clstr --fasta-path {spidroin_fasta_file} --output-path {shortest_seq_file}"
run_cmd(cdhit_cmd, [spidroin_fasta_file_rep])
run_cmd(shortest_seq_cmd, [shortest_seq_file],force=True)
# Out:
# ⏭️ /home/gyk/project/spider_silkome/data/interim/miniprot_mapping_20260127/cdhit/cdhit_rep_seq.fa exists, skip
# 2026-01-27 10:51:07.499 | INFO     | spider_silkome_module.config:<module>:11 - PROJ_ROOT path is: /home/gyk/project/spider_silkome
# 2026-01-27 10:51:07.725 | INFO     | __main__:main:61 - Parsing cluster file: /home/gyk/project/spider_silkome/data/interim/miniprot_mapping_20260127/cdhit/cdhit_rep_seq.fa.clstr
# 2026-01-27 10:51:07.752 | INFO     | __main__:main:63 - Found 6985 clusters
# 2026-01-27 10:51:07.752 | DEBUG    | __main__:get_shortest_seq_ids:48 - Cluster 0: shortest = 5826_MaSp2_CTD (1854aa)
# 2026-01-27 10:51:07.752 | DEBUG    | __main__:get_shortest_seq_ids:48 - Cluster 1: shortest = 2571_Flag_CTD (448aa)
# 2026-01-27 10:51:07.752 | DEBUG    | __main__:get_shortest_seq_ids:48 - Cluster 2: shortest = 1737_MiSp_CTD (1674aa)
# 2026-01-27 10:51:07.752 | DEBUG    | __main__:get_shortest_seq_ids:48 - Cluster 3: shortest = 4955_AgSp1_CTD (200aa)
# 2026-01-27 10:51:07.752 | DEBUG    | __main__:get_shortest_seq_ids:48 - Cluster 4: shortest = 4681_AgSp1_CTD (200aa)
# 2026-01-27 10:51:07.752 | DEBUG    | __main__:get_shortest_seq_ids:48 - Cluster 5: shortest = 5222_AgSp1_CTD (926aa)
# 2026-01-27 10:51:07.752 | DEBUG    | __main__:get_shortest_seq_ids:48 - Cluster 6: shortest = 5385_AgSp1_CTD (1674aa)
# 2026-01-27 10:51:07.752 | DEBUG    | __main__:get_shortest_seq_ids:48 - Cluster 7: shortest = 7481_PySp_NTD (1674aa)
# 2026-01-27 10:51:07.752 | DEBUG    | __main__:get_shortest_seq_ids:48 - Cluster 8: shortest = 7802_MaSp1_NTD (1674aa)
# 2026-01-27 10:51:07.753 | DEBUG    | __main__:get_shortest_seq_ids:48 - Cluster 9: shortest = 3436_MiSp_CTD (1673aa)
# 2026-01-27 10:51:07.753 | DEBUG    | __main__:get_shortest_seq_ids:48 - Cluster 10: shortest = 2373_CrSp_CTD (1673aa)
# 2026-01-27 10:51:07.753 | DEBUG    | __main__:get_shortest_seq_ids:48 - Cluster 11: shortest = 3539_PySp_CTD (1673aa)
# 2026-01-27 10:51:07.753 | DEBUG    | __main__:get_shortest_seq_ids:48 - Cluster 12: shortest = 4153_PySp_CTD (1673aa)
# 2026-01-27 10:51:07.753 | DEBUG    | __main__:get_shortest_seq_ids:48 - Cluster 13: shortest = 4597_AgSp1_CTD (200aa)
# 2026-01-27 10:51:07.753 | DEBUG    | __main__:get_shortest_seq_ids:48 - Cluster 14: shortest = 63_AgSp1_CTD (247aa)
# 2026-01-27 10:51:07.753 | DEBUG    | __main__:get_shortest_seq_ids:48 - Cluster 15: shortest = 4607_AgSp1_CTD (200aa)
# 2026-01-27 10:51:07.753 | DEBUG    | __main__:get_shortest_seq_ids:48 - Cluster 16: shortest = 5401_AgSp1_CTD (1247aa)
# 2026-01-27 10:51:07.753 | DEBUG    | __main__:get_shortest_seq_ids:48 - Cluster 17: shortest = 5428_AgSp1_CTD (1673aa)
# 2026-01-27 10:51:07.753 | DEBUG    | __main__:get_shortest_seq_ids:48 - Cluster 18: shortest = 5255_AgSp1_CTD (1051aa)
# 2026-01-27 10:51:07.753 | DEBUG    | __main__:get_shortest_seq_ids:48 - Cluster
a)
# 2026-01-27 10:51:07.763 | DEBUG    | __main__:get_shortest_seq_ids:48 - Cluster 217: shortest = 1961_CySp_CTD (358aa)
# 2026-01-27 10:51:07.763 | DEBUG    | __main__:get_shortest_seq_ids:48 - Cluster 218: shortest = 5307_AgSp1_CTD (919aa)
# 2026-01-27 10:51:07.763 | DEBUG    | __main__:get_shortest_seq_ids:48 - Cluster 219: shortest = 8629_Flag_NTD (173aa)
# 2026-01-27 10:51:07.763 | DEBUG    | __main__:get_shortest_seq_ids:48 - Cluster 220: shortest = 8770_MaSp_NTD (1238aa)
# 2026-01-27 10:51:07.763 | DEBUG    | __main__:get_shortest_seq_ids:48 - Cluster 221: shortest = 5481_AgSp1_CTD (936aa)
# 2026-01-27 10:51:07.763 | DEBUG    | __main__:get_shortest_seq_ids:48 - Cluster 222: shortest = 10475_MaSp_NTD (336aa)
# 2026-01-27 10:51:07.763 | DEBUG    | __main__:get_shortest_seq_ids:48 - Cluster 223: shortest = 135_MiSp_CTD (1232aa)
# 2026-01-27 10:51:07.763 | DEBUG    | __main__:get_shortest_seq_ids:48 - Cluster 224: shortest = 4639_AgSp1_CTD (200aa)
# 2026-01-27 10:51:07.763 | DEBUG    | __main__:get_shortest_seq_ids:48 - Cluster 225: shortest = 4549_MaSp2_CTD (1231aa)
# 2026-01-27 10:51:07.764 | DEBUG    | __main__:get_shortest_seq_ids:48 - Cluster 226: shortest = 1212_PySp_CTD (1228aa)
# 2026-01-27 10:51:07.764 | DEBUG    | __main__:get_shortest_seq_ids:48 - Cluster 227: shortest = 5515_Spidroin_CTD (1228aa)
# 2026-01-27 10:51:07.764 | DEBUG    | __main__:get_shortest_seq_ids:48 - Cluster 228: shortest = 1458_PySp_CTD (872aa)
# 2026-01-27 10:51:07.764 | DEBUG    | __main__:get_shortest_seq_ids:48 - Cluster 229: shortest = 1481_AcSp_CTD (1223aa)
# 2026-01-27 10:51:07.764 | DEBUG    | __main__:get_shortest_seq_ids:48 - Cluster 230: shortest = 148_Spidroin_CTD (648aa)
# 2026-01-27 10:51:07.764 | DEBUG    | __main__:get_shortest_seq_ids:48 - Cluster 231: shortest = 2885_MaSp_CTD (1220aa)
# 2026-01-27 10:51:07.764 | DEBUG    | __main__:get_shortest_seq_ids:48 - Cluster 232: shortest = 6904_AcSp_NTD (924aa)
# 2026-01-27 10:51:07.764 | DEBUG    | __main__:get_shortest_seq_ids:48 - Cluster 233: shortest = 7728_MaSp1_NTD (354aa)
# 2026-01-27 10:51:07.764 | DEBUG    | __main__:get_shortest_seq_ids:48 - Cluster 234: shortest = 3879_AcSp_CTD (1216aa)
# 2026-01-27 10:51:07.764 | DEBUG    | __main__:get_shortest_seq_ids:48 - Cluster 235: shortest = 1479_Spidroin_CTD (1214aa)
# 2026-01-27 10:51:07.764 | DEBUG    | __main__:get_shortest_seq_ids:48 - Cluster 236: shortest = 7546_Spidroin_NTD (218aa)
# 2026-01-27 10:51:07.764 | DEBUG    | __main__:get_shortest_seq_ids:48 - Cluster 237: shortest = 1103_CrSp_CTD (769aa)
# 2026-01-27 10:51:07.764 | DEBUG    | __main__:get_shortest_seq_ids:48 - Cluster 238: shortest = 3639_MiSp_CTD (1210aa)
# 2026-01-27 10:51:07.764 | DEBUG    | __main__:get_shortest_seq_ids:48 - Cluster 239: shortest = 2386_Ampullate_spidroin_CTD (1208aa)
# 2026-01-27 10:51:07.764 | DEBUG    | __main__:get_shortest_seq_ids:48 - Cluster 240: shortest = 2354_MiSp_CTD (1207aa)
# 2026-01-27 10:51:07.764 | DEBUG    | __main__:get_shortest_seq_ids:48 - Cluster 241: shortest = 3154_AcSp_CTD (1206aa)
# 2026-01-27 10:51:07.764 | DEBUG    | __main__:get_shortest_seq_ids:48 - Cluster 242: shortest = 9838_MiSp_NTD (170aa)
# 2026-01-27 10:51:07.764 | DEBUG    | __main__:get_shortest_seq_ids:48 - Cluster 243: shortest = 3109_AcSp_CTD (430aa)
# 2026-01-27 10:51:07.764 | DEBUG    | __main__:get_shortest_seq_ids:48 - Cluster 244: shortest = 5950_CySp_NTD (651aa)
# 2026-01-27 10:51:07.765 | DEBUG    | __main__:get_shortest_seq_ids:48 - Cluster 245: shortest = 6594_AcSp_NTD (1200aa)
# 2026-01-27 10:51:07.765 | DEBUG    | __main__:get_shortest_seq_ids:48 - Cluster 246: shortest = 8521_AcSp_NTD (1199aa)
# 2026-01-27 10:51:07.765 | DEBUG    | __main__:get_shortest_seq_ids:48 - Cluster 247: shortest = 2851_AcSp_CTD (444aa)
# 2026-01-27 10:51:07.765 | DEBUG    | __main__:get_shortest_seq_ids:48 - Cluster 248: shortest = 2526_Spidroin_CTD (1191aa)
# 2026-01-27 10:51:07.765 | DEBUG    | __main__:get_shortest_seq_ids:48 - Cluster 249: shortest = 7559_MiSp_NTD (1190aa)
# 2026-01-27 10:51:07.765 | DEBUG    | __main__:get_shortest_seq_ids:48 - Cluster 250: shortest = 1569_MaSp2_CTD (1011aa)
# 2026-01-27 10:51:07.765 | DEBUG    | __main__:get_shortest_seq_ids:48 - Cluster 251: shortest = 3612_PySp_CTD (572aa)
# 2026-01-27 10:51:07.765 | DEBUG    | __main__:get_shortest_seq_ids:48 - Cluster 252: shortest = 1105_AcSp_CTD (692aa)
# 2026-01-27 10:51:07.765 | DEBUG    | __main__:get_shortest_seq_ids:48 - Cluster 253: shortest = 1461_PySp_CTD (557aa)
# 2026-01-27 10:51:07.765 | DEBUG    | __main__:get_shortest_seq_ids:48 - Cluster 254: shortest = 2061_MiSp_CTD (1182aa)
# 2026-01-27 10:51:07.765 | DEBUG    | __main__:get_shortest_seq_ids:48 - Cluster 255: shortest = 5523_PySp_CTD (1182aa)
# 2026-01-27 10:51:07.765 | DEBUG    | __main__:get_shortest_seq_ids:48 - Cluster 256: shortest = 1675_AcSp_CTD (1181aa)
# 2026-01-27 10:51:07.765 | DEBUG    | __main__:get_shortest_seq_ids:48 - Cluster 257: shortest = 4457_Flag_CTD (1180aa)
# 2026-01-27 10:51:07.765 | DEBUG    | __main__:get_shortest_seq_ids:48 - Cluster 258: shortest = 1599_AcSp_CTD (426aa)
# 2026-01-27 10:51:07.765 | DEBUG    | __main__:get_shortest_seq_ids:48 - Cluster 259: shortest = 3084_AcSp_CTD (1175aa)
# 2026-01-27 10:51:07.765 | DEBUG    | __main__:get_shortest_seq_ids:48 - Cluster 260: shortest = 2332_PySp_CTD (259aa)
# 2026-01-27 10:51:07.765 | DEBUG    | __main__:get_shortest_seq_ids:48 - Cluster 261: shortest = 2056_PySp_CTD (1173aa)
# 2026-01-27 10:51:07.765 | DEBUG    | __main__:get_shortest_seq_ids:48 - Cluster 262: shortest = 2058_PySp_CTD (1173aa)
# 2026-01-27 10:51:07.765 | DEBUG    | __main__:get_shortest_seq_ids:48 - Cluster 263: shortest = 3981_PySp_CTD (1173aa)
# 2026-01-27 10:51:07.765 | DEBUG    | __main__:get_shortest_seq_ids:48 - Cluster 264: shortest = 8461_MaSp_NTD (516aa)
# 2026-01-27 10:51:07.766 | DEBUG    | __main__:get_shortest_seq_ids:48 - Cluster 265: shortest = 1257_AcSp_CTD (1172aa)
# 2026-01-27 10:51:07.766 | DEBUG    | __main__:get_shortest_seq_ids:48 - Cluster 266: shortest = 3543_Putative_spidroin_CTD (1172aa)
# 2026-01-27 10:51:07.766 | DEBUG    | __main__:get_shortest_seq_ids:48 - Cluster 267: shortest = 3633_AcSp_CTD (1172aa)
# 2026-01-27 10:51:07.766 | DEBUG    | __main__:get_shortest_seq_ids:48 - Cluster 268: shortest = 6195_AcSp_NTD (1172aa)
# 2026-01-27 10:51:07.766 | DEBUG    | __main__:get_shortest_seq_ids:48 - Cluster 269: shortest = 6046_PySp_NTD (237aa)
# 2026-01-27 10:51:07.766 | DEBUG    | __main__:get_shortest_seq_ids:48 - Cluster 270: shortest = 3532_MiSp_CTD (1171aa)
# 2026-01-27 10:51:07.766 | DEBUG    | __main__:get_shortest_seq_ids:48 - Cluster 271: shortest = 3456_PySp_CTD (555aa)
# 2026-01-27 10:51:07.766 | DEBUG    | __main__:get_shortest_seq_ids:48 - Cluster 272: shortest = 4149_MaSp2_CTD (1159aa)
# 2026-01-27 10:51:07.766 | DEBUG    | __main__:get_shortest_seq_ids:48 - Cluster 273: shortest = 943_AcSp_CTD (1168aa)
# 2026-01-27 10:51:07.766 | DEBUG    | __main__:get_shortest_seq_ids:48 - Cluster 274: shortest = 560_CrSp_CTD (1167aa)
# 2026-01-27 10:51:07.766 | DEBUG    | __main__:get_shortest_seq_ids:48 - Cluster 275: shortest = 675_PySp_CTD (1166aa)
# 2026-01-27 10:51:07.766 | DEBUG    | __main__:get_shortest_seq_ids:48 - Cluster 276: shortest = 983_Flag_CTD (808aa)
# 2026-01-27 10:51:07.766 | DEBUG    | __main__:get_shortest_seq_ids:48 - Cluster 277: shortest = 1093_PySp_CTD (481aa)
# 2026-01-27 10:51:07.766 | DEBUG    | __main__:get_shortest_seq_ids:48 - Cluster 278: shortest = 2269_PySp_CTD (1162aa)
# 2026-01-27 10:51:07.766 | DEBUG    | __main__:get_shortest_seq_ids:48 - Cluster 279: shortest = 9278_Spidroin_NTD (627aa)
# 2026-01-27 10:51:07.766 | DEBUG    | __main__:get_shortest_seq_ids:48 - Cluster
a)
# 2026-01-27 10:51:08.123 | DEBUG    | __main__:get_shortest_seq_ids:48 - Cluster 6920: shortest = 8320_AgSp1_NTD (147aa)
# 2026-01-27 10:51:08.123 | DEBUG    | __main__:get_shortest_seq_ids:48 - Cluster 6921: shortest = 5600_MaSp3B_CTD (147aa)
# 2026-01-27 10:51:08.123 | DEBUG    | __main__:get_shortest_seq_ids:48 - Cluster 6922: shortest = 5532_MaSp_CTD (147aa)
# 2026-01-27 10:51:08.123 | DEBUG    | __main__:get_shortest_seq_ids:48 - Cluster 6923: shortest = 10467_MaSp_NTD (123aa)
# 2026-01-27 10:51:08.123 | DEBUG    | __main__:get_shortest_seq_ids:48 - Cluster 6924: shortest = 5551_MiSp_CTD (146aa)
# 2026-01-27 10:51:08.123 | DEBUG    | __main__:get_shortest_seq_ids:48 - Cluster 6925: shortest = 6869_AgSp2_NTD (146aa)
# 2026-01-27 10:51:08.123 | DEBUG    | __main__:get_shortest_seq_ids:48 - Cluster 6926: shortest = 5680_MiSp_CTD (145aa)
# 2026-01-27 10:51:08.123 | DEBUG    | __main__:get_shortest_seq_ids:48 - Cluster 6927: shortest = 5502_PySp_CTD (145aa)
# 2026-01-27 10:51:08.123 | DEBUG    | __main__:get_shortest_seq_ids:48 - Cluster 6928: shortest = 5647_Ampullate_spidroin_CTD (145aa)
# 2026-01-27 10:51:08.123 | DEBUG    | __main__:get_shortest_seq_ids:48 - Cluster 6929: shortest = 6016_AgSp2_NTD (145aa)
# 2026-01-27 10:51:08.123 | DEBUG    | __main__:get_shortest_seq_ids:48 - Cluster 6930: shortest = 5734_MiSp_CTD (144aa)
# 2026-01-27 10:51:08.123 | DEBUG    | __main__:get_shortest_seq_ids:48 - Cluster 6931: shortest = 5588_MiSp_CTD (143aa)
# 2026-01-27 10:51:08.123 | DEBUG    | __main__:get_shortest_seq_ids:48 - Cluster 6932: shortest = 6112_Spidroin_NTD (143aa)
# 2026-01-27 10:51:08.123 | DEBUG    | __main__:get_shortest_seq_ids:48 - Cluster 6933: shortest = 10708_MaSp_NTD (143aa)
# 2026-01-27 10:51:08.123 | DEBUG    | __main__:get_shortest_seq_ids:48 - Cluster 6934: shortest = 5864_MaSp2_CTD (142aa)
# 2026-01-27 10:51:08.123 | DEBUG    | __main__:get_shortest_seq_ids:48 - Cluster 6935: shortest = 11075_MaSp2_NTD (142aa)
# 2026-01-27 10:51:08.123 | DEBUG    | __main__:get_shortest_seq_ids:48 - Cluster 6936: shortest = 10205_MaSp_NTD (141aa)
# 2026-01-27 10:51:08.124 | DEBUG    | __main__:get_shortest_seq_ids:48 - Cluster 6937: shortest = 10794_MaSp1_NTD (141aa)
# 2026-01-27 10:51:08.124 | DEBUG    | __main__:get_shortest_seq_ids:48 - Cluster 6938: shortest = 5793_MaSp1_CTD (140aa)
# 2026-01-27 10:51:08.124 | DEBUG    | __main__:get_shortest_seq_ids:48 - Cluster 6939: shortest = 8702_Spidroin_NTD (100aa)
# 2026-01-27 10:51:08.124 | DEBUG    | __main__:get_shortest_seq_ids:48 - Cluster 6940: shortest = 5758_MaSp_CTD (139aa)
# 2026-01-27 10:51:08.124 | DEBUG    | __main__:get_shortest_seq_ids:48 - Cluster 6941: shortest = 9466_Ampullate_spidroin_NTD (139aa)
# 2026-01-27 10:51:08.124 | DEBUG    | __main__:get_shortest_seq_ids:48 - Cluster 6942: shortest = 5719_MiSp_CTD (138aa)
# 2026-01-27 10:51:08.124 | DEBUG    | __main__:get_shortest_seq_ids:48 - Cluster 6943: shortest = 5799_MaSp1_CTD (137aa)
# 2026-01-27 10:51:08.124 | DEBUG    | __main__:get_shortest_seq_ids:48 - Cluster 6944: shortest = 4_MiSp_CTD (135aa)
# 2026-01-27 10:51:08.124 | DEBUG    | __main__:get_shortest_seq_ids:48 - Cluster 6945: shortest = 5736_MaSp_CTD (133aa)
# 2026-01-27 10:51:08.124 | DEBUG    | __main__:get_shortest_seq_ids:48 - Cluster 6946: shortest = 5804_MaSp1_CTD (132aa)
# 2026-01-27 10:51:08.124 | DEBUG    | __main__:get_shortest_seq_ids:48 - Cluster 6947: shortest = 5544_MiSp_CTD (131aa)
# 2026-01-27 10:51:08.124 | DEBUG    | __main__:get_shortest_seq_ids:48 - Cluster 6948: shortest = 5531_MaSp_CTD (129aa)
# 2026-01-27 10:51:08.124 | DEBUG    | __main__:get_shortest_seq_ids:48 - Cluster 6949: shortest = 5757_MaSp_CTD (129aa)
# 2026-01-27 10:51:08.124 | DEBUG    | __main__:get_shortest_seq_ids:48 - Cluster 6950: shortest = 9112_AgSp1_NTD (129aa)
# 2026-01-27 10:51:08.124 | DEBUG    | __main__:get_shortest_seq_ids:48 - Cluster 6951: shortest = 9748_MiSp_NTD (129aa)
# 2026-01-27 10:51:08.124 | DEBUG    | __main__:get_shortest_seq_ids:48 - Cluster 6952: shortest = 9384_Ampullate_spidroin_NTD (128aa)
# 2026-01-27 10:51:08.124 | DEBUG    | __main__:get_shortest_seq_ids:48 - Cluster 6953: shortest = 5771_MaSp_CTD (126aa)
# 2026-01-27 10:51:08.124 | DEBUG    | __main__:get_shortest_seq_ids:48 - Cluster 6954: shortest = 5535_Spidroin_CTD (125aa)
# 2026-01-27 10:51:08.124 | DEBUG    | __main__:get_shortest_seq_ids:48 - Cluster 6955: shortest = 10248_MaSp_NTD (122aa)
# 2026-01-27 10:51:08.125 | DEBUG    | __main__:get_shortest_seq_ids:48 - Cluster 6956: shortest = 10570_MaSp_NTD (121aa)
# 2026-01-27 10:51:08.125 | DEBUG    | __main__:get_shortest_seq_ids:48 - Cluster 6957: shortest = 5823_MaSp2B_CTD (120aa)
# 2026-01-27 10:51:08.125 | DEBUG    | __main__:get_shortest_seq_ids:48 - Cluster 6958: shortest = 5592_MaSp3B_CTD (117aa)
# 2026-01-27 10:51:08.125 | DEBUG    | __main__:get_shortest_seq_ids:48 - Cluster 6959: shortest = 5858_MaSp2_CTD (115aa)
# 2026-01-27 10:51:08.125 | DEBUG    | __main__:get_shortest_seq_ids:48 - Cluster 6960: shortest = 5501_Ampullate_spidroin_CTD (114aa)
# 2026-01-27 10:51:08.125 | DEBUG    | __main__:get_shortest_seq_ids:48 - Cluster 6961: shortest = 8218_AgSp2_NTD (112aa)
# 2026-01-27 10:51:08.125 | DEBUG    | __main__:get_shortest_seq_ids:48 - Cluster 6962: shortest = 9482_Ampullate_spidroin_NTD (112aa)
# 2026-01-27 10:51:08.125 | DEBUG    | __main__:get_shortest_seq_ids:48 - Cluster 6963: shortest = 1_MiSp_CTD (111aa)
# 2026-01-27 10:51:08.125 | DEBUG    | __main__:get_shortest_seq_ids:48 - Cluster 6964: shortest = 9269_Ampullate_spidroin_NTD (110aa)
# 2026-01-27 10:51:08.125 | DEBUG    | __main__:get_shortest_seq_ids:48 - Cluster 6965: shortest = 5725_MiSp_CTD (107aa)
# 2026-01-27 10:51:08.125 | DEBUG    | __main__:get_shortest_seq_ids:48 - Cluster 6966: shortest = 5788_MaSp1_CTD (106aa)
# 2026-01-27 10:51:08.125 | DEBUG    | __main__:get_shortest_seq_ids:48 - Cluster 6967: shortest = 5873_MaSp2_CTD (105aa)
# 2026-01-27 10:51:08.125 | DEBUG    | __main__:get_shortest_seq_ids:48 - Cluster 6968: shortest = 9280_Ampullate_spidroin_NTD (105aa)
# 2026-01-27 10:51:08.125 | DEBUG    | __main__:get_shortest_seq_ids:48 - Cluster 6969: shortest = 5500_Ampullate_spidroin_CTD (103aa)
# 2026-01-27 10:51:08.125 | DEBUG    | __main__:get_shortest_seq_ids:48 - Cluster 6970: shortest = 5503_Spidroin_CTD (101aa)
# 2026-01-27 10:51:08.125 | DEBUG    | __main__:get_shortest_seq_ids:48 - Cluster 6971: shortest = 5564_MiSp_CTD (100aa)
# 2026-01-27 10:51:08.125 | DEBUG    | __main__:get_shortest_seq_ids:48 - Cluster 6972: shortest = 5979_Spidroin_NTD (100aa)
# 2026-01-27 10:51:08.125 | DEBUG    | __main__:get_shortest_seq_ids:48 - Cluster 6973: shortest = 6739_Spidroin_NTD (100aa)
# 2026-01-27 10:51:08.125 | DEBUG    | __main__:get_shortest_seq_ids:48 - Cluster 6974: shortest = 7233_Spidroin_NTD (100aa)
# 2026-01-27 10:51:08.125 | DEBUG    | __main__:get_shortest_seq_ids:48 - Cluster 6975: shortest = 7912_MiSp_NTD (100aa)
# 2026-01-27 10:51:08.126 | DEBUG    | __main__:get_shortest_seq_ids:48 - Cluster 6976: shortest = 8384_CySp_NTD (100aa)
# 2026-01-27 10:51:08.126 | DEBUG    | __main__:get_shortest_seq_ids:48 - Cluster 6977: shortest = 8478_Spidroin_NTD (100aa)
# 2026-01-27 10:51:08.126 | DEBUG    | __main__:get_shortest_seq_ids:48 - Cluster 6978: shortest = 8540_MaSp_NTD (100aa)
# 2026-01-27 10:51:08.126 | DEBUG    | __main__:get_shortest_seq_ids:48 - Cluster 6979: shortest = 8587_MaSp1_NTD (100aa)
# 2026-01-27 10:51:08.126 | DEBUG    | __main__:get_shortest_seq_ids:48 - Cluster 6980: shortest = 8758_MiSp_NTD (100aa)
# 2026-01-27 10:51:08.126 | DEBUG    | __main__:get_shortest_seq_ids:48 - Cluster 6981: shortest = 11119_MaSp2_NTD (100aa)
# 2026-01-27 10:51:08.126 | DEBUG    | __main__:get_shortest_seq_ids:48 - Cluster 6982: shortest = 5572_MiSp_CTD (86aa)
# 2026-01-27 10:51:08.126 | DEBUG    | __main__:get_shortest_seq_ids:48 - Cluster 6983: shortest = 7678_AgSp1_NTD (78aa)
# 2026-01-27 10:51:08.126 | DEBUG    | __main__:get_shortest_seq_ids:48 - Cluster 6984: shortest = 7777_AgSp1_NTD (76aa)
# 2026-01-27 10:51:08.126 | INFO     | __main__:main:66 - Extracting 6985 shortest sequences
# 2026-01-27 10:51:08.126 | INFO     | __main__:main:68 - Reading FASTA file: /home/gyk/project/spider_silkome/data/external/spider-silkome-database.v1.prot.fixed.renamed.fasta
# 2026-01-27 10:51:08.214 | INFO     | __main__:main:90 - Writing 6985 sequences to /home/gyk/project/spider_silkome/data/interim/miniprot_mapping_20260127/cdhit/cdhit_shortest_seq.fa
# 2026-01-27 10:51:08.246 | SUCCESS  | __main__:main:93 - Extracted 6985 shortest sequences from 6985 clusters
# Extracting sequences: 100%|██████████| 6985/6985 [00:00<00:00, 938922.97it/s]

# %% [markdown]
# Use miniprot to align the C-terminal and N-terminal sequences of the spidroin gene sequences to the genome of the new species.

# %%
# index_cmd = f"miniprot -t70 -d {gnome_mpi_path}/{spider}.mpi {spider_genome_path}/{spider_genome}"
miniprot_cmd = f"pixi run python -m spider_silkome_module.run_miniprot --input-path {spider_genome_path} --protein-fasta {shortest_seq_file} --output-path {miniprot_output_path} --threads 70 --outc 0.8 --force"

# run_cmd(index_cmd, [gnome_mpi_path])
run_cmd(miniprot_cmd, [miniprot_output_path])
# Out:
# 2026-01-27 12:35:50.046 | INFO     | spider_silkome_module.config:<module>:11 - PROJ_ROOT path is: /home/gyk/project/spider_silkome
# Processing genomes:   0%|          | 0/10 [00:00<?, ?it/s]
# 2026-01-27 12:35:50.077 | INFO     | __main__:main:76 - Input path: /home/gyk/project/spider_silkome/data/raw/spider_genome
# 2026-01-27 12:35:50.078 | INFO     | __main__:main:77 - Protein FASTA: /home/gyk/project/spider_silkome/data/interim/miniprot_mapping_20260127/cdhit/cdhit_shortest_seq.fa
# 2026-01-27 12:35:50.079 | INFO     | __main__:main:84 - Found 10 genome(s) to process
# 2026-01-27 12:35:50.080 | INFO     | __main__:main:89 - Processing Songthela_sp: /home/gyk/project/spider_silkome/data/raw/spider_genome/049.Songthela_sp/Songthela_sp.mpi
# [M::mp_idx_restore@18.123*0.56] loaded the index
# [M::mp_idx_print_stat] 2398163 distinct k-mers; mean occ of infrequent k-mers: 507.90; 2150 frequent k-mers accounting for 105152995 occurrences
# [M::worker_pipeline::27.231*22.50] mapped 4066 sequences
# [M::worker_pipeline::29.724*25.90] mapped 2919 sequences
# [M::main] Version: 0.18-r281
# [M::main] CMD: miniprot -S --gff-delim . --outc 0.8 -t 70 -I --gff-only /home/gyk/project/spider_silkome/data/raw/spider_genome/049.Songthela_sp/Songthela_sp.mpi /home/gyk/project/spider_silkome/data/interim/miniprot_mapping_20260127/cdhit/cdhit_shortest_seq.fa
# [M::main] Real time: 30.217 sec; CPU: 770.238 sec; Peak RSS: 14.456 GB
# Processing genomes:  10%|█         | 1/10 [00:30<04:32, 30.28s/it]
# 2026-01-27 12:36:20.357 | INFO     | __main__:main:99 - Output: /home/gyk/project/spider_silkome/data/processed/miniprot_mapping_20260127/miniprot_output/Songthela_sp/Songthela_sp.gff
# 2026-01-27 12:36:20.358 | INFO     | __main__:main:89 - Processing Araneus_ventricosus: /home/gyk/project/spider_silkome/data/raw/spider_genome/064.Araneus_ventricosus/Araneus_ventricosus.mpi
# [M::mp_idx_restore@10.371*0.60] loaded the index
# [M::mp_idx_print_stat] 2371156 distinct k-mers; mean occ of infrequent k-mers: 368.91; 368 frequent k-mers accounting for 10236796 occurrences
# [M::worker_pipeline::16.531*24.23] mapped 4066 sequences
# [M::worker_pipeline::18.639*28.92] mapped 2919 sequences
# [M::main] Version: 0.18-r281
# [M::main] CMD: miniprot -S --gff-delim . --outc 0.8 -t 70 -I --gff-only /home/gyk/project/spider_silkome/data/raw/spider_genome/064.Araneus_ventricosus/Araneus_ventricosus.mpi /home/gyk/project/spider_silkome/data/interim/miniprot_mapping_20260127/cdhit/cdhit_shortest_seq.fa
# [M::main] Real time: 18.983 sec; CPU: 539.287 sec; Peak RSS: 9.306 GB
# Processing genomes:  20%|██        | 2/10 [00:49<03:09, 23.70s/it]
# 2026-01-27 12:36:39.453 | INFO     | __main__:main:99 - Output: /home/gyk/project/spider_silkome/data/processed/miniprot_mapping_20260127/miniprot_output/Araneus_ventricosus/Araneus_ventricosus.gff
# 2026-01-27 12:36:39.453 | INFO     | __main__:main:89 - Processing Pardosa_pseudoannulata: /home/gyk/project/spider_silkome/data/raw/spider_genome/106.Pardosa_pseudoannulata/Pardosa_pseudoannulata.mpi
# [M::mp_idx_restore@11.353*0.56] loaded the index
# [M::mp_idx_print_stat] 2345173 distinct k-mers; mean occ of infrequent k-mers: 312.51; 841 frequent k-mers accounting for 53172699 occurrences
# [M::worker_pipeline::15.822*17.63] mapped 4066 sequences
# [M::worker_pipeline::18.000*22.22] mapped 2919 sequences
# [M::main] Version: 0.18-r281
# [M::main] CMD: miniprot -S --gff-delim . --outc 0.8 -t 70 -I --gff-only /home/gyk/project/spider_silkome/data/raw/spider_genome/106.Pardosa_pseudoannulata/Pardosa_pseudoannulata.mpi /home/gyk/project/spider_silkome/data/interim/miniprot_mapping_20260127/cdhit/cdhit_shortest_seq.fa
# [M::main] Real time: 18.282 sec; CPU: 400.292 sec; Peak RSS: 7.499 GB
# Processing genomes:  30%|███       | 3/10 [01:07<02:29, 21.29s/it]
# 2026-01-27 12:36:57.870 | INFO     | __main__:main:99 - Output: /home/gyk/project/spider_silkome/data/processed/miniprot_mapping_20260127/miniprot_output/Pardosa_pseudoannulata/Pardosa_pseudoannulata.gff
# 2026-01-27 12:36:57.870 | INFO     | __main__:main:89 - Processing Heteropoda_venatoria: /home/gyk/project/spider_silkome/data/raw/spider_genome/079.Heteropoda_venatoria/Heteropoda_venatoria.mpi
# [M::mp_idx_restore@29.988*0.57] loaded the index
# [M::mp_idx_print_stat] 2400099 distinct k-mers; mean occ of infrequent k-mers: 814.51; 10205 frequent k-mers accounting for 299685481 occurrences
# [M::worker_pipeline::53.287*29.21] mapped 4066 sequences
# [M::worker_pipeline::55.964*30.35] mapped 2919 sequences
# [M::main] Version: 0.18-r281
# [M::main] CMD: miniprot -S --gff-delim . --outc 0.8 -t 70 -I --gff-only /home/gyk/project/spider_silkome/data/raw/spider_genome/079.Heteropoda_venatoria/Heteropoda_venatoria.mpi /home/gyk/project/spider_silkome/data/interim/miniprot_mapping_20260127/cdhit/cdhit_shortest_seq.fa
# [M::main] Real time: 56.918 sec; CPU: 1699.393 sec; Peak RSS: 23.398 GB
# Processing genomes:  40%|████      | 4/10 [02:04<03:32, 35.37s/it]
# 2026-01-27 12:37:54.827 | INFO     | __main__:main:99 - Output: /home/gyk/project/spider_silkome/data/processed/miniprot_mapping_20260127/miniprot_output/Heteropoda_venatoria/Heteropoda_venatoria.gff
# 2026-01-27 12:37:54.828 | INFO     | __main__:main:89 - Processing Scorpiops_zhui: /home/gyk/project/spider_silkome/data/raw/spider_genome/045.Scorpiops_zhui/Scorpiops_zhui.mpi
# [M::mp_idx_restore@33.461*0.60] loaded the index
# [M::mp_idx_print_stat] 2404995 distinct k-mers; mean occ of infrequent k-mers: 949.21; 14376 frequent k-mers accounting for 503454547 occurrences
# [M::worker_pipeline::57.122*27.42] mapped 4066 sequences
# [M::worker_pipeline::60.667*28.98] mapped 2919 sequences
# [M::main] Version: 0.18-r281
# [M::main] CMD: miniprot -S --gff-delim . --outc 0.8 -t 70 -I --gff-only /home/gyk/project/spider_silkome/data/raw/spider_genome/045.Scorpiops_zhui/Scorpiops_zhui.mpi /home/gyk/project/spider_silkome/data/interim/miniprot_mapping_20260127/cdhit/cdhit_shortest_seq.fa
# [M::main] Real time: 61.947 sec; CPU: 1759.277 sec; Peak RSS: 27.552 GB
# Processing genomes:  50%|█████     | 5/10 [03:06<03:44, 44.96s/it]
# 2026-01-27 12:38:56.803 | INFO     | __main__:main:99 - Output: /home/gyk/project/spider_silkome/data/processed/miniprot_mapping_20260127/miniprot_output/Scorpiops_zhui/Scorpiops_zhui.gff
# 2026-01-27 12:38:56.803 | INFO     | __main__:main:89 - Processing Pholcus_sp: /home/gyk/project/spider_silkome/data/raw/spider_genome/034.Pholcus_sp/Pholcus_sp.mpi
# [M::mp_idx_restore@5.317*0.57] loaded the index
# [M::mp_idx_print_stat] 2319710 distinct k-mers; mean occ of infrequent k-mers: 169.35; 102 frequent k-mers accounting for 2936720 occurrences
# [M::worker_pipeline::7.588*18.71] mapped 4066 sequences
# [M::worker_pipeline::8.456*23.71] mapped 2919 sequences
# [M::main] Version: 0.18-r281
# [M::main] CMD: miniprot -S --gff-delim . --outc 0.8 -t 70 -I --gff-only /home/gyk/project/spider_silkome/data/raw/spider_genome/034.Pholcus_sp/Pholcus_sp.mpi /home/gyk/project/spider_silkome/data/interim/miniprot_mapping_20260127/cdhit/cdhit_shortest_seq.fa
# [M::main] Real time: 8.646 sec; CPU: 200.635 sec; Peak RSS: 3.865 GB
# Processing genomes:  60%|██████    | 6/10 [03:15<02:10, 32.65s/it]
# 2026-01-27 12:39:05.543 | INFO     | __main__:main:99 - Output: /home/gyk/project/spider_silkome/data/processed/miniprot_mapping_20260127/miniprot_output/Pholcus_sp/Pholcus_sp.gff
# 2026-01-27 12:39:05.543 | INFO     | __main__:main:89 - Processing Evarcha_sp: /home/gyk/project/spider_silkome/data/raw/spider_genome/013.Evarcha_sp/Evarcha_sp.mpi
# [M::mp_idx_restore@32.889*0.63] loaded the index
# [M::mp_idx_print_stat] 2379530 distinct k-mers; mean occ of infrequent k-mers: 827.53; 15638 frequent k-mers accounting for 523531217 occurrences
# [M::worker_pipeline::58.625*29.51] mapped 4066 sequences
# [M::worker_pipeline::62.517*31.32] mapped 2919 sequences
# [M::main] Version: 0.18-r281
# [M::main] CMD: miniprot -S --gff-delim . --outc 0.8 -t 70 -I --gff-only /home/gyk/project/spider_silkome/data/raw/spider_genome/013.Evarcha_sp/Evarcha_sp.mpi /home/gyk/project/spider_silkome/data/interim/miniprot_mapping_20260127/cdhit/cdhit_shortest_seq.fa
# [M::main] Real time: 63.519 sec; CPU: 1958.761 sec; Peak RSS: 23.942 GB
# Processing genomes:  70%|███████   | 7/10 [04:19<02:08, 42.75s/it]
# 2026-01-27 12:40:09.088 | INFO     | __main__:main:99 - Output: /home/gyk/project/spider_silkome/data/processed/miniprot_mapping_20260127/miniprot_output/Evarcha_sp/Evarcha_sp.gff
# 2026-01-27 12:40:09.088 | INFO     | __main__:main:89 - Processing Pandercetes_sp: /home/gyk/project/spider_silkome/data/raw/spider_genome/031.Pandercetes_sp/Pandercetes_sp.mpi
# [M::mp_idx_restore@29.770*0.58] loaded the index
# [M::mp_idx_print_stat] 2400014 distinct k-mers; mean occ of infrequent k-mers: 740.24; 6594 frequent k-mers accounting for 200110267 occurrences
# [M::worker_pipeline::58.322*33.03] mapped 4066 sequences
# [M::worker_pipeline::63.691*35.44] mapped 2919 sequences
# [M::main] Version: 0.18-r281
# [M::main] CMD: miniprot -S --gff-delim . --outc 0.8 -t 70 -I --gff-only /home/gyk/project/spider_silkome/data/raw/spider_genome/031.Pandercetes_sp/Pandercetes_sp.mpi /home/gyk/project/spider_silkome/data/interim/miniprot_mapping_20260127/cdhit/cdhit_shortest_seq.fa
# [M::main] Real time: 64.597 sec; CPU: 2258.179 sec; Peak RSS: 21.445 GB
# Processing genomes:  80%|████████  | 8/10 [05:23<01:39, 49.72s/it]
# 2026-01-27 12:41:13.746 | INFO     | __main__:main:99 - Output: /home/gyk/project/spider_silkome/data/processed/miniprot_mapping_20260127/miniprot_output/Pandercetes_sp/Pandercetes_sp.gff
# 2026-01-27 12:41:13.747 | INFO     | __main__:main:89 - Processing Hippasa_lycosina: /home/gyk/project/spider_silkome/data/raw/spider_genome/017.Hippasa_lycosina/Hippasa_lycosina.mpi
# [M::mp_idx_restore@11.240*0.60] loaded the index
# [M::mp_idx_print_stat] 2347132 distinct k-mers; mean occ of infrequent k-mers: 329.05; 587 frequent k-mers accounting for 22261028 occurrences
# [M::worker_pipeline::19.345*27.52] mapped 4066 sequences
# [M::worker_pipeline::21.064*30.57] mapped 2919 sequences
# [M::main] Version: 0.18-r281
# [M::main] CMD: miniprot -S --gff-delim . --outc 0.8 -t 70 -I --gff-only /home/gyk/project/spider_silkome/data/raw/spider_genome/017.Hippasa_lycosina/Hippasa_lycosina.mpi /home/gyk/project/spider_silkome/data/interim/miniprot_mapping_20260127/cdhit/cdhit_shortest_seq.fa
# [M::main] Real time: 21.467 sec; CPU: 644.427 sec; Peak RSS: 7.830 GB
# Processing genomes:  90%|█████████ | 9/10 [05:45<00:40, 40.93s/it]
# 2026-01-27 12:41:35.351 | INFO     | __main__:main:99 - Output: /home/gyk/project/spider_silkome/data/processed/miniprot_mapping_20260127/miniprot_output/Hippasa_lycosina/Hippasa_lycosina.gff
# 2026-01-27 12:41:35.352 | INFO     | __main__:main:89 - Processing Trichonephila_clavata: /home/gyk/project/spider_silkome/data/raw/spider_genome/119.Trichonephila_clavata/Trichonephila_clavata.mpi
# [M::mp_idx_restore@3.893*1.00] loaded the index
# [M::mp_idx_print_stat] 2364518 distinct k-mers; mean occ of infrequent k-mers: 391.92; 573 frequent k-mers accounting for 15240950 occurrences
# [M::worker_pipeline::15.088*48.93] mapped 4066 sequences
# [M::worker_pipeline::16.882*50.57] mapped 2919 sequences
# [M::main] Version: 0.18-r281
# [M::main] CMD: miniprot -S --gff-delim . --outc 0.8 -t 70 -I --gff-only /home/gyk/project/spider_silkome/data/raw/spider_genome/119.Trichonephila_clavata/Trichonephila_clavata.mpi /home/gyk/project/spider_silkome/data/interim/miniprot_mapping_20260127/cdhit/cdhit_shortest_seq.fa
# [M::main] Real time: 17.346 sec; CPU: 854.098 sec; Peak RSS: 9.686 GB
# Processing genomes: 100%|██████████| 10/10 [06:02<00:00, 36.28s/it]
# 2026-01-27 12:41:52.857 | INFO     | __main__:main:99 - Output: /home/gyk/project/spider_silkome/data/processed/miniprot_mapping_20260127/miniprot_output/Trichonephila_clavata/Trichonephila_clavata.gff
# 2026-01-27 12:41:52.858 | SUCCESS  | __main__:main:101 - Completed miniprot alignment for 10 genome(s)

# %%
from pybedtools import BedTool

spider = "Trichonephila_clavata"
output_dir = f"{miniprot_output_path}/{spider}_all"
mRNA_gff = f"{output_dir}/{spider}.mRNA.gff"

merged_mRNA_gff = BedTool(mRNA_gff).merge(s=True)
for gene in merged_mRNA_gff:
    print(gene)

# %% [markdown]
# Defining the gene boundaries for each type of Spidroin should be part of the `for spider_genome in spider_genomes:` loop. For convenience, this section has been separated for testing.
#
# <zh>处理每一种蛛丝蛋白的基因边界界定，这一部分应该作为`for spider_genome in spider_genomes:`循环下的一部分，这里为了方便，独立出来进行测试。</zh>

# %%
spidroins = ['MaSp3', 'Pflag', 'MiSp', 'MaSp2', 'AcSp', 'CySp',
'MaSp3B', 'Spidroin', 'Putative_spidroin', 'CrSp', 'AgSp2', 'MaSp1',
'Ampullate_spidroin', 'MaSp', 'Flag', 'AgSp1', 'MaSp2B', 'PySp'] # Define the spidroins for test, should be the same as the spidroins used in the `for spider_genome in spider_genomes:` loop.
all_gff_records = []
all_csv = pd.DataFrame()
for spidroin in spidroins:
    # spidroin = "MiSp"
    spider = "Trichonephila_clavata"
    output_dir = f"{miniprot_output_path}/{spider}_all"
    spidroin_gff = f"{output_dir}/{spider}.mRNA.{spidroin}.gff"
    attr_dict = {}
    spidroin_gff_data = []
    with open(spidroin_gff, 'r') as f:
        for line in f:
            if line.startswith('#'):
                continue

            fields = line.strip().split('\t')

            # Analysis of the attributes field
            for attr in fields[8].split(';'):
                if '=' in attr:
                    key, value = attr.split('=', 1)
                    attr_dict[key] = value

            # Create attributes object
            attr_obj = Attributes(
                ID=attr_dict['ID'],
                Rank=int(attr_dict['Rank']),
                Identity=float(attr_dict['Identity']),
                Positive=float(attr_dict['Positive']),
                Target=attr_dict['Target'].split('|')
            )

            # Create gff_data object and add to list
            spidroin_gff_data.append(GFFData(
                seqid=fields[0],
                source=fields[1],
                type=fields[2],
                start=int(fields[3]),
                end=int(fields[4]),
                score=float(fields[5]),
                strand=fields[6],
                frame=fields[7],
                attributes=attr_obj
            ))

    # Sort by positive with descending order
    spidroin_gff_data.sort(key=lambda x: x.attributes.Positive, reverse=True)
    # Extract positions
    positions = extract_positions_from_gff(spidroin_gff_data, positive_threshold=0.75)
    # Export data
    # Export CSV data
    csv_output = spidroin_gff.replace('.gff', '.csv')
    df = positions_export(positions, csv_output, format='csv')
    all_csv = pd.concat([all_csv, df], ignore_index=True)

    # Export GFF data
    gff_output = spidroin_gff.replace('.gff', '.combined.gff')
    gff_records = positions_export(
        positions,
        gff_output,
        format='gff',
        spidroin=spidroin,
        min_length=1000, # Set minimum gene length threshold
        max_length=100000, # Set maximum gene length threshold
        extension_length=10000 # Set length to extend when start or end is missing
)

    all_gff_records.extend(gff_records)

# Convert to DataFrame and save
final_output_dir = f"{PROCESSED_DATA_DIR}/01.miniprot_mapping"
os.makedirs(final_output_dir, exist_ok=True)
if all_gff_records:
    df_combined = pd.DataFrame(all_gff_records)
    # Sort by seqid (chromosome) and start position with natural sorting
    df_combined['seqid_sort'] = df_combined['seqid'].str.extract(r'(\d+)').astype(float)
    df_combined = df_combined.sort_values(['seqid_sort', 'start']).drop('seqid_sort', axis=1)
    # //todo: 添加一个函数，能够处理 df_comined 中基因座相似的情况。
    # Write to GFF file
    with open(f"{final_output_dir}/{spider}.gff", 'w') as f:
        f.write("##gff-version 3\n")
        df_combined.to_csv(f, sep='\t', header=False, index=False)
else:
    print(f"No GFF records to combine for {spider}")

if not all_csv.empty:
    all_csv.to_csv(f"{final_output_dir}/{spider}.csv", index=False)

# %% [markdown]
# Filter positive_threshold > 0.75 mRNA in gff file

# %%
spider_genomes = [f for f in os.listdir(spider_genome_path) if f.endswith(".fa.gz")]
positive_threshold = 0.75
for spider_genome in spider_genomes:
    spider = spider_genome.replace(".fa.gz", "")
    gff_file = f"{INTERIM_DATA_DIR}/miniprot/{spider}_all/{spider}.gff"
    if not os.path.exists(gff_file):
        gff_file = f"{INTERIM_DATA_DIR}/miniprot/{spider}_all/{spider}.fa.mRNA.gff"
    filtered_gff_file = f"{INTERIM_DATA_DIR}/miniprot/filtered_gff/{spider}.gff"
    os.makedirs(os.path.dirname(filtered_gff_file), exist_ok=True)
    cmd = f"awk -F'\t' '$3==\"mRNA\"{{match($9,/Positive=([0-9.]+)/,m); if(m[1]>={positive_threshold}) print; next}}1' {gff_file} | sort -k1,1V -k4,4n -k9,9 > {filtered_gff_file}"
    run_shell_command_with_check(cmd, filtered_gff_file, force=True)
